# %% [markdown]
# ##1.What is  the difference between interpreted and compiled languages? ##

# %% [markdown]
# **1.Interpreted Languages**
#
# Execution Process: Code is executed line-by-line or statement-by-statement using an interpreter. The interpreter reads the source code and directly executes instructions.
# Translation: The program is not converted into machine code in advance; instead, it is processed in real-time during execution.
#
# Examples: Python, JavaScript, Ruby, PHP.
#
# *Pros:*
#
# Easier debugging because errors are caught during execution.
# Platform independence; as long as an interpreter exists for a platform, the code can run on it.
# No separate compilation step, so faster iteration during development.
#
# *Cons:*
#
# Slower execution speed due to real-time interpretation.
# Requires the interpreter to run the program, which can add overhead.
#
# **2.Compiled Languages**
#
# Execution Process: Source code is converted into machine code (binary) using a compiler. The resulting machine code can then be executed directly by the computer’s hardware.
# Translation: Compilation happens before execution, producing a standalone executable file.
# Examples: C, C++, Rust, Go.
#
# *Pros:*
#
# Faster execution because the code is already translated into machine language.
# Typically results in more optimized and efficient programs.
# No need for the source code to run the program, which can protect intellectual property.
#
# *Cons:*
# Longer development process because of the separate compilation step.
# Errors are harder to debug since they are not caught until compilation is complete.
# The compiled code is platform-specific, so different binaries may be needed for different platforms.

# %% [markdown]
# ##2.What is exception handling in python ?

# %% [markdown]
# Exception handling in Python is a mechanism for managing errors or exceptional conditions that arise during program execution. It ensures the program can handle these issues gracefully instead of crashing. Python uses the try, except, else, and finally blocks to handle exceptions.
#
# **Key Components of Exception Handling**
#
#     try Block
#
# Contains the code that might raise an exception.
# If an exception occurs within the try block, the program jumps to the corresponding except block.
#
#     except Block
#
# Contains the code to handle the exception.
# You can specify the type of exception to handle specific errors or use a generic handler.
#
#     else Block (Optional)
#
# Runs if no exception occurs in the try block.
# Useful for code that should execute only when the try block succeeds.
#
#     finally Block (Optional)
#
# Contains code that runs regardless of whether an exception occurred or not.
# Typically used for cleanup tasks like closing files or releasing resources.

# %%
##Basic syntax
try:
    # Code that might raise an exception
    result = 10 / 0
except ZeroDivisionError:
    # Handling a specific exception
    print("You can't divide by zero!")
else:
    # Executes if no exception occurs
    print("Division successful:", result)
finally:
    # Always executes
    print("End of the exception handling block.")
# Out:
# You can't divide by zero!
# End of the exception handling block.

# %% [markdown]
# Common Exception Types in Python
#
# *ZeroDivisionError*: Raised when dividing by zero.
#
# *ValueError:* Raised when a function gets an argument of the correct type but an inappropriate value.
#
# *TypeError:* Raised when an operation is applied to an object of inappropriate type.
#
# *KeyError:* Raised when a dictionary key is not found.
#
# *IndexError:* Raised when accessing an out-of-range index in a list or tuple.
#
# *FileNotFoundError:* Raised when attempting to open a file that doesn't exist.

# %%
#Example: Handling Multiple Exceptions
try:
    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))
    result = x / y
except ValueError:
    print("Invalid input! Please enter numbers only.")
except ZeroDivisionError:
    print("You can't divide by zero!")
else:
    print("Result:", result)
finally:
    print("Thank you for using the calculator.")

# %% [markdown]
# ##3.What is the purpose of the finally blockin exception handling ?

# %% [markdown]
# The purpose of the finally block in exception handling is to ensure that specific code is always executed, regardless of whether an exception occurred or not. This block is typically used for cleanup operations or releasing resources like closing files, network connections, or releasing memory.
#
# **Key Features of the finally Block:**
#
# *Guaranteed Execution:*
#
# Code inside the finally block will always run after the try block, whether or not an exception occurs.
# If an exception is raised and not handled in the except block, the finally block still executes before the program terminates.
#
# *Resource Management:*
#
# It is commonly used to clean up resources such as:
# Closing file handles.
# Releasing database connections.
# Cleaning up temporary data.
#
# *Prevents Resource Leaks:*
#
# Ensures that resources are released or operations are finalized even when exceptions occur.

# %%
#Example: Using finally for Cleanup
try:
    file = open("example.txt", "r")
    # Attempt to read the file
    data = file.read()
except FileNotFoundError:
    print("File not found.")
finally:
    # Always close the file
    file.close()
    print("File has been closed.")

# %% [markdown]
# Explanation:
#
# If the file doesn't exist, an exception will be raised and caught by the except block.
#
# Regardless of whether the try block succeeds or fails, the finally block ensures the file is closed.

# %%
#Example: With an Unhandled Exception
try:
    print("Trying...")
    result = 10 / 0  # This raises ZeroDivisionError
finally:
    print("Execution of finally block.")

# %% [markdown]
# ***4.What is logging in python ?***

# %% [markdown]
# Logging in Python is a way to track events that happen while a program runs. It provides a mechanism to record messages that describe the program's operation, errors, and other information, which can help in debugging, monitoring, and auditing.
#
# Python’s built-in logging module is a powerful tool for managing logs, allowing developers to record messages at different levels of severity and output them to various destinations, such as the console, files, or external systems.
#
#
# *Benefits of Logging*
#
# Debugging and Diagnostics: Helps identify issues in a program without halting execution.
#
# *Audit Trails:* Records events for compliance or forensic purposes.
#
# *Monitoring:* Tracks the health and behavior of applications in production environments.
#
# *Customizable:* Offers granular control over what gets logged and where.
# Logging Levels
# The logging module provides predefined levels of severity for log messages:
#
#      Level	            Purpose	                        Example Use Case*
#
#     DEBUG 	Detailed information for debugging	Diagnosing complex issues
#     INFO	   General operational messages	        Normal operation tracking
#     WARNING	Indicates potential issues	        Deprecated features or low disk space
#     ERROR	   Error that prevents part of the program	     Catching exceptions
#     CRITICAL	Severe error causing program termination	  System failure

# %%
#Basic Usage Example
import logging

# Configure the logging system
logging.basicConfig(level=logging.INFO)

# Log messages at different levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
#Writing Logs to a File
logging.basicConfig(filename='app.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

logging.error("This is an error message.")
# Out:
# ERROR:root:This is an error message.

# %% [markdown]
#    filename: Specifies the file where logs will be written.
#
#    level: Sets the logging level.
#
#   format: Defines the structure of log messages.

# %% [markdown]
# Customizing Log Format
#
# You can customize log messages with placeholders:
#
# Placeholder	Description
#
#     *%(asctime)s*	   Timestamp of the log message
#
#     *%(levelname)s*	   Severity level of the log
#
#      *%(message)s*	  The log message text
#
#       *%(name)s*	  Logger’s name
#
#       *%(filename)s*	  Name of the source file

# %% [markdown]
# ***5.What is significance of __del__ mehod in python?***

# %% [markdown]
# Key Features of  __ del __
#
# Automatic Invocation:
#
# Called when an object’s reference count drops to zero, meaning there are no more references to the object.
# The exact timing of its invocation depends on Python's garbage collection process.
#
# Cleanup Tasks:
#
# Typically used to release resources, perform cleanup, or log messages during object destruction.
#
# Not Guaranteed Timing:
#
# The timing of __del__ invocation is not predictable, especially in programs with circular references or when using certain garbage collection mechanisms.

# %%
class MyClass:
    def __init__(self, name):
        self.name = name
        print(f"Object {self.name} created.")

    def __del__(self):
        print(f"Object {self.name} destroyed.")

# Create an object
obj = MyClass("A")

# Delete the object
del obj
# Out:
# Object A created.
# Object A destroyed.

# %% [markdown]
# Important Considerations
#
# Circular References:
# If objects are involved in circular references, the __del__ method may not be called because the garbage collector cannot determine which to delete first.
#
# Explicit Cleanup Preferred:
#
# It’s generally better to use context managers (with statement) for resource management as they provide deterministic cleanup:

# %%
with open("example.txt", "w") as file:
    file.write("Hello, World!")
# File is automatically closed when the block ends.

# %% [markdown]
# Avoid Complex Logic in __ del __:
#
# Placing extensive operations or relying on global state in __del__ is discouraged, as the environment during object destruction might be partially cleaned up.
#
# Garbage Collection:
#
# In CPython, the garbage collector is reference-count based, so __del__ is called when an object's reference count hits zero. However, in other Python implementations (like PyPy), the behavior may vary.

# %% [markdown]
# ***6.What is the difference between import and from ...import in python? ***

# %% [markdown]
# 1. import Statement
# The import statement loads an entire module and gives you access to all its attributes (functions, classes, and variables) using the module's name as a prefix.
#
# Syntax:
#
#        import module_name

# %%
import math
print(math.sqrt(16))  # Access sqrt function using math prefix

# %% [markdown]
# Advantages:
#
# Provides full access to the module's namespace.
# Reduces naming conflicts since attributes are accessed with the module prefix.
#
# Disadvantages:
#
# Can be verbose because you must use the module name every time you access its attributes.
#
# 2. from ... import Statement
#
# The from ... import statement allows you to import specific attributes (functions, classes, or variables) from a module directly into your program's namespace. This lets you use them without the module prefix.
#
# Syntax:
#
#           from module_name import attribute_name

# %%
from math import sqrt
print(sqrt(16))  # Directly use sqrt without math prefix

# %% [markdown]
# Advantages:
#
# More concise code, as there's no need to use the module prefix.
# Useful when you only need a few components from a large module.
#
# Disadvantages:
#
# Can lead to naming conflicts if the imported attribute has the same name as an existing identifier in your code.
# Makes it less clear which module the attribute comes from, potentially reducing code readability.

# %% [markdown]
# ***7.How can you handle  multiple exceptions in python ?***

# %% [markdown]
# 1. Using a Tuple of Exceptions
#
# we can catch multiple exceptions in a single except block by specifying them as a tuple.

# %%
try:
    # Code that might raise an exception
    x = int("not_a_number")
except (ValueError, TypeError) as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# 2. Using Multiple except Blocks
#
# wecan use multiple except blocks to handle different exceptions separately.

# %%
try:
    # Code that might raise an exception
    x = 1 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Value error occurred!")
#This allows you to handle each exception type differently.

# %% [markdown]
# 3. Catching All Exceptions (Not Recommended)
#
# we can catch all exceptions using a generic Exception. This should be used cautiously as it may mask other unexpected errors.

# %%
try:
    # Code that might raise an exception
    x = int("not_a_number")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %% [markdown]
# 4. Combining Specific and Generic Exception Handling
#
# we can combine specific exception handling with a generic except block to ensure all exceptions are caught.

# %%
try:
    # Code that might raise an exception
    x = 1 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Value error occurred!")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %% [markdown]
# 5. Using finally for Cleanup
#
# The finally block can be used for cleanup actions that must be executed regardless of whether an exception occurred.

# %%
try:
    x = int("not_a_number")
except ValueError:
    print("A ValueError occurred.")
finally:
    print("Execution complete.")

# %% [markdown]
# 6. Using else
#
# The else block is executed if no exception occurs.

# %%
try:
    x = int("10")
except ValueError:
    print("A ValueError occurred.")
else:
    print("No exception occurred. x =", x)
finally:
    print("Execution complete.")

# %% [markdown]
# Key Takeaways
#
# Use a tuple for catching related exceptions in a single block.
#
# Use separate except blocks for fine-grained control.
#
# Avoid catching Exception or BaseException unless absolutely necessary, as
# this may hide programming errors or critical issues.

# %% [markdown]
# ***8.What is the purpose of the with statement when handling files in python ?***

# %% [markdown]
# The with statement in Python is used to simplify file handling and ensure that resources like files are properly managed. Its primary purpose is to manage the context of a resource, automatically handling setup and teardown actions such as opening and closing files.
#
# ##Benefits of Using with for File Handling##
#
# ***Automatic Resource Management***
#
# The with statement ensures that the file is automatically closed after the block of code is executed, even if an exception occurs during file operations.
# This eliminates the need to explicitly call file.close().
#
# **Cleaner and More Readable Code**
#
# It reduces boilerplate code, making the program easier to read and maintain.
# **Exception Safety**
#
# The with statement ensures that resources are released properly in the event of an exception, preventing resource leaks.

# %%
#Example Without with
file = open("example.txt", "r")
try:
    data = file.read()
    print(data)
finally:
    file.close()  # Must be explicitly called to release the resource

# %%
#Example With with
with open("example.txt", "r") as file:
    data = file.read()
    print(data)
# The file is automatically closed at the end of the block

# %% [markdown]
# ###How It Works##
# The with statement creates a context using a context manager (in this case, the file object).
#
# The file object’s __ enter __ method is called at the start of the block, which opens the file.
#
# The file object’s __ exit __ method is called at the end of the block, which closes the file, ensuring proper cleanup.

# %%
#General Syntax
with expression [as variable]:
    block_of_code

# %% [markdown]
#      expression: Creates the context (e.g., open("file.txt")).
#      variable: A reference to the object (e.g., file).
#      block_of_code: The code that operates on the resource within the context.

# %%
#Extended Example: Writing to a File
with open("output.txt", "w") as file:
    file.write("Hello, world!")
# No need to call file.close(), it’s done automatically

# %% [markdown]
# ***9.What is the difference between  multithreading and multiprocessing ?***

# %% [markdown]
# The main difference between multithreading and multiprocessing lies in how they achieve concurrency and handle resources. Here's a detailed breakdown:
#
# **1. Definition**
#
# *Multithreading:*
#
# Involves running multiple threads within the same process.
# Threads share the same memory space.
# Primarily used to perform tasks concurrently within a single process.
# Multiprocessing:
#
# Involves running multiple processes, each with its own memory space.
# Each process operates independently.
# Designed to leverage multiple CPU cores for parallel execution.
#
# **2. Concurrency vs. Parallelism**
#
# *Multithreading:*
#
# Achieves concurrency, which means multiple threads take turns executing tasks.
# In Python, due to the Global Interpreter Lock (GIL), threads do not execute Python bytecode in parallel. However, I/O-bound tasks can benefit from threading.
#
# *Multiprocessing:*
#
# Achieves true parallelism, where multiple processes run simultaneously on different CPU cores.
# Each process has its own interpreter and memory space, so the GIL does not limit multiprocessing.
#
# **3. Use Cases**
#
# *Multithreading:*
#
# Best for I/O-bound tasks (e.g., reading/writing files, handling network requests).
# Example: A web server handling multiple client connections simultaneously.
#
# *Multiprocessing:*
#
# Best for CPU-bound tasks (e.g., mathematical computations, data processing).
# Example: Parallel processing of large datasets or machine learning model training.
#
# **4. Resource Sharing**
#
# *Multithreading:*
#
# Threads share the same memory, which makes communication between them easier.
# Shared memory can lead to issues like race conditions and requires synchronization mechanisms (e.g., locks, semaphores).
#
# *Multiprocessing:*
#
# Processes have separate memory, so communication is more complex and done via mechanisms like pipes, queues, or shared memory.
# Safer than multithreading because processes don't share memory by default.
#
# **5.Overhead**
#
# *Multithreading:*
#
# Lighter weight, as threads within the same process share resources.
# Less memory overhead compared to multiprocessing.
# Multiprocessing:
#
# Heavier weight, as each process requires its own memory space.
# Higher memory and context-switching overhead.
#
# **6. Python-Specific Considerations**
#
# **Global Interpreter Lock (GIL):**
# In CPython (the standard Python implementation), the GIL prevents multiple threads from executing Python bytecode simultaneously.
# Multithreading in Python is not ideal for CPU-bound tasks but works well for I/O-bound tasks.
# Multiprocessing avoids the GIL because each process has its own Python interpreter.

# %%
#Multithreading Example:
import threading

def print_numbers():
    for i in range(5):
        print(f"Thread {i}")

threads = []
for _ in range(3):
    t = threading.Thread(target=print_numbers)
    threads.append(t)
    t.start()

for t in threads:
    t.join()

# %%
#Multiprocessing Example:
import multiprocessing

def print_numbers():
    for i in range(5):
        print(f"Process {i}")

processes = []
for _ in range(3):
    p = multiprocessing.Process(target=print_numbers)
    processes.append(p)
    p.start()

for p in processes:
    p.join()

# %% [markdown]
# ***10.What are the advantages of using logging in a program?***

# %% [markdown]
# **1. Improved Debugging and Problem Diagnosis**
#
# Logs provide detailed information about program execution, making it easier to identify and fix issues.
#
# They record the sequence of events leading to an error or unexpected behavior.
#
# **2. Persistent Record of Execution*
#
# Logs serve as a historical record of the program's behavior, allowing you to review what happened even after the program has finished running.
#
# Useful for post-mortem analysis and understanding issues reported by users.
#
# **3. Real-time Monitoring**
#
# Logging can provide real-time updates about the system's health and activities, which is crucial for long-running or production applications.
#
# Logs can be integrated into monitoring tools to detect anomalies or issues as they occur.
#
# **4. Separation of Concerns**
#
# Logs allow developers to separate diagnostic messages from normal program output, keeping the program output clean and focused on its primary purpose.
#
# **5. Customizable and Granular Control**
#
# You can log messages at different levels of importance (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# Fine-grained control allows for detailed output during development and concise logs in production.
#
# **6. Scalable and Flexible**
#
# Logs can be written to various destinations, such as the console, files, databases, or external monitoring systems.
#
# The logging library supports advanced configurations, such as log rotation and formatting.
#
# **7. Thread-Safe logging **
#
# Python's logging module is thread-safe, which means you can safely log from multiple threads in a multithreaded application.
#
# **8. Compliance and Auditability**
# Logs provide evidence of system activity, which can help in compliance with regulations or auditing requirements.
# They demonstrate accountability and operational transparency.
#
# **9. Support for Structured Data**
# Logging frameworks can handle structured data (e.g., JSON), making it easier to parse and analyze logs programmatically.
#
# **10. Built-in Support in Python**
#
# Python's logging module is part of the standard library, making it easy to integrate logging without external dependencies.
#
# Example of setting up logging in Python

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.info("This is an informational message.")
logging.warning("This is a warning.")
logging.error("This is an error message.")

# %% [markdown]
# 11. Facilitates Collaboration
#
# Logs provide context for team members working on the same codebase, allowing them to understand the state and flow of the application without additional explanations.
#
# **Logging Levels in Python**
#
#     DEBUG: Detailed information for diagnosing problems.
#     INFO: Confirmation that things are working as expected.
#     WARNING: Indication of a potential problem.
#     ERROR: A more serious issue that prevents the program from continuing some operation.
#     CRITICAL: A very serious issue that may cause the program to terminate.

# %% [markdown]
# ***11.What is the memory management n python ?***

# %% [markdown]
# **1. Key Features of Python Memory Management**
#
# *Automatic Memory Management:*
#
# Python uses a garbage collector to automatically reclaim unused memory, eliminating the need for explicit memory management like in C or C++.
# Object Allocation and Deallocation:
#
# Memory for objects is allocated dynamically and deallocated when they are no longer needed.
# Reference Counting:
#
# Python uses reference counting as the primary mechanism for memory management. Each object keeps track of how many references point to it.
#
# **2. Components of Python Memory Management**
#
# *a. Python Memory Manager*
#
# The Python memory manager handles the allocation and deallocation of memory at the application level. It includes:
#
# *Object-specific Allocators:*
#
# Different types of objects (e.g., integers, strings, lists) use optimized memory allocators.
#
# *Private Heap:*
#
# All Python objects and data structures reside in a private heap managed by the interpreter.
#
# *b. Garbage Collector*
#
# Python's garbage collector is part of the gc module and handles the cleanup of unused objects. It:
#
# Reclaims memory of objects that are no longer accessible.
# Handles cyclic references (e.g., objects referencing each other in a loop).
# Can be explicitly invoked with gc.collect().
#
# *c. Reference Counting*
#
# Each Python object has an associated reference count, which increases when a new reference to the object is created and decreases when a reference is deleted.
# When the reference count reaches zero, the memory occupied by the object is deallocated.
#
# *d. Memory Pools*
#
# Python uses a memory pool mechanism for efficiency, especially for small objects.
# Small objects are stored in fixed-size blocks to reduce fragmentation and improve performance

# %%
import sys

a = [1, 2, 3]
print(sys.getrefcount(a))  # Shows the reference count for object `a`

# %% [markdown]
# *4. Memory Leaks and Best Practices*
#
# While Python handles memory management well, memory leaks can occur if:
#
# There are references that persist unintentionally.
#
# Objects with circular references remain inaccessible to the garbage collector.
#
# *Best Practices:*
#
# Use weak references (weakref module) to avoid strong references when necessary.
#
# Avoid creating circular references, especially with custom objects.
#
# Use tools like gc and memory_profiler to monitor memory usage.
#
# Release resources explicitly using del or context managers (with).
#
# **5. Low-Level Details**
#
# PyObject: All Python objects are instances of PyObject, which includes metadata like reference count.
#
# Memory APIs: Python provides PyMalloc and other APIs for efficient memory allocation.

# %%
#Example of Memory Management in Action
import gc

class MyClass:
    def __del__(self):
        print("Object deleted")

obj = MyClass()
print("Reference count:", gc.get_referrers(obj))
del obj  # Explicitly deleting the object
gc.collect()  # Force garbage collection

# %% [markdown]
# ***12.What are the basic steps involved in exception handling in python ?***

# %% [markdown]
# **1. Identify Risky Code**
#
# Determine which parts of your code might cause an exception, such as file operations, user input, or calculations that might raise errors like division by zero.
#
# **2. Use a try Block**
#
# Place the potentially risky code inside a try block. This block will monitor for exceptions during execution.

# %%
try:
    # Risky code
    num = int(input("Enter a number: "))

# %% [markdown]
# **3. Handle Exceptions with except**
#
# Follow the try block with one or more except blocks to handle specific exceptions or all exceptions.
#
# Each except block is used to define how the program should respond to a particular type of exception.

# %%
try:
    num = int(input("Enter a number: "))
except ValueError:
    print("Invalid input! Please enter a valid number.")

# %% [markdown]
# **4. Use an else Block (Optional)**
#
# The else block runs if no exception occurs in the try block. It allows you to specify code that should execute only when the try block succeeds.

# %%
try:
    num = int(input("Enter a number: "))
except ValueError:
    print("Invalid input!")
else:
    print(f"Success! You entered {num}")

# %% [markdown]
# 5. Use a finally Block (Optional)
#
# The finally block contains code that should run no matter what, whether an exception occurs or not. It’s commonly used for cleanup actions like closing files or releasing resources.

# %%
try:
    file = open("example.txt", "r")
    data = file.read()
except FileNotFoundError:
    print("File not found!")
finally:
    print("Closing file...")
    file.close()

# %% [markdown]
# 6. Raise Exceptions (Optional)
#
# You can explicitly raise exceptions in your code using the raise keyword, either with or without custom error messages.

# %%
raise ValueError("This is a custom error message")

# %%
#Example: Complete Exception Handling
try:
    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))
    result = x / y
except ValueError:
    print("Invalid input! Please enter numbers only.")
except ZeroDivisionError:
    print("Cannot divide by zero!")
else:
    print(f"The result is: {result}")
finally:
    print("Execution complete.")

# %% [markdown]
# *Key Points:*
#
# try: Defines a block of code to monitor for exceptions.
# except: Defines how to handle specific exceptions.
#
# else: Executes code if no exceptions are raised.
# finally: Executes cleanup code regardless of exceptions.
#
# *Best Practices:*
#
# Catch specific exceptions rather than using a generic except Exception.
#
# Use the finally block to ensure resource cleanup.
#
# Avoid using exceptions for normal control flow.
#
# Provide meaningful error messages in your exception handling code.

# %% [markdown]
# ***13.Why is memory mangement in python?***

# %% [markdown]
# **1. Automatic Memory Allocation and Deallocation**
#
# Python automates memory allocation for creating objects and variables, and deallocates it when they are no longer needed.
# This reduces the burden on developers to manually allocate and free memory, avoiding common memory management issues like memory leaks and dangling pointers.
#
# **2. Efficient Use of Resources**
#
# Proper memory management ensures optimal use of system memory, allowing Python programs to run efficiently.
# Python uses techniques like reference counting and garbage collection to reclaim unused memory, which prevents memory wastage.
#
# **3. Simplified Programming**
#
# Developers can focus on solving problems without worrying about low-level memory operations, as Python handles it transparently.
# This abstraction makes Python easier to learn and use compared to languages like C or C++ that require manual memory management.
#
# **4. Prevention of Memory Leaks**
# The garbage collector identifies objects no longer in use and deallocates their memory, reducing the risk of memory leaks.
# However, developers should still be cautious of circular references, which can require explicit garbage collection or memory debugging tools.
#
# **5. Dynamic Memory Allocation**
#
# Python supports dynamic typing, where variable types are determined at runtime, requiring dynamic memory allocation.
# The memory manager handles this by efficiently allocating and resizing memory for objects as needed.
#
# **6. Support for Complex Applications**
#
# Effective memory management is crucial for applications that handle large datasets or run for extended periods, such as:
# Machine learning models.
# Web servers and microservices.
# Real-time data processing applications.
#
# **7. Multi-threading and Multi-processing**
#
# Python's memory management ensures thread-safe operations by isolating memory in different threads or processes.
# This is particularly important for concurrent programming, where memory access needs to be coordinated.
#
# **8. Managed Memory Pooling**
#
# Python uses memory pools for small objects (like integers and strings) to minimize memory fragmentation and improve performance.
# This internal optimization speeds up object creation and reuses memory efficiently.
# ***Key Features of Python's Memory Management***
#
# **Private Heap:** Python objects and data structures are stored in a private heap managed internally.
#
# **Reference Counting:** Tracks the number of references to an object. When the count drops to zero, the memory is deallocated.
#
# **Garbage Collection:** Identifies and reclaims memory for objects involved in circular references.
# Dynamic Memory Allocation: Adjusts memory allocation for variables and objects as the program runs.

# %%
#Example of Memory Management in Action
import sys
import gc

# Creating an object
a = [1, 2, 3]
print(f"Reference count of object a: {sys.getrefcount(a)}")

# Deleting the reference
del a
print("Deleted the object. Invoking garbage collector...")
gc.collect()
# Out:
# Reference count of object a: 2
# Deleted the object. Invoking garbage collector...
# 32

# %% [markdown]
# ***Why Memory Management Matters***
#
# It ensures that your programs are robust, efficient, and scalable.
# Reduces the likelihood of runtime errors and system crashes caused by insufficient memory.
# Helps manage limited system resources in large-scale or resource-intensive applications.

# %% [markdown]
# ***14.What is the role of try and except in exceptional handling ? ***

# %% [markdown]
# **Role of try**
#
# *Monitor Risky Code:*
#
# The try block contains the code that might raise an exception.
# Python "tries" to execute the code in this block. If no exceptions occur, the program proceeds normally.
#
# *Isolate Error-Prone Sections:*
#
# By isolating risky code in a try block, you can focus error handling on just those parts of the program that are likely to fail.
#
# **Prevent Crashes:**
#
# If an exception occurs within the try block, Python immediately exits the block and looks for an appropriate except block to handle the error. This prevents the program from crashing unexpectedly.
#
# **Role of except**
#
# *Handle Exceptions:*
#
# The except block defines how to respond to specific exceptions. It catches and processes the errors that occurred in the try block.
#
# **Control Flow:**
#
# By handling exceptions, the except block allows the program to continue running, even after encountering an error.
#
# **Catch Specific Errors:**
#
# You can catch specific types of exceptions (e.g., ValueError, ZeroDivisionError) and provide tailored responses for each.
#
# *Catch All Errors (Optionally):*
#
# You can use a generic except block to catch any exception that is not explicitly handled. However, this should be used cautiously to avoid masking unexpected errors.

# %%
#Syntax of try and except
try:
    # Code that might raise an exception
except SpecificException:
    # Code to handle the exception

# %%
#Example: Handling a Specific Exception
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except ValueError:
    print("Invalid input! Please enter a number.")
except ZeroDivisionError:
    print("Division by zero is not allowed.")
else:
    print(f"Result is {result}")
finally:
    print("Execution complete.")
# Out:
# Enter a number: 10
# Result is 1.0
# Execution complete.

# %% [markdown]
# ***15.How does python's garbage collection system work ?***

# %% [markdown]
# ***Key Concepts of Python's Garbage Collection:***
#
# *1. Reference Counting*
#
# Reference counting is the primary memory management technique used by Python.
# Every object in Python has an associated reference count that tracks how many references point to the object.
# When an object is created, its reference count starts at 1 (one reference to the object).
# When a new reference to the object is created (e.g., by assigning it to another variable), the reference count increases.
# When a reference is deleted, the reference count decreases.
#
# When the reference count reaches 0, it means the object is no longer needed, and Python automatically deallocates its memory.
#
# *2. Cyclic Garbage Collection*
#
# While reference counting works well for most cases, it cannot handle circular references—where two or more objects reference each other, creating a cycle.

# %%
class A:
    def __init__(self):
        self.ref = None

obj1 = A()
obj2 = A()
obj1.ref = obj2  # obj1 references obj2
obj2.ref = obj1  # obj2 references obj1 (circular reference)

# %% [markdown]
# In this case, even though obj1 and obj2 are no longer referenced by any other part of the program, their reference counts won't reach 0 because they reference each other. This would lead to a memory leak.
#
# To handle circular references, Python uses a garbage collector (GC), which periodically checks for and removes unreachable objects, even if they are part of a cycle.

# %% [markdown]
# **3. Generational Garbage Collection**
#
# Python's garbage collection uses a generational approach to manage memory more efficiently. It divides objects into three generations (young, middle-aged, and old) based on how long they have been alive in the program:
#
# Generation 0: Newly created objects (most objects are expected to die young).
#
# Generation 1: Objects that survived one garbage collection cycle.
#
# Generation 2: Objects that survived multiple garbage collection cycles.
# The idea is that:
#
# Young objects are more likely to become unreachable soon, so the garbage collector runs more frequently on Generation 0.
# Older objects are less likely to be garbage, so they are collected less frequently.
#
# **4. Garbage Collection Process**
#
# Python's garbage collector runs periodically in the background to identify objects that are no longer needed and can be safely deleted. The GC looks for objects that:
#
# Have no references pointing to them.
# Are part of a cyclic reference.
# The gc module in Python allows you to control and interact with the
#
# **garbage collection process:**
#
# You can manually trigger garbage collection using gc. collect().
# You can inspect objects tracked by the garbage collector using gc. get_objects().

# %%
import gc

gc.collect()  # Forces garbage collection

# %% [markdown]
# **5. Memory Management with gc Module**
#
# Python’s gc module provides functions to interact with the garbage collector, such as:
#
# gc.collect(): Forces the garbage collection process to run.
#
# gc.get_count(): Returns the number of objects in each generation.
#
# gc.get_objects(): Returns a list of all objects tracked by the garbage collector.

# %%
import gc

# Force a garbage collection cycle
gc.collect()

# Check the number of objects in each generation
print(gc.get_count())

# %% [markdown]
# **Advantages of Python's Garbage Collection System:**
#
# *Automatic Memory Management:* Developers do not need to manually manage memory allocation and deallocation, which reduces errors like memory leaks and dangling pointers.
#
# *Efficient Handling of Cyclic References:* Python can handle cyclic references, which reference counting alone cannot address.
#
# *Generational Approach:* The GC's generational strategy is efficient because it assumes that most objects die young, reducing the overhead of frequent garbage collections for older objects.
#
# *Customizability:* Developers can control and fine-tune the behavior of the garbage collector, such as forcing a collection or changing the threshold for when garbage collection occurs.

# %% [markdown]
# ***16.What is the purpose of the else block inexception handling ?***

# %% [markdown]
# **Key Points about the else Block**
#
# *When it Runs:*
#
# The else block runs if the try block completes without raising any exceptions.
#
# *When it Does Not Run:*
#
# If an exception is raised in the try block and handled by an except block, the else block is skipped.
#
# **Purpose:**
#
# It is used to run code that should only execute when the try block is successful.
# Keeps the try block focused on code that may raise exceptions, while separating out the normal logic.

# %%
try:
    # Code that might raise an exception
    result = 10 / 2
except ZeroDivisionError:
    # Handle division by zero
    print("Cannot divide by zero!")
else:
    # Execute only if no exception occurs
    print("Division successful. Result:", result)
# Out:
# Division successful. Result: 5.0

# %% [markdown]
# **Why Use It?**
#
# To improve readability by clearly distinguishing error handling (except) from success case logic (else).
#
# To avoid accidentally handling non-exceptional cases in the except block.
# If there is no else block, you might end up mixing success-case code with exception-handling logic, which can make the code harder to understand.

# %% [markdown]
# ***17.What are the common loggin levels in python?***

# %% [markdown]
# **Common Logging Levels in Python**
#
# DEBUG (Level: 10)
#
# Purpose: Detailed diagnostic information useful for debugging.
# Usage: Typically used during development to understand the flow and state of the application.
#
#        logging.debug("This is a debug message.")

# %% [markdown]
# **INFO (Level: 20)**
#
# Purpose: General information about the application's normal operations.
#
# Usage: Used to confirm that things are working as expected.
#
#        logging.info("Application started successfully.")
#
#
#  **WARNING (Level: 30)**
#
# Purpose: Indications of potential issues or unexpected situations that aren't necessarily errors.
#
# Usage: Used to alert about situations that may need attention.
#
#          logging.warning("Disk space is running low.")
#
# **ERROR (Level: 40)**
#
# Purpose: Serious issues that have caused a failure in some part of the application.
#
# Usage: Used to log errors that need immediate investigation.
#
#           logging.error("Failed to connect to the database.")
#
# **CRITICAL (Level: 50)**
#
# Purpose: Severe errors that may cause the program to terminate.
#
# Usage: Used to log critical problems that require immediate action.
#
#           logging.critical("System is out of memory.")
#
# ###Setting Logging Level
# You can set the logging level using basicConfig to control the minimum level of messages that will be logged. For example:
#
#     import logging
#
#     logging.basicConfig(level=logging.WARNING)
#     logging.debug("This won't be logged.")  # Below the threshold
#     logging.info("This won't be logged either.")  # Below the threshold
#     logging.warning("This will be logged.")  # At the threshold
#     logging.error("This will also be logged.")  # Above the threshold
#     logging.critical("This will definitely be logged.")  # Above the threshold
#
# ###Logging Hierarchy and Custom Levels
# In addition to the default levels, you can define custom levels if needed. The hierarchy ensures higher-severity messages always appear if a lower logging level is set.

# %% [markdown]
# ***18.What is the difference between os.fork() and multiprocessing in python ?***

# %% [markdown]
# **1. os.fork()**
#
# *What it Does:*
#
# os.fork() is a low-level system call that creates a new process by duplicating the current process (parent process).
# It directly interacts with the underlying operating system.
# Platform Dependency:
#
# Only available on Unix-like systems (e.g., Linux, macOS).
# Not supported on Windows.
#
# *Usage:*
#
# The child process starts execution right after the os.fork() call, sharing the parent process's memory space but with independent copies.
# Requires manual management of resources like shared data or inter-process communication (IPC).
#
# **Complexity:**
#
# Requires the programmer to handle low-level details (e.g., synchronization, communication).
# Debugging is harder due to shared memory and potential side effects.

# %%
import os

pid = os.fork()

if pid == 0:
    # Code for the child process
    print("This is the child process.")
else:
    # Code for the parent process
    print(f"This is the parent process. Child PID: {pid}")
# Out:
# This is the parent process. Child PID: 5344
# This is the child process.

# %% [markdown]
# **2. multiprocessing Module**
#
# *What it Does:*
#
# The multiprocessing module provides a higher-level API for creating and managing processes.
# It creates new Python processes that are fully independent from each other, each with its own memory space.
#
# *Platform Independence:*
#
# Works on all major platforms, including Windows, Linux, and macOS.
# On Windows, it uses a different mechanism (spawn instead of fork).
# Usage:
#
# Includes utilities for process pools, inter-process communication (queues, pipes), and shared memory.
# Processes can be managed using classes like Process, Pool, and more.

# %%
from multiprocessing import Process

def worker():
    print("This is the child process.")

if __name__ == "__main__":
    p = Process(target=worker)
    p.start()
    p.join()
    print("This is the parent process.")
# Out:
# This is the child process.
# This is the parent process.

# %% [markdown]
# ###When to Use
#
# *os.fork():*
#
# When you need fine-grained control over process creation and execution.
# For performance-critical applications where you understand the risks and complexities.
# On Unix-based systems only.
#
# *multiprocessing:*
#
# For most Python applications requiring parallelism or concurrent execution.
# When portability, ease of use, and robust process management are more important.
#
#       Feature	             os.fork()	             multiprocessing
#     Abstraction Level	Low-level system call	High-level Python library
#     Portability	 Unix/Linux only	              Cross-platform
#     Memory Space	Shared (but with copy-on-write)	Independent
#     Ease of Use	Requires manual handling of IPC, etc.	Provides utilities for IPC and management
#     Performance	Faster for lightweight process creation	Slightly slower due to abstraction
#     Debugging	Harder due to shared state	Easier due to isolated processes

# %% [markdown]
# ***19.What is the importance of closing a file in python ?***

# %% [markdown]
# **1. Releasing System Resources**
#
# When a file is opened, the operating system allocates resources like memory buffers and file descriptors to manage the file.
# Closing the file ensures these resources are released and made available for other tasks.
#
# **2. Flushing Write Buffers**
#
# For writable files, data may be buffered (temporarily stored in memory) before being written to disk.
# Closing the file ensures all data in the buffer is flushed to disk, avoiding data loss or incomplete writes.
# with open("example.txt", "w") as file:
#
#           file.write("Hello, World!")
#           # File is automatically closed here
# If you forget to close the file, some data might remain in the buffer and not be saved to the file.
#
# **3. Preventing File Locks**
# On some operating systems, an open file may be locked for use by the process.
# Closing the file releases the lock, allowing other processes to access it.
#
# **4. Avoiding File Corruption**
# Failing to close a file properly (especially during write operations) can lead to file corruption or incomplete file states.
#
# **5. Improved Code Readability and Safety**
# Closing a file explicitly signals the end of its use, making the code more understandable.
# Using constructs like with (context managers) ensures files are automatically closed, even if an error occurs during processing.
#
# Example: Closing Files Manually vs. Automatically
# Manual Closing
#
#                file = open("example.txt", "w")
#                file.write("Hello, World!")
#                file.close()  # Explicitly closing the file
#
# **Using a Context Manager**
#
#             with open("example.txt", "w") as file:
#             file.write("Hello, World!")
#               # File is automatically closed after the block

# %% [markdown]
# ***20.What is the difference between file.read() and file.deadline() in python ?***

# %% [markdown]
# 1. file.read([size])
# Purpose: Reads the entire file or a specified number of characters (or bytes for binary files) from the file.
#
# Behavior:
#
# If size is not provided, it reads the entire file content as a single string.
# If size is provided, it reads up to size characters (or bytes) from the file.

# %%
with open("example.txt", "r") as file:
    content = file.read()  # Reads the entire file
    print(content)
#With a size argument:
with open("example.txt", "r") as file:
    partial_content = file.read(5)  # Reads the first 5 characters
    print(partial_content)

# %% [markdown]
# 2. file.readline()
# Purpose: Reads a single line from the file.
#
# Behavior:
#
# Stops reading when it encounters a newline character (\n).
# If called repeatedly, it continues reading the next line until the end of the file.
# Returns an empty string ("") when the end of the file is reached.

# %%
with open("example.txt", "r") as file:
    line = file.readline()  # Reads the first line
    print(line)
#Reading line by line:
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())  # Reads and prints each line

# %% [markdown]
#       Feature	    file.read()	                       file.readline()
#
#     Reads	Whole file or specified number of chars	A single line at a time
#
#     Returns	A string (entire content or part of it)	A string (one line, including \n)
#     Memory Usage	Can be high for large files	More memory-efficient for line-by-line
#     End of File	Returns an empty string at EOF	Returns an empty string at EOF
#     Use Case	Read entire content or chunks	Process one line at a time

# %% [markdown]
# ***21.What is the logging module in python used for?***

# %% [markdown]
# **Key Features of the logging Module**
#
# *Captures Events and Errors:* Logs important events, warnings, or errors during program execution.
#
# *Customizable Logging Levels:* Allows control over the severity of messages to log.
#
# *Output Flexibility:*
#
#  Log messages can be directed to different destinations,
# such as:
# Console (standard output)
# Log files
# External logging systems or services
#
# *Thread-Safe:* Can handle logging in multi-threaded programs without conflicts.
# Logging Levels
# The logging module provides predefined logging levels to categorize the severity of log messages:
#
# *DEBUG (10):* Detailed diagnostic information, typically used during development.
#
# *INFO (20):* Confirmation that things are working as expected.
#
# *WARNING (30):* Indication of potential problems (e.g., deprecated features, missing files).
#
# *ERROR (40):* Serious problems that prevent the program from continuing.
#
# *CRITICAL (50):* Severe errors causing the program to crash or require immediate attention.

# %%
import logging

# Configuring the logging system
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Logging messages at different levels
logging.debug("This is a DEBUG message")
logging.info("This is an INFO message")
logging.warning("This is a WARNING message")
logging.error("This is an ERROR message")
logging.critical("This is a CRITICAL message")

# %%
#Advanced Features
##Log to Files: You can log messages to a file instead of the console.
logging.basicConfig(filename='app.log', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')
logging.error("This message will be saved in app.log")

# %%
#Custom Loggers: You can create and configure custom loggers to suit specific needs:

logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)

# Adding a console handler
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)

# Adding a file handler
file_handler = logging.FileHandler('my_log.log')
file_handler.setLevel(logging.ERROR)

# Setting a formatter
formatter = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
console_handler.setFormatter(formatter)
file_handler.setFormatter(formatter)

# Adding handlers to the logger
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# Logging messages
logger.debug("Debug message")
logger.error("Error message")

# %% [markdown]
# Filter Logs by Module or File: Each module or script can define its logger, making it easier to track logs by source.
#
#
# Rotating Log Files: Using RotatingFileHandler or TimedRotatingFileHandler, you can create log files that rotate based on size or time.

# %% [markdown]
# ***22.What is the os module in python used for in file handling?***

# %% [markdown]
# ***Common Uses of the os Module in File Handling***
#
# **File and Directory Management:**
#
# *Check for Existence:* Verify if a file or directory exists.
#
# *Create/Delete Files:* Programmatically create or delete files.
#
# *Create/Delete Directories:* Manage directories on the system.
# Path Manipulation:
#
# Construct, split, or normalize file paths.
# Handle operating system-specific path differences.
#
# **File Metadata:**
#
# Retrieve details like file size, creation time, and modification time.
#
# **Navigating Directories:**
#
# Change the current working directory.
# List files and subdirectories.

# %% [markdown]
# **Commonly Used os Module Functions for File Handling**
#
# *1. Working with Files*
#
# os.remove(path): Deletes a file at the specified path.

# %%
import os

if os.path.exists("example.txt"):
    os.remove("example.txt")
    print("File deleted")
else:
    print("File does not exist")

# %% [markdown]
# os.rename(src, dst): Renames or moves a file.

# %%
os.rename("old_name.txt", "new_name.txt")

# %% [markdown]
# **2. Working with Directories**
#
# os.mkdir(path): Creates a new directory.

# %%
os.mkdir("new_directory")

# %% [markdown]
# os.rmdir(path): Removes an empty directory.

# %%
os.rmdir("new_directory")

# %% [markdown]
# os.listdir(path): Lists all files and directories in the specified path.

# %%
print(os.listdir("."))

# %% [markdown]
# os.makedirs(path): Creates intermediate directories if they don't exist.

# %%
os.makedirs("parent/child/grandchild")

# %% [markdown]
# os.removedirs(path): Removes directories recursively.

# %%
os.removedirs("parent/child/grandchild")

# %% [markdown]
# **3. Path and Metadata Operations**
#
# os.path.exists(path): Checks if a file or directory exists.

# %%
if os.path.exists("example.txt"):
    print("File exists")

# %% [markdown]
# os.path.join(*paths): Joins multiple path components into one.

# %%
path = os.path.join("folder", "subfolder", "file.txt")
print(path)

# %% [markdown]
# os.path.isfile(path): Checks if the path is a file.

# %%
print(os.path.isfile("example.txt"))

# %% [markdown]
# os.path.isdir(path): Checks if the path is a directory.

# %%
print(os.path.isdir("folder"))

# %% [markdown]
# os.path.getsize(path): Gets the size of a file in bytes.

# %%
print(os.path.abspath("example.txt"))

# %% [markdown]
# os.path.abspath(path): Returns the absolute path of the given path

# %%
print(os.path.abspath("example.txt"))

# %% [markdown]
# **4. Current Working Directory**
#
# os.getcwd(): Gets the current working directory.

# %%
print(os.getcwd())

# %% [markdown]
# os.chdir(path): Changes the current working directory.

# %%
os.chdir("new_directory")
print(os.getcwd())

# %%
#Example: Combining Functions for File Operations
import os

# Create a directory
os.makedirs("project/files")

# Change the working directory
os.chdir("project/files")

# Create a new file
with open("example.txt", "w") as file:
    file.write("Hello, world!")

# Check file existence and get details
if os.path.exists("example.txt"):
    print("File exists")
    print(f"Size: {os.path.getsize('example.txt')} bytes")
    print(f"Absolute Path: {os.path.abspath('example.txt')}")

# Rename the file
os.rename("example.txt", "renamed_example.txt")

# Delete the file
os.remove("renamed_example.txt")

# Navigate back and remove directories
os.chdir("../..")
os.removedirs("project/files")

# %% [markdown]
# ***23.What are the challenges associated with memory mangement in python?***

# %% [markdown]
# **1. Memory Leaks**
#
# *Issue:* Memory leaks occur when objects are no longer needed but cannot be freed by the garbage collector because of lingering references.
#
# *Common Causes:*
#
# *Circular References:* Two or more objects reference each other, preventing their deallocation.
#
# *Global Variables:* Variables in the global scope that are not cleared can retain memory unnecessarily.
#
# *Incorrect Use of C Extensions:* C extensions or poorly implemented libraries can prevent proper garbage collection.
#
# *Mitigation:*
#
# Use tools like gc.collect() to manually trigger garbage collection.
# Avoid circular references by using weakref to create weak references.

# %%
class Node:
    def __init__(self):
        self.reference = None

a = Node()
b = Node()
a.reference = b
b.reference = a

# %% [markdown]
# **2. High Memory Usage**
#
# *Issue:* Python’s dynamic typing and object model consume more memory compared to lower-level languages like C or C++.
#
# **Common Causes:**
#
# Overuse of large objects, like lists, dictionaries, or strings.
#
# Inefficient data structures, such as using lists instead of array or numpy arrays for numerical computations.
#
# **Mitigation:**
# Use memory-efficient libraries like numpy or pandas for large datasets.
# Use generators instead of lists for iterables to save memory.

# %%
# Instead of this:
squares = [x**2 for x in range(1000000)]
# Use this:
squares = (x**2 for x in range(1000000))

# %% [markdown]
# **3. Fragmentation**
#
# *Issue:* Memory fragmentation occurs when the allocation and deallocation of objects lead to gaps between allocated memory blocks, wasting memory.
#
# Cause:
# Frequent creation and deletion of small objects.
#
# **Mitigation:**
# Use memory pools or libraries like pymalloc, which optimize memory allocation for small objects.
#
# **4. Garbage Collection Overhead**
#
# *Issue:* While Python’s garbage collector automates memory cleanup, its operations can introduce performance overhead, particularly for applications requiring high-speed execution.
#
# *Common Causes:*
# Excessive creation and deletion of objects.
# Large numbers of objects in the same generation of the garbage collector.
#
# **Mitigation:**
# Tune garbage collection parameters using the gc module.
# Disable garbage collection temporarily if it conflicts with performance-critical code.

# %%
import gc
gc.disable()
# Run performance-critical code here
gc.enable()

# %% [markdown]
# **5. Objects Retaining Unnecessary References**
#
# Issue: Unintentional retention of references prevents garbage collection.
#
# **Mitigation:**
#
# Explicitly delete references to objects using del if they are no longer needed.

# %%
def create_object():
    obj = [1, 2, 3]
    return obj

reference = create_object()
# `reference` holds onto the object, preventing deallocation.

# %% [markdown]
# **6. Inefficient Use of Built-In Data Structures**
#
# Issue: Choosing the wrong data structure can lead to excessive memory usage.
# Example:
# Using a list for a large number of unique elements instead of a set.
#
# **Mitigation:**
# Understand the memory characteristics of Python’s built-in data structures.
# Use appropriate data types, e.g., deque for fast insertions/deletions or frozenset for immutable sets.
#
# **7. Challenges with Multithreading**
#
# Issue: The Global Interpreter Lock (GIL) in CPython can lead to inefficiencies in memory management for multithreaded applications.
# Cause:
# Threads sharing memory can result in contention and memory overhead.
#
# *Mitigation:*
# Use multiprocessing instead of multithreading for CPU-bound tasks.
#
# **8. Debugging Memory Issues**
#
# Issue: Identifying and resolving memory issues like leaks or fragmentation can be challenging.
#
# *Mitigation:*
# Use profiling tools like:
#
# tracemalloc: Tracks memory allocations.
#
# memory_profiler: Monitors memory usage.
#
# objgraph: Identifies reference cycles and memory leaks.

# %%
import tracemalloc

tracemalloc.start()
# Your code here
print(tracemalloc.get_traced_memory())
tracemalloc.stop()

# %% [markdown]
# **9. Large Objects in Memory**
#
# Issue: Large objects (e.g., data frames, matrices, images) can lead to memory exhaustion.
# Mitigation:
# Break large objects into smaller chunks.
# Use in-place operations where possible to save memory.
#
# **10. Memory Overhead of Python Objects**
#
# Issue: Each Python object has additional overhead for metadata like reference count and type information.
# Cause: Python’s dynamic nature requires every object to store extra information.
#
# *Mitigation:*
#
# Use lower-level libraries like cython for performance-critical tasks.
# For repetitive data, use data structures like array or numpy arrays, which have less overhead.

# %% [markdown]
# ***24.How do you raise an exception manually in python ?***

# %% [markdown]
# In Python, you can manually raise an exception using the raise statement. Here's the syntax and examples to demonstrate this:
#
# Syntax

# %%
raise ExceptionType("Error message")

# %%
#Example 1: Raising a general exception
raise Exception("This is a general exception.")

# %%
#Example 2: Raising a specific exception
#You can raise specific built-in exception types, like ValueError, TypeError, etc.
raise ValueError("Invalid value provided!")

# %%
#Example 3: Raising custom exceptions
#You can define your own exception class and then raise it.
class MyCustomError(Exception):
    pass

raise MyCustomError("This is a custom exception!")

# %%
#Example 4: Raising exceptions conditionally
x = -1
if x < 0:
    raise ValueError("x cannot be negative!")

# %% [markdown]
# ***25.Why is it important to use multithreading in certain applications?***

# %% [markdown]
# **1. Improved Responsiveness**
#
# Scenario: Applications with user interfaces (e.g., GUIs, mobile apps).
#
# Reason: Multithreading ensures that time-consuming tasks (e.g., file I/O, network requests) don't block the main thread. For instance, a user can continue interacting with the app while background operations execute.
# **2. Better Resource Utilization**
#
# *Scenario:* Systems with multiple CPU cores.
#
# Reason: Multithreading allows tasks to run in parallel on multiple cores, leveraging the full processing power of modern CPUs. This is especially useful in compute-intensive tasks like simulations, image processing, or data analysis.
#
# **3. Faster Execution Through Concurrency**
#
# Scenario: Applications involving I/O-bound tasks.
#
# Reason: Threads waiting for external resources (e.g., disk read/write, network) can release the CPU to other threads, maximizing throughput and reducing idle time.
#
# **4. Simplified Program Structure**
#
# Scenario: Real-time systems or systems with asynchronous tasks.
#
# Reason: Multithreading simplifies programming for scenarios requiring periodic updates or simultaneous tasks (e.g., monitoring, real-time data streams, sensor handling).
#
# **5. Handling Multiple Connections in Networking**
#
# Scenario: Servers and network applications.
#
# Reason: Multithreading enables handling multiple client connections simultaneously, ensuring high availability and responsiveness (e.g., web servers, chat applications).
#
# **6. Parallelizing Independent Tasks**
#
# Scenario: Applications like batch processing or game engines.
#
# Reason: Independent tasks (e.g., physics simulation, rendering, AI in games) can execute in separate threads, improving overall performance.
#
# **7. Avoiding Bottlenecks in Long Operations**
#
# Scenario: Data processing pipelines.
#
# Reason: Tasks like downloading, parsing, and storing data can run in parallel threads, reducing overall runtime.
# Challenges to Consider
#
# Thread Safety: Ensuring correct shared resource access requires synchronization mechanisms (e.g., locks, semaphores).
#
# Overhead: Context switching between threads can introduce performance overhead.
#
# Complexity: Debugging and maintaining multithreaded programs can be more challenging.

# %% [markdown]
# ***1.How can you open a file for writing in python and write a string to it ?***

# %% [markdown]
# In Python, you can open a file for writing and write a string to it using the open() function and the write() method. Here's how you can do it:
#
# Syntax
#
#     with open("filename.txt", "w") as file:
#           file.write("Your string here")
#
# Steps Explained
#
# *Open the File:* Use the open() function with the mode "w" (write mode). If the file doesn't exist, it will be created. If it exists, its contents will be overwritten.
#
# *Write to the File:* Use the write() method to write a string to the file.
#
# *Close the File:* Using the with statement ensures the file is automatically closed after the block of code executes.

# %%
# Open the file in write mode
with open("example.txt", "w") as file:
    # Write a string to the file
    file.write("Hello, World!")

print("String written to file successfully.")
# Out:
# String written to file successfully.

# %% [markdown]
# ***2.Write a python program to read the contents of a file and print each line.***

# %%
# Open the file in read mode
with open("example.txt", "r") as file:
    # Read and print each line
    for line in file:
        print(line.strip())  # Use .strip() to remove leading/trailing whitespace, including newlines
# Out:
# Hello, World!

# %% [markdown]
# ***3.How would you handle a case where the file doesn't exist while trying to open it for reading?***

# %%
filename = "nonexistent_file.txt"

try:
    with open(filename, "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist. Please check the file path and try again.")
# Out:
# Error: The file 'nonexistent_file.txt' does not exist. Please check the file path and try again.

# %%
#Alternative: Check File Existence Before Opening
#You can use the os.path.exists() function to check if the file exists before attempting to open it:
import os

filename = "nonexistent_file.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        for line in file:
            print(line.strip())
else:
    print(f"Error: The file '{filename}' does not exist.")

# %% [markdown]
# ***4.Write a python script that reads from one file and writes its content to another file.***

# %%
# Specify the source and destination file paths
source_file = "source.txt"
destination_file = "destination.txt"

try:
    # Open the source file for reading
    with open(source_file, "r") as src:
        # Read the contents of the source file
        content = src.read()

    # Open the destination file for writing
    with open(destination_file, "w") as dest:
        # Write the content to the destination file
        dest.write(content)

    print(f"Content successfully copied from '{source_file}' to '{destination_file}'.")
except FileNotFoundError:
    print(f"Error: The file '{source_file}' does not exist. Please check the file path.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# Error: The file 'source.txt' does not exist. Please check the file path.

# %% [markdown]
# ***5.How would you catch and handle division by zero error in python?***

# %%
try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    result = numerator / denominator
    print(f"The result is: {result}")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter valid numeric values.")
# Out:
# Enter numerator: 10
# Enter denominator: 2
# The result is: 5.0

# %% [markdown]
# ***6.Write a python program that logs an error message to a log file when a division by zero exception occurs.***

# %%
import logging

# Configure logging
logging.basicConfig(
    filename="error_log.txt",  # Log file name
    level=logging.ERROR,       # Log level
    format="%(asctime)s - %(levelname)s - %(message)s"  # Log message format
)

def divide_numbers(numerator, denominator):
    try:
        result = numerator / denominator
        print(f"The result is: {result}")
    except ZeroDivisionError as e:
        error_message = "Error: Division by zero occurred."
        print(error_message)
        logging.error(error_message)  # Log the error to the log file

# Example usage
try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    divide_numbers(numerator, denominator)
except ValueError:
    print("Error: Please enter valid numeric values.")
    logging.error("Error: Non-numeric input provided.")
# Out:
# Enter numerator: 5
# Enter denominator: 2
# The result is: 2.5

# %% [markdown]
# ***7.How do you log information at different levels (INFO,ERROR,WARNING) in python using the logging module?***

# %%
#Basic Setup for Logging
import logging

# Configure the logging system
logging.basicConfig(
    filename="app.log",         # Log file name
    level=logging.DEBUG,        # Minimum log level to capture
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
#Logging Messages at Different Levels
# Log messages at various levels
logging.debug("This is a DEBUG message.")
logging.info("This is an INFO message.")
logging.warning("This is a WARNING message.")
logging.error("This is an ERROR message.")
logging.critical("This is a CRITICAL message.")
# Out:
# WARNING:root:This is a WARNING message.
# ERROR:root:This is an ERROR message.
# CRITICAL:root:This is a CRITICAL message.

# %%
#Adding Console Output (Optional)
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console_handler.setFormatter(formatter)

# Add the console handler to the root logger
logging.getLogger().addHandler(console_handler)

# %% [markdown]
# ***8.Write a program to handle to handle a file  opening error using exception handling.***

# %%
def read_file(filename):
    try:
        # Attempt to open the file
        with open(filename, 'r') as file:
            # Read and print the file content
            content = file.read()
            print("File Content:")
            print(content)
    except FileNotFoundError:
        # Handle the case where the file does not exist
        print(f"Error: The file '{filename}' was not found.")
    except PermissionError:
        # Handle the case where the file cannot be accessed due to permissions
        print(f"Error: You do not have permission to access '{filename}'.")
    except Exception as e:
        # Handle any other exception
        print(f"An unexpected error occurred: {e}")

# Test the function
filename = input("Enter the filename to open: ")
read_file(filename)

# %% [markdown]
# ***9.How can you read line by line and store its content in a list in python?***

# %%
def read_lines_to_list(filename):
    try:
        # Open the file and read lines
        with open(filename, 'r') as file:
            lines = file.readlines()  # Reads all lines and stores them in a list
        return lines
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
        return []
    except PermissionError:
        print(f"Error: You do not have permission to access '{filename}'.")
        return []
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return []

# Test the function
filename = input("Enter the filename to open: ")
lines = read_lines_to_list(filename)

if lines:  # Check if the list is not empty
    print("File Content as a List:")
    print(lines)
# Out:
# Enter the filename to open: line 1
# Error: The file 'line 1' was not found.

# %% [markdown]
# ***10.How can you append data to an existing file in python?***

# %%
def append_to_file(filename, data):
    try:
        # Open the file in append mode
        with open(filename, 'a') as file:
            file.write(data + '\n')  # Add data with a newline at the end
        print(f"Data successfully appended to '{filename}'.")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except PermissionError:
        print(f"Error: You do not have permission to write to '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Test the function
filename = input("Enter the filename to append to: ")
data = input("Enter the data to append: ")
append_to_file(filename, data)
# Out:
# Enter the filename to append to: sr.txt
# Enter the data to append: line 3
# Data successfully appended to 'sr.txt'.

# %% [markdown]
# ***11.Write a python program that uses a try-except block to handle an error when attempting to access a dictionary key that does not exsist.***

# %%
def access_dictionary_key(dictionary, key):
    try:
        # Attempt to access the dictionary key
        value = dictionary[key]
        print(f"Value for key '{key}': {value}")
    except KeyError:
        # Handle the case where the key does not exist
        print(f"Error: The key '{key}' does not exist in the dictionary.")

# Test the function
sample_dict = {"name": "Alice", "age": 25, "city": "New York"}
print("Sample Dictionary:", sample_dict)

key_to_access = input("Enter the key to access: ")
access_dictionary_key(sample_dict, key_to_access)
# Out:
# Sample Dictionary: {'name': 'Alice', 'age': 25, 'city': 'New York'}
# Enter the key to access: country
# Error: The key 'country' does not exist in the dictionary.

# %% [markdown]
# ***12.Write a program that demonstrate using multiple except blocks to handle different types of exceptions.***

# %%
def demonstrate_exceptions():
    try:
        # Ask the user for two inputs
        num1 = int(input("Enter the first number: "))
        num2 = int(input("Enter the second number: "))

        # Attempt to divide the numbers
        result = num1 / num2
        print(f"Result: {result}")

        # Access a list element
        sample_list = [10, 20, 30]
        index = int(input("Enter the index to access (0-2): "))
        print(f"Element at index {index}: {sample_list[index]}")

    except ValueError:
        # Handle invalid input that cannot be converted to an integer
        print("Error: Invalid input. Please enter an integer.")
    except ZeroDivisionError:
        # Handle division by zero
        print("Error: Division by zero is not allowed.")
    except IndexError:
        # Handle invalid index access
        print("Error: Index out of range. Please enter a valid index (0-2).")
    except Exception as e:
        # Handle any other unexpected exception
        print(f"An unexpected error occurred: {e}")

# Run the program
demonstrate_exceptions()
# Out:
# Enter the first number: 10
# Enter the second number: 2
# Result: 5.0
# Enter the index to access (0-2): 2
# Element at index 2: 30

# %% [markdown]
# ***13.How would you check if a file exsists before attemting to read it in python?***

# %%
#Using os.path.exists()
import os

filename = input("Enter the filename to check: ")

if os.path.exists(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print("File Content:")
            print(content)
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Enter the filename to check: sr.txt
# File Content:
# line 3

# %%
#Using pathlib.Path.exists()
from pathlib import Path

filename = input("Enter the filename to check: ")
file_path = Path(filename)

if file_path.exists():
    try:
        with file_path.open('r') as file:
            content = file.read()
            print("File Content:")
            print(content)
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Enter the filename to check: ert.txt
# Error: The file 'ert.txt' does not exist.

# %% [markdown]
# ***14.Write a program uses thev logging module to log both informational and error messges.***

# %%
import logging

# Configure the logging module
logging.basicConfig(
    filename='app.log',  # Log file name
    level=logging.DEBUG,  # Set logging level
    format='%(asctime)s - %(levelname)s - %(message)s'  # Log message format
)

def divide_numbers(num1, num2):
    """Divides two numbers and logs the operation."""
    try:
        logging.info(f"Attempting to divide {num1} by {num2}.")
        result = num1 / num2
        logging.info(f"Division successful: {num1} / {num2} = {result}")
        return result
    except ZeroDivisionError:
        logging.error("Division by zero attempted.")
        return None
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")
        return None

# Main program
logging.info("Program started.")

try:
    num1 = float(input("Enter the first number: "))
    num2 = float(input("Enter the second number: "))
    result = divide_numbers(num1, num2)
    if result is not None:
        print(f"Result: {result}")
    else:
        print("An error occurred during division.")
except ValueError:
    logging.error("Invalid input. Non-numeric value entered.")
    print("Error: Please enter numeric values.")

logging.info("Program ended.")
# Out:
# Enter the first number: 0
# Enter the second number: 10
# Result: 0.0

# %% [markdown]
# ***15.Write a python program that prints  the content of a files and handles  the case when the file is empty.***

# %%
def print_file_content(filename):
    try:
        # Open the file in read mode
        with open(filename, 'r') as file:
            content = file.read()

            if content.strip():  # Check if content is not empty
                print("File Content:")
                print(content)
            else:
                print(f"The file '{filename}' is empty.")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except PermissionError:
        print(f"Error: You do not have permission to access '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Test the function
filename = input("Enter the filename to open: ")
print_file_content(filename)
# Out:
# Enter the filename to open: empty.txt
# Error: The file 'empty.txt' does not exist.

# %% [markdown]
# ***16.Demonstrate how to use memory profiling to check the memoru usage of a small program.***

# %%
#Step 1: Install memory_profiler
# !pip install memory_profiler
# !python -m memory_profiler your_program.py
from memory_profiler import profile

@profile
def create_large_list():
    # Allocate a large list
    large_list = [x ** 2 for x in range(100000)]
    print("List created.")
    return large_list

if __name__ == "__main__":
    create_large_list()
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.10/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from memory_profiler) (5.9.5)
# Could not find script your_program.py
# ERROR: Could not find file <ipython-input-21-b7a5dce3713e>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# List created.

# %% [markdown]
# ***17.Write a python program  to create and write a list of numbers to a file, one number  per line.***

# %%
def write_numbers_to_file(filename, numbers):
    try:
        # Open the file in write mode
        with open(filename, 'w') as file:
            for number in numbers:
                file.write(f"{number}\n")  # Write each number followed by a newline
        print(f"Numbers successfully written to '{filename}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
numbers = [1, 2, 3, 4, 5, 10, 20, 30]
filename = "numbers.txt"

write_numbers_to_file(filename, numbers)
# Out:
# Numbers successfully written to 'numbers.txt'.

# %% [markdown]
# ***18.How would you implement a basic logging setup that logs to a file with rotation  after 1MB ?***

# %%
import logging
from logging.handlers import RotatingFileHandler

# Define log file path and maximum size (in bytes)
log_file_path = "app.log"
max_log_size = 1 * 1024 * 1024  # 1 MB
backup_count = 5  # Number of backup files to keep

# Create a logger
logger = logging.getLogger("MyAppLogger")
logger.setLevel(logging.DEBUG)  # Set the log level (DEBUG, INFO, WARNING, etc.)

# Create a rotating file handler
rotating_handler = RotatingFileHandler(
    log_file_path, maxBytes=max_log_size, backupCount=backup_count
)
rotating_handler.setLevel(logging.DEBUG)

# Define a log message format
formatter = logging.Formatter(
    "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)
rotating_handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(rotating_handler)

# Example logging messages
logger.debug("This is a debug message.")
logger.info("This is an info message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")
logger.critical("This is a critical message.")

# Simulate more logs to trigger rotation
for i in range(10000):
    logger.info(f"Log entry {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyAppLogger:Log entry 5000
# INFO:MyAppLogger:Log entry 5001
# INFO:MyAppLogger:Log entry 5002
# INFO:MyAppLogger:Log entry 5003
# INFO:MyAppLogger:Log entry 5004
# INFO:MyAppLogger:Log entry 5005
# INFO:MyAppLogger:Log entry 5006
# INFO:MyAppLogger:Log entry 5007
# INFO:MyAppLogger:Log entry 5008
# INFO:MyAppLogger:Log entry 5009
# INFO:MyAppLogger:Log entry 5010
# INFO:MyAppLogger:Log entry 5011
# INFO:MyAppLogger:Log entry 5012
# INFO:MyAppLogger:Log entry 5013
# INFO:MyAppLogger:Log entry 5014
# INFO:MyAppLogger:Log entry 5015
# INFO:MyAppLogger:Log entry 5016
# INFO:MyAppLogger:Log entry 5017
# INFO:MyAppLogger:Log entry 5018
# INFO:MyAppLogger:Log entry 5019
# INFO:MyAppLogger:Log entry 5020
# INFO:MyAppLogger:Log entry 5021
# INFO:MyAppLogger:Log entry 5022
# INFO:MyAppLogger:Log entry 5023
# INFO:MyAppLogger:Log entry 5024
# INFO:MyAppLogger:Log entry 5025
# INFO:MyAppLogger:Log entry 5026
# INFO:MyAppLogger:Log entry 5027
# INFO:MyAppLogger:Log entry 5028
# INFO:MyAppLogger:Log entry 5029
# INFO:MyAppLogger:Log entry 5030
# INFO:MyAppLogger:Log entry 5031
# INFO:MyAppLogger:Log entry 5032
# INFO:MyAppLogger:Log entry 5033
# INFO:MyAppLogger:Log entry 5034
# INFO:MyAppLogger:Log entry 5035
# INFO:MyAppLogger:Log entry 5036
# INFO:MyAppLogger:Log entry 5037
# INFO:MyAppLogger:Log entry 5038
# INFO:MyAppLogger:Log entry 5039
# INFO:MyAppLogger:Log entry 5040
# INFO:MyAppLogger:Log entry 5041
# INFO:MyAppLogger:Log entry 5042
# INFO:MyAppLogger:Log entry 5043
# INFO:MyAppLogger:Log entry 5044
# INFO:MyAppLogger:Log entry 5045
# INFO:MyAppLogger:Log entry 5046
# INFO:MyAppLogger:Log entry 5047
# INFO:MyAppLogger:Log entry 5048
# INFO:MyAppLogger:Log entry 5049
# INFO:MyAppLogger:Log entry 5050
# INFO:MyAppLogger:Log entry 5051
# INFO:MyAppLogger:Log entry 5052
# INFO:MyAppLogger:Log entry 5053
# INFO:MyAppLogger:Log entry 5054
# INFO:MyAppLogger:Log entry 5055
# INFO:MyAppLogger:Log entry 5056
# INFO:MyAppLogger:Log entry 5057
# INFO:MyAppLogger:Log entry 5058
# INFO:MyAppLogger:Log entry 5059
# INFO:MyAppLogger:Log entry 5060
# INFO:MyAppLogger:Log entry 5061
# INFO:MyAppLogger:Log entry 5062
# INFO:MyAppLogger:Log entry 5063
# INFO:MyAppLogger:Log entry 5064
# INFO:MyAppLogger:Log entry 5065
# INFO:MyAppLogger:Log entry 5066
# INFO:MyAppLogger:Log entry 5067
# INFO:MyAppLogger:Log entry 5068
# INFO:MyAppLogger:Log entry 5069
# INFO:MyAppLogger:Log entry 5070
# INFO:MyAppLogger:Log entry 5071
# INFO:MyAppLogger:Log entry 5072
# INFO:MyAppLogger:Log entry 5073
# INFO:MyAppLogger:Log entry 5074
# INFO:MyAppLogger:Log entry 5075
# INFO:MyAppLogger:Log entry 5076
# INFO:MyAppLogger:Log entry 5077
# INFO:MyAppLogger:Log entry 5078
# INFO:MyAppLogger:Log entry 5079
# INFO:MyAppLogger:Log entry 5080
# INFO:MyAppLogger:Log entry 5081
# INFO:MyAppLogger:Log entry 5082
# INFO:MyAppLogger:Log entry 5083
# INFO:MyAppLogger:Log entry 5084
# INFO:MyAppLogger:Log entry 5085
# INFO:MyAppLogger:Log entry 5086
# INFO:MyAppLogger:Log entry 5087
# INFO:MyAppLogger:Log entry 5088
# INFO:MyAppLogger:Log entry 5089
# INFO:MyAppLogger:Log entry 5090
# INFO:MyAppLogger:Log entry 5091
# INFO:MyAppLogger:Log entry 5092
# INFO:MyAppLogger:Log entry 5093
# INFO:MyAppLogger:Log entry 5094
# INFO:MyAppLogger:Log entry 5095
# INFO:MyAppLogger:Log entry 5096
# INFO:MyAppLogger:Log entry 5097
# INFO:MyAppLogger:Log entry 5098
# INFO:MyAppLogger:Log entry 5099
# INFO:MyAppLogger:Log entry 5100
# INFO:MyAppLogger:Log entry 5101
# INFO:MyAppLogger:Log entry 5102
# INFO:MyAppLogger:Log entry 5103
# INFO:MyAppLogger:Log entry 5104
# INFO:MyAppLogger:Log entry 5105
# INFO:MyAppLogger:Log entry 5106
# INFO:MyAppLogger:Log entry 5107
# INFO:MyAppLogger:Log entry 5108
# INFO:MyAppLogger:Log entry 5109
# INFO:MyAppLogger:Log entry 5110
# INFO:MyAppLogger:Log entry 5111
# INFO:MyAppLogger:Log entry 5112
# INFO:MyAppLogger:Log entry 5113
# INFO:MyAppLogger:Log entry 5114
# INFO:MyAppLogger:Log entry 5115
# INFO:MyAppLogger:Log entry 5116
# INFO:MyAppLogger:Log entry 5117
# INFO:MyAppLogger:Log entry 5118
# INFO:MyAppLogger:Log entry 5119
# INFO:MyAppLogger:Log entry 5120
# INFO:MyAppLogger:Log entry 5121
# INFO:MyAppLogger:Log entry 5122
# INFO:MyAppLogger:Log entry 5123
# INFO:MyAppLogger:Log entry 5124
# INFO:MyAppLogger:Log entry 5125
# INFO:MyAppLogger:Log entry 5126
# INFO:MyAppLogger:Log entry 5127
# INFO:MyAppLogger:Log entry 5128
# INFO:MyAppLogger:Log entry 5129
# INFO:MyAppLogger:Log entry 5130
# INFO:MyAppLogger:Log entry 5131
# INFO:MyAppLogger:Log entry 5132
# INFO:MyAppLogger:Log entry 5133
# INFO:MyAppLogger:Log entry 5134
# INFO:MyAppLogger:Log entry 5135
# INFO:MyAppLogger:Log entry 5136
# INFO:MyAppLogger:Log entry 5137
# INFO:MyAppLogger:Log entry 5138
# INFO:MyAppLogger:Log entry 5139
# INFO:MyAppLogger:Log entry 5140
# INFO:MyAppLogger:Log entry 5141
# INFO:MyAppLogger:Log entry 5142
# INFO:MyAppLogger:Log entry 5143
# INFO:MyAppLogger:Log entry 5144
# INFO:MyAppLogger:Log entry 5145
# INFO:MyAppLogger:Log entry 5146
# INFO:MyAppLogger:Log entry 5147
# INFO:MyAppLogger:Log entry 5148
# INFO:MyAppLogger:Log entry 5149
# INFO:MyAppLogger:Log entry 5150
# INFO:MyAppLogger:Log entry 5151
# INFO:MyAppLogger:Log entry 5152
# INFO:MyAppLogger:Log entry 5153
# INFO:MyAppLogger:Log entry 5154
# INFO:MyAppLogger:Log entry 5155
# INFO:MyAppLogger:Log entry 5156
# INFO:MyAppLogger:Log entry 5157
# INFO:MyAppLogger:Log entry 5158
# INFO:MyAppLogger:Log entry 5159
# INFO:MyAppLogger:Log entry 5160
# INFO:MyAppLogger:Log entry 5161
# INFO:MyAppLogger:Log entry 5162
# INFO:MyAppLogger:Log entry 5163
# INFO:MyAppLogger:Log entry 5164
# INFO:MyAppLogger:Log entry 5165
# INFO:MyAppLogger:Log entry 5166
# INFO:MyAppLogger:Log entry 5167
# INFO:MyAppLogger:Log entry 5168
# INFO:MyAppLogger:Log entry 5169
# INFO:MyAppLogger:Log entry 5170
# INFO:MyAppLogger:Log entry 5171
# INFO:MyAppLogger:Log entry 5172
# INFO:MyAppLogger:Log entry 5173
# INFO:MyAppLogger:Log entry 5174
# INFO:MyAppLogger:Log entry 5175
# INFO:MyAppLogger:Log entry 5176
# INFO:MyAppLogger:Log entry 5177
# INFO:MyAppLogger:Log entry 5178
# INFO:MyAppLogger:Log entry 5179
# INFO:MyAppLogger:Log entry 5180
# INFO:MyAppLogger:Log entry 5181
# INFO:MyAppLogger:Log entry 5182
# INFO:MyAppLogger:Log entry 5183
# INFO:MyAppLogger:Log entry 5184
# INFO:MyAppLogger:Log entry 5185
# INFO:MyAppLogger:Log entry 5186
# INFO:MyAppLogger:Log entry 5187
# INFO:MyAppLogger:Log entry 5188
# INFO:MyAppLogger:Log entry 5189
# INFO:MyAppLogger:Log entry 5190
# INFO:MyAppLogger:Log entry 5191
# INFO:MyAppLogger:Log entry 5192
# INFO:MyAppLogger:Log entry 5193
# INFO:MyAppLogger:Log entry 5194
# INFO:MyAppLogger:Log entry 5195
# INFO:MyAppLogger:Log entry 5196
# INFO:MyAppLogger:Log entry 5197
# INFO:MyAppLogger:Log entry 5198
# INFO:MyAppLogger:Log entry 5199
# INFO:MyAppLogger:Log entry 5200
# INFO:MyAppLogger:Log entry 5201
# INFO:MyAppLogger:Log entry 5202
# INFO:MyAppLogger:Log entry 5203
# INFO:MyAppLogger:Log entry 5204
# INFO:MyAppLogger:Log entry 5205
# INFO:MyAppLogger:Log entry 5206
# INFO:MyAppLogger:Log entry 5207
# INFO:MyAppLogger:Log entry 5208
# INFO:MyAppLogger:Log entry 5209
# INFO:MyAppLogger:Log entry 5210
# INFO:MyAppLogger:Log entry 5211
# INFO:MyAppLogger:Log entry 5212
# INFO:MyAppLogger:Log entry 5213
# INFO:MyAppLogger:Log entry 5214
# INFO:MyAppLogger:Log entry 5215
# INFO:MyAppLogger:Log entry 5216
# INFO:MyAppLogger:Log entry 5217
# INFO:MyAppLogger:Log entry 5218
# INFO:MyAppLogger:Log entry 5219
# INFO:MyAppLogger:Log entry 5220
# INFO:MyAppLogger:Log entry 5221
# INFO:MyAppLogger:Log entry 5222
# INFO:MyAppLogger:Log entry 5223
# INFO:MyAppLogger:Log entry 5224
# INFO:MyAppLogger:Log entry 5225
# INFO:MyAppLogger:Log entry 5226
# INFO:MyAppLogger:Log entry 5227
# INFO:MyAppLogger:Log entry 5228
# INFO:MyAppLogger:Log entry 5229
# INFO:MyAppLogger:Log entry 5230
# INFO:MyAppLogger:Log entry 5231
# INFO:MyAppLogger:Log entry 5232
# INFO:MyAppLogger:Log entry 5233
# INFO:MyAppLogger:Log entry 5234
# INFO:MyAppLogger:Log entry 5235
# INFO:MyAppLogger:Log entry 5236
# INFO:MyAppLogger:Log entry 5237
# INFO:MyAppLogger:Log entry 5238
# INFO:MyAppLogger:Log entry 5239
# INFO:MyAppLogger:Log entry 5240
# INFO:MyAppLogger:Log entry 5241
# INFO:MyAppLogger:Log entry 5242
# INFO:MyAppLogger:Log entry 5243
# INFO:MyAppLogger:Log entry 5244
# INFO:MyAppLogger:Log entry 5245
# INFO:MyAppLogger:Log entry 5246
# INFO:MyAppLogger:Log entry 5247
# INFO:MyAppLogger:Log entry 5248
# INFO:MyAppLogger:Log entry 5249
# INFO:MyAppLogger:Log entry 5250
# INFO:MyAppLogger:Log entry 5251
# INFO:MyAppLogger:Log entry 5252
# INFO:MyAppLogger:Log entry 5253
# INFO:MyAppLogger:Log entry 5254
# INFO:MyAppLogger:Log entry 5255
# INFO:MyAppLogger:Log entry 5256
# INFO:MyAppLogger:Log entry 5257
# INFO:MyAppLogger:Log entry 5258
# INFO:MyAppLogger:Log entry 5259
# INFO:MyAppLogger:Log entry 5260
# INFO:MyAppLogger:Log entry 5261
# INFO:MyAppLogger:Log entry 5262
# INFO:MyAppLogger:Log entry 5263
# INFO:MyAppLogger:Log entry 5264
# INFO:MyAppLogger:Log entry 5265
# INFO:MyAppLogger:Log entry 5266
# INFO:MyAppLogger:Log entry 5267
# INFO:MyAppLogger:Log entry 5268
# INFO:MyAppLogger:Log entry 5269
# INFO:MyAppLogger:Log entry 5270
# INFO:MyAppLogger:Log entry 5271
# INFO:MyAppLogger:Log entry 5272
# INFO:MyAppLogger:Log entry 5273
# INFO:MyAppLogger:Log entry 5274
# INFO:MyAppLogger:Log entry 5275
# INFO:MyAppLogger:Log entry 5276
# INFO:MyAppLogger:Log entry 5277
# INFO:MyAppLogger:Log entry 5278
# INFO:MyAppLogger:Log entry 5279
# INFO:MyAppLogger:Log entry 5280
# INFO:MyAppLogger:Log entry 5281
# INFO:MyAppLogger:Log entry 5282
# INFO:MyAppLogger:Log entry 5283
# INFO:MyAppLogger:Log entry 5284
# INFO:MyAppLogger:Log entry 5285
# INFO:MyAppLogger:Log entry 5286
# INFO:MyAppLogger:Log entry 5287
# INFO:MyAppLogger:Log entry 5288
# INFO:MyAppLogger:Log entry 5289
# INFO:MyAppLogger:Log entry 5290
# INFO:MyAppLogger:Log entry 5291
# INFO:MyAppLogger:Log entry 5292
# INFO:MyAppLogger:Log entry 5293
# INFO:MyAppLogger:Log entry 5294
# INFO:MyAppLogger:Log entry 5295
# INFO:MyAppLogger:Log entry 5296
# INFO:MyAppLogger:Log entry 5297
# INFO:MyAppLogger:Log entry 5298
# INFO:MyAppLogger:Log entry 5299
# INFO:MyAppLogger:Log entry 5300
# INFO:MyAppLogger:Log entry 5301
# INFO:MyAppLogger:Log entry 5302
# INFO:MyAppLogger:Log entry 5303
# INFO:MyAppLogger:Log entry 5304
# INFO:MyAppLogger:Log entry 5305
# INFO:MyAppLogger:Log entry 5306
# INFO:MyAppLogger:Log entry 5307
# INFO:MyAppLogger:Log entry 5308
# INFO:MyAppLogger:Log entry 5309
# INFO:MyAppLogger:Log entry 5310
# INFO:MyAppLogger:Log entry 5311
# INFO:MyAppLogger:Log entry 5312
# INFO:MyAppLogger:Log entry 5313
# INFO:MyAppLogger:Log entry 5314
# INFO:MyAppLogger:Log entry 5315
# INFO:MyAppLogger:Log entry 5316
# INFO:MyAppLogger:Log entry 5317
# INFO:MyAppLogger:Log entry 5318
# INFO:MyAppLogger:Log entry 5319
# INFO:MyAppLogger:Log entry 5320
# INFO:MyAppLogger:Log entry 5321
# INFO:MyAppLogger:Log entry 5322
# INFO:MyAppLogger:Log entry 5323
# INFO:MyAppLogger:Log entry 5324
# INFO:MyAppLogger:Log entry 5325
# INFO:MyAppLogger:Log entry 5326
# INFO:MyAppLogger:Log entry 5327
# INFO:MyAppLogger:Log entry 5328
# INFO:MyAppLogger:Log entry 5329
# INFO:MyAppLogger:Log entry 5330
# INFO:MyAppLogger:Log entry 5331
# INFO:MyAppLogger:Log entry 5332
# INFO:MyAppLogger:Log entry 5333
# INFO:MyAppLogger:Log entry 5334
# INFO:MyAppLogger:Log entry 5335
# INFO:MyAppLogger:Log entry 5336
# INFO:MyAppLogger:Log entry 5337
# INFO:MyAppLogger:Log entry 5338
# INFO:MyAppLogger:Log entry 5339
# INFO:MyAppLogger:Log entry 5340
# INFO:MyAppLogger:Log entry 5341
# INFO:MyAppLogger:Log entry 5342
# INFO:MyAppLogger:Log entry 5343
# INFO:MyAppLogger:Log entry 5344
# INFO:MyAppLogger:Log entry 5345
# INFO:MyAppLogger:Log entry 5346
# INFO:MyAppLogger:Log entry 5347
# INFO:MyAppLogger:Log entry 5348
# INFO:MyAppLogger:Log entry 5349
# INFO:MyAppLogger:Log entry 5350
# INFO:MyAppLogger:Log entry 5351
# INFO:MyAppLogger:Log entry 5352
# INFO:MyAppLogger:Log entry 5353
# INFO:MyAppLogger:Log entry 5354
# INFO:MyAppLogger:Log entry 5355
# INFO:MyAppLogger:Log entry 5356
# INFO:MyAppLogger:Log entry 5357
# INFO:MyAppLogger:Log entry 5358
# INFO:MyAppLogger:Log entry 5359
# INFO:MyAppLogger:Log entry 5360
# INFO:MyAppLogger:Log entry 5361
# INFO:MyAppLogger:Log entry 5362
# INFO:MyAppLogger:Log entry 5363
# INFO:MyAppLogger:Log entry 5364
# INFO:MyAppLogger:Log entry 5365
# INFO:MyAppLogger:Log entry 5366
# INFO:MyAppLogger:Log entry 5367
# INFO:MyAppLogger:Log entry 5368
# INFO:MyAppLogger:Log entry 5369
# INFO:MyAppLogger:Log entry 5370
# INFO:MyAppLogger:Log entry 5371
# INFO:MyAppLogger:Log entry 5372
# INFO:MyAppLogger:Log entry 5373
# INFO:MyAppLogger:Log entry 5374
# INFO:MyAppLogger:Log entry 5375
# INFO:MyAppLogger:Log entry 5376
# INFO:MyAppLogger:Log entry 5377
# INFO:MyAppLogger:Log entry 5378
# INFO:MyAppLogger:Log entry 5379
# INFO:MyAppLogger:Log entry 5380
# INFO:MyAppLogger:Log entry 5381
# INFO:MyAppLogger:Log entry 5382
# INFO:MyAppLogger:Log entry 5383
# INFO:MyAppLogger:Log entry 5384
# INFO:MyAppLogger:Log entry 5385
# INFO:MyAppLogger:Log entry 5386
# INFO:MyAppLogger:Log entry 5387
# INFO:MyAppLogger:Log entry 5388
# INFO:MyAppLogger:Log entry 5389
# INFO:MyAppLogger:Log entry 5390
# INFO:MyAppLogger:Log entry 5391
# INFO:MyAppLogger:Log entry 5392
# INFO:MyAppLogger:Log entry 5393
# INFO:MyAppLogger:Log entry 5394
# INFO:MyAppLogger:Log entry 5395
# INFO:MyAppLogger:Log entry 5396
# INFO:MyAppLogger:Log entry 5397
# INFO:MyAppLogger:Log entry 5398
# INFO:MyAppLogger:Log entry 5399
# INFO:MyAppLogger:Log entry 5400
# INFO:MyAppLogger:Log entry 5401
# INFO:MyAppLogger:Log entry 5402
# INFO:MyAppLogger:Log entry 5403
# INFO:MyAppLogger:Log entry 5404
# INFO:MyAppLogger:Log entry 5405
# INFO:MyAppLogger:Log entry 5406
# INFO:MyAppLogger:Log entry 5407
# INFO:MyAppLogger:Log entry 5408
# INFO:MyAppLogger:Log entry 5409
# INFO:MyAppLogger:Log entry 5410
# INFO:MyAppLogger:Log entry 5411
# INFO:MyAppLogger:Log entry 5412
# INFO:MyAppLogger:Log entry 5413
# INFO:MyAppLogger:Log entry 5414
# INFO:MyAppLogger:Log entry 5415
# INFO:MyAppLogger:Log entry 5416
# INFO:MyAppLogger:Log entry 5417
# INFO:MyAppLogger:Log entry 5418
# INFO:MyAppLogger:Log entry 5419
# INFO:MyAppLogger:Log entry 5420
# INFO:MyAppLogger:Log entry 5421
# INFO:MyAppLogger:Log entry 5422
# INFO:MyAppLogger:Log entry 5423
# INFO:MyAppLogger:Log entry 5424
# INFO:MyAppLogger:Log entry 5425
# INFO:MyAppLogger:Log entry 5426
# INFO:MyAppLogger:Log entry 5427
# INFO:MyAppLogger:Log entry 5428
# INFO:MyAppLogger:Log entry 5429
# INFO:MyAppLogger:Log entry 5430
# INFO:MyAppLogger:Log entry 5431
# INFO:MyAppLogger:Log entry 5432
# INFO:MyAppLogger:Log entry 5433
# INFO:MyAppLogger:Log entry 5434
# INFO:MyAppLogger:Log entry 5435
# INFO:MyAppLogger:Log entry 5436
# INFO:MyAppLogger:Log entry 5437
# INFO:MyAppLogger:Log entry 5438
# INFO:MyAppLogger:Log entry 5439
# INFO:MyAppLogger:Log entry 5440
# INFO:MyAppLogger:Log entry 5441
# INFO:MyAppLogger:Log entry 5442
# INFO:MyAppLogger:Log entry 5443
# INFO:MyAppLogger:Log entry 5444
# INFO:MyAppLogger:Log entry 5445
# INFO:MyAppLogger:Log entry 5446
# INFO:MyAppLogger:Log entry 5447
# INFO:MyAppLogger:Log entry 5448
# INFO:MyAppLogger:Log entry 5449
# INFO:MyAppLogger:Log entry 5450
# INFO:MyAppLogger:Log entry 5451
# INFO:MyAppLogger:Log entry 5452
# INFO:MyAppLogger:Log entry 5453
# INFO:MyAppLogger:Log entry 5454
# INFO:MyAppLogger:Log entry 5455
# INFO:MyAppLogger:Log entry 5456
# INFO:MyAppLogger:Log entry 5457
# INFO:MyAppLogger:Log entry 5458
# INFO:MyAppLogger:Log entry 5459
# INFO:MyAppLogger:Log entry 5460
# INFO:MyAppLogger:Log entry 5461
# INFO:MyAppLogger:Log entry 5462
# INFO:MyAppLogger:Log entry 5463
# INFO:MyAppLogger:Log entry 5464
# INFO:MyAppLogger:Log entry 5465
# INFO:MyAppLogger:Log entry 5466
# INFO:MyAppLogger:Log entry 5467
# INFO:MyAppLogger:Log entry 5468
# INFO:MyAppLogger:Log entry 5469
# INFO:MyAppLogger:Log entry 5470
# INFO:MyAppLogger:Log entry 5471
# INFO:MyAppLogger:Log entry 5472
# INFO:MyAppLogger:Log entry 5473
# INFO:MyAppLogger:Log entry 5474
# INFO:MyAppLogger:Log entry 5475
# INFO:MyAppLogger:Log entry 5476
# INFO:MyAppLogger:Log entry 5477
# INFO:MyAppLogger:Log entry 5478
# INFO:MyAppLogger:Log entry 5479
# INFO:MyAppLogger:Log entry 5480
# INFO:MyAppLogger:Log entry 5481
# INFO:MyAppLogger:Log entry 5482
# INFO:MyAppLogger:Log entry 5483
# INFO:MyAppLogger:Log entry 5484
# INFO:MyAppLogger:Log entry 5485
# INFO:MyAppLogger:Log entry 5486
# INFO:MyAppLogger:Log entry 5487
# INFO:MyAppLogger:Log entry 5488
# INFO:MyAppLogger:Log entry 5489
# INFO:MyAppLogger:Log entry 5490
# INFO:MyAppLogger:Log entry 5491
# INFO:MyAppLogger:Log entry 5492
# INFO:MyAppLogger:Log entry 5493
# INFO:MyAppLogger:Log entry 5494
# INFO:MyAppLogger:Log entry 5495
# INFO:MyAppLogger:Log entry 5496
# INFO:MyAppLogger:Log entry 5497
# INFO:MyAppLogger:Log entry 5498
# INFO:MyAppLogger:Log entry 5499
# INFO:MyAppLogger:Log entry 5500
# INFO:MyAppLogger:Log entry 5501
# INFO:MyAppLogger:Log entry 5502
# INFO:MyAppLogger:Log entry 5503
# INFO:MyAppLogger:Log entry 5504
# INFO:MyAppLogger:Log entry 5505
# INFO:MyAppLogger:Log entry 5506
# INFO:MyAppLogger:Log entry 5507
# INFO:MyAppLogger:Log entry 5508
# INFO:MyAppLogger:Log entry 5509
# INFO:MyAppLogger:Log entry 5510
# INFO:MyAppLogger:Log entry 5511
# INFO:MyAppLogger:Log entry 5512
# INFO:MyAppLogger:Log entry 5513
# INFO:MyAppLogger:Log entry 5514
# INFO:MyAppLogger:Log entry 5515
# INFO:MyAppLogger:Log entry 5516
# INFO:MyAppLogger:Log entry 5517
# INFO:MyAppLogger:Log entry 5518
# INFO:MyAppLogger:Log entry 5519
# INFO:MyAppLogger:Log entry 5520
# INFO:MyAppLogger:Log entry 5521
# INFO:MyAppLogger:Log entry 5522
# INFO:MyAppLogger:Log entry 5523
# INFO:MyAppLogger:Log entry 5524
# INFO:MyAppLogger:Log entry 5525
# INFO:MyAppLogger:Log entry 5526
# INFO:MyAppLogger:Log entry 5527
# INFO:MyAppLogger:Log entry 5528
# INFO:MyAppLogger:Log entry 5529
# INFO:MyAppLogger:Log entry 5530
# INFO:MyAppLogger:Log entry 5531
# INFO:MyAppLogger:Log entry 5532
# INFO:MyAppLogger:Log entry 5533
# INFO:MyAppLogger:Log entry 5534
# INFO:MyAppLogger:Log entry 5535
# INFO:MyAppLogger:Log entry 5536
# INFO:MyAppLogger:Log entry 5537
# INFO:MyAppLogger:Log entry 5538
# INFO:MyAppLogger:Log entry 5539
# INFO:MyAppLogger:Log entry 5540
# INFO:MyAppLogger:Log entry 5541
# INFO:MyAppLogger:Log entry 5542
# INFO:MyAppLogger:Log entry 5543
# INFO:MyAppLogger:Log entry 5544
# INFO:MyAppLogger:Log entry 5545
# INFO:MyAppLogger:Log entry 5546
# INFO:MyAppLogger:Log entry 5547
# INFO:MyAppLogger:Log entry 5548
# INFO:MyAppLogger:Log entry 5549
# INFO:MyAppLogger:Log entry 5550
# INFO:MyAppLogger:Log entry 5551
# INFO:MyAppLogger:Log entry 5552
# INFO:MyAppLogger:Log entry 5553
# INFO:MyAppLogger:Log entry 5554
# INFO:MyAppLogger:Log entry 5555
# INFO:MyAppLogger:Log entry 5556
# INFO:MyAppLogger:Log entry 5557
# INFO:MyAppLogger:Log entry 5558
# INFO:MyAppLogger:Log entry 5559
# INFO:MyAppLogger:Log entry 5560
# INFO:MyAppLogger:Log entry 5561
# INFO:MyAppLogger:Log entry 5562
# INFO:MyAppLogger:Log entry 5563
# INFO:MyAppLogger:Log entry 5564
# INFO:MyAppLogger:Log entry 5565
# INFO:MyAppLogger:Log entry 5566
# INFO:MyAppLogger:Log entry 5567
# INFO:MyAppLogger:Log entry 5568
# INFO:MyAppLogger:Log entry 5569
# INFO:MyAppLogger:Log entry 5570
# INFO:MyAppLogger:Log entry 5571
# INFO:MyAppLogger:Log entry 5572
# INFO:MyAppLogger:Log entry 5573
# INFO:MyAppLogger:Log entry 5574
# INFO:MyAppLogger:Log entry 5575
# INFO:MyAppLogger:Log entry 5576
# INFO:MyAppLogger:Log entry 5577
# INFO:MyAppLogger:Log entry 5578
# INFO:MyAppLogger:Log entry 5579
# INFO:MyAppLogger:Log entry 5580
# INFO:MyAppLogger:Log entry 5581
# INFO:MyAppLogger:Log entry 5582
# INFO:MyAppLogger:Log entry 5583
# INFO:MyAppLogger:Log entry 5584
# INFO:MyAppLogger:Log entry 5585
# INFO:MyAppLogger:Log entry 5586
# INFO:MyAppLogger:Log entry 5587
# INFO:MyAppLogger:Log entry 5588
# INFO:MyAppLogger:Log entry 5589
# INFO:MyAppLogger:Log entry 5590
# INFO:MyAppLogger:Log entry 5591
# INFO:MyAppLogger:Log entry 5592
# INFO:MyAppLogger:Log entry 5593
# INFO:MyAppLogger:Log entry 5594
# INFO:MyAppLogger:Log entry 5595
# INFO:MyAppLogger:Log entry 5596
# INFO:MyAppLogger:Log entry 5597
# INFO:MyAppLogger:Log entry 5598
# INFO:MyAppLogger:Log entry 5599
# INFO:MyAppLogger:Log entry 5600
# INFO:MyAppLogger:Log entry 5601
# INFO:MyAppLogger:Log entry 5602
# INFO:MyAppLogger:Log entry 5603
# INFO:MyAppLogger:Log entry 5604
# INFO:MyAppLogger:Log entry 5605
# INFO:MyAppLogger:Log entry 5606
# INFO:MyAppLogger:Log entry 5607
# INFO:MyAppLogger:Log entry 5608
# INFO:MyAppLogger:Log entry 5609
# INFO:MyAppLogger:Log entry 5610
# INFO:MyAppLogger:Log entry 5611
# INFO:MyAppLogger:Log entry 5612
# INFO:MyAppLogger:Log entry 5613
# INFO:MyAppLogger:Log entry 5614
# INFO:MyAppLogger:Log entry 5615
# INFO:MyAppLogger:Log entry 5616
# INFO:MyAppLogger:Log entry 5617
# INFO:MyAppLogger:Log entry 5618
# INFO:MyAppLogger:Log entry 5619
# INFO:MyAppLogger:Log entry 5620
# INFO:MyAppLogger:Log entry 5621
# INFO:MyAppLogger:Log entry 5622
# INFO:MyAppLogger:Log entry 5623
# INFO:MyAppLogger:Log entry 5624
# INFO:MyAppLogger:Log entry 5625
# INFO:MyAppLogger:Log entry 5626
# INFO:MyAppLogger:Log entry 5627
# INFO:MyAppLogger:Log entry 5628
# INFO:MyAppLogger:Log entry 5629
# INFO:MyAppLogger:Log entry 5630
# INFO:MyAppLogger:Log entry 5631
# INFO:MyAppLogger:Log entry 5632
# INFO:MyAppLogger:Log entry 5633
# INFO:MyAppLogger:Log entry 5634
# INFO:MyAppLogger:Log entry 5635
# INFO:MyAppLogger:Log entry 5636
# INFO:MyAppLogger:Log entry 5637
# INFO:MyAppLogger:Log entry 5638
# INFO:MyAppLogger:Log entry 5639
# INFO:MyAppLogger:Log entry 5640
# INFO:MyAppLogger:Log entry 5641
# INFO:MyAppLogger:Log entry 5642
# INFO:MyAppLogger:Log entry 5643
# INFO:MyAppLogger:Log entry 5644
# INFO:MyAppLogger:Log entry 5645
# INFO:MyAppLogger:Log entry 5646
# INFO:MyAppLogger:Log entry 5647
# INFO:MyAppLogger:Log entry 5648
# INFO:MyAppLogger:Log entry 5649
# INFO:MyAppLogger:Log entry 5650
# INFO:MyAppLogger:Log entry 5651
# INFO:MyAppLogger:Log entry 5652
# INFO:MyAppLogger:Log entry 5653
# INFO:MyAppLogger:Log entry 5654
# INFO:MyAppLogger:Log entry 5655
# INFO:MyAppLogger:Log entry 5656
# INFO:MyAppLogger:Log entry 5657
# INFO:MyAppLogger:Log entry 5658
# INFO:MyAppLogger:Log entry 5659
# INFO:MyAppLogger:Log entry 5660
# INFO:MyAppLogger:Log entry 5661
# INFO:MyAppLogger:Log entry 5662
# INFO:MyAppLogger:Log entry 5663
# INFO:MyAppLogger:Log entry 5664
# INFO:MyAppLogger:Log entry 5665
# INFO:MyAppLogger:Log entry 5666
# INFO:MyAppLogger:Log entry 5667
# INFO:MyAppLogger:Log entry 5668
# INFO:MyAppLogger:Log entry 5669
# INFO:MyAppLogger:Log entry 5670
# INFO:MyAppLogger:Log entry 5671
# INFO:MyAppLogger:Log entry 5672
# INFO:MyAppLogger:Log entry 5673
# INFO:MyAppLogger:Log entry 5674
# INFO:MyAppLogger:Log entry 5675
# INFO:MyAppLogger:Log entry 5676
# INFO:MyAppLogger:Log entry 5677
# INFO:MyAppLogger:Log entry 5678
# INFO:MyAppLogger:Log entry 5679
# INFO:MyAppLogger:Log entry 5680
# INFO:MyAppLogger:Log entry 5681
# INFO:MyAppLogger:Log entry 5682
# INFO:MyAppLogger:Log entry 5683
# INFO:MyAppLogger:Log entry 5684
# INFO:MyAppLogger:Log entry 5685
# INFO:MyAppLogger:Log entry 5686
# INFO:MyAppLogger:Log entry 5687
# INFO:MyAppLogger:Log entry 5688
# INFO:MyAppLogger:Log entry 5689
# INFO:MyAppLogger:Log entry 5690
# INFO:MyAppLogger:Log entry 5691
# INFO:MyAppLogger:Log entry 5692
# INFO:MyAppLogger:Log entry 5693
# INFO:MyAppLogger:Log entry 5694
# INFO:MyAppLogger:Log entry 5695
# INFO:MyAppLogger:Log entry 5696
# INFO:MyAppLogger:Log entry 5697
# INFO:MyAppLogger:Log entry 5698
# INFO:MyAppLogger:Log entry 5699
# INFO:MyAppLogger:Log entry 5700
# INFO:MyAppLogger:Log entry 5701
# INFO:MyAppLogger:Log entry 5702
# INFO:MyAppLogger:Log entry 5703
# INFO:MyAppLogger:Log entry 5704
# INFO:MyAppLogger:Log entry 5705
# INFO:MyAppLogger:Log entry 5706
# INFO:MyAppLogger:Log entry 5707
# INFO:MyAppLogger:Log entry 5708
# INFO:MyAppLogger:Log entry 5709
# INFO:MyAppLogger:Log entry 5710
# INFO:MyAppLogger:Log entry 5711
# INFO:MyAppLogger:Log entry 5712
# INFO:MyAppLogger:Log entry 5713
# INFO:MyAppLogger:Log entry 5714
# INFO:MyAppLogger:Log entry 5715
# INFO:MyAppLogger:Log entry 5716
# INFO:MyAppLogger:Log entry 5717
# INFO:MyAppLogger:Log entry 5718
# INFO:MyAppLogger:Log entry 5719
# INFO:MyAppLogger:Log entry 5720
# INFO:MyAppLogger:Log entry 5721
# INFO:MyAppLogger:Log entry 5722
# INFO:MyAppLogger:Log entry 5723
# INFO:MyAppLogger:Log entry 5724
# INFO:MyAppLogger:Log entry 5725
# INFO:MyAppLogger:Log entry 5726
# INFO:MyAppLogger:Log entry 5727
# INFO:MyAppLogger:Log entry 5728
# INFO:MyAppLogger:Log entry 5729
# INFO:MyAppLogger:Log entry 5730
# INFO:MyAppLogger:Log entry 5731
# INFO:MyAppLogger:Log entry 5732
# INFO:MyAppLogger:Log entry 5733
# INFO:MyAppLogger:Log entry 5734
# INFO:MyAppLogger:Log entry 5735
# INFO:MyAppLogger:Log entry 5736
# INFO:MyAppLogger:Log entry 5737
# INFO:MyAppLogger:Log entry 5738
# INFO:MyAppLogger:Log entry 5739
# INFO:MyAppLogger:Log entry 5740
# INFO:MyAppLogger:Log entry 5741
# INFO:MyAppLogger:Log entry 5742
# INFO:MyAppLogger:Log entry 5743
# INFO:MyAppLogger:Log entry 5744
# INFO:MyAppLogger:Log entry 5745
# INFO:MyAppLogger:Log entry 5746
# INFO:MyAppLogger:Log entry 5747
# INFO:MyAppLogger:Log entry 5748
# INFO:MyAppLogger:Log entry 5749
# INFO:MyAppLogger:Log entry 5750
# INFO:MyAppLogger:Log entry 5751
# INFO:MyAppLogger:Log entry 5752
# INFO:MyAppLogger:Log entry 5753
# INFO:MyAppLogger:Log entry 5754
# INFO:MyAppLogger:Log entry 5755
# INFO:MyAppLogger:Log entry 5756
# INFO:MyAppLogger:Log entry 5757
# INFO:MyAppLogger:Log entry 5758
# INFO:MyAppLogger:Log entry 5759
# INFO:MyAppLogger:Log entry 5760
# INFO:MyAppLogger:Log entry 5761
# INFO:MyAppLogger:Log entry 5762
# INFO:MyAppLogger:Log entry 5763
# INFO:MyAppLogger:Log entry 5764
# INFO:MyAppLogger:Log entry 5765
# INFO:MyAppLogger:Log entry 5766
# INFO:MyAppLogger:Log entry 5767
# INFO:MyAppLogger:Log entry 5768
# INFO:MyAppLogger:Log entry 5769
# INFO:MyAppLogger:Log entry 5770
# INFO:MyAppLogger:Log entry 5771
# INFO:MyAppLogger:Log entry 5772
# INFO:MyAppLogger:Log entry 5773
# INFO:MyAppLogger:Log entry 5774
# INFO:MyAppLogger:Log entry 5775
# INFO:MyAppLogger:Log entry 5776
# INFO:MyAppLogger:Log entry 5777
# INFO:MyAppLogger:Log entry 5778
# INFO:MyAppLogger:Log entry 5779
# INFO:MyAppLogger:Log entry 5780
# INFO:MyAppLogger:Log entry 5781
# INFO:MyAppLogger:Log entry 5782
# INFO:MyAppLogger:Log entry 5783
# INFO:MyAppLogger:Log entry 5784
# INFO:MyAppLogger:Log entry 5785
# INFO:MyAppLogger:Log entry 5786
# INFO:MyAppLogger:Log entry 5787
# INFO:MyAppLogger:Log entry 5788
# INFO:MyAppLogger:Log entry 5789
# INFO:MyAppLogger:Log entry 5790
# INFO:MyAppLogger:Log entry 5791
# INFO:MyAppLogger:Log entry 5792
# INFO:MyAppLogger:Log entry 5793
# INFO:MyAppLogger:Log entry 5794
# INFO:MyAppLogger:Log entry 5795
# INFO:MyAppLogger:Log entry 5796
# INFO:MyAppLogger:Log entry 5797
# INFO:MyAppLogger:Log entry 5798
# INFO:MyAppLogger:Log entry 5799
# INFO:MyAppLogger:Log entry 5800
# INFO:MyAppLogger:Log entry 5801
# INFO:MyAppLogger:Log entry 5802
# INFO:MyAppLogger:Log entry 5803
# INFO:MyAppLogger:Log entry 5804
# INFO:MyAppLogger:Log entry 5805
# INFO:MyAppLogger:Log entry 5806
# INFO:MyAppLogger:Log entry 5807
# INFO:MyAppLogger:Log entry 5808
# INFO:MyAppLogger:Log entry 5809
# INFO:MyAppLogger:Log entry 5810
# INFO:MyAppLogger:Log entry 5811
# INFO:MyAppLogger:Log entry 5812
# INFO:MyAppLogger:Log entry 5813
# INFO:MyAppLogger:Log entry 5814
# INFO:MyAppLogger:Log entry 5815
# INFO:MyAppLogger:Log entry 5816
# INFO:MyAppLogger:Log entry 5817
# INFO:MyAppLogger:Log entry 5818
# INFO:MyAppLogger:Log entry 5819
# INFO:MyAppLogger:Log entry 5820
# INFO:MyAppLogger:Log entry 5821
# INFO:MyAppLogger:Log entry 5822
# INFO:MyAppLogger:Log entry 5823
# INFO:MyAppLogger:Log entry 5824
# INFO:MyAppLogger:Log entry 5825
# INFO:MyAppLogger:Log entry 5826
# INFO:MyAppLogger:Log entry 5827
# INFO:MyAppLogger:Log entry 5828
# INFO:MyAppLogger:Log entry 5829
# INFO:MyAppLogger:Log entry 5830
# INFO:MyAppLogger:Log entry 5831
# INFO:MyAppLogger:Log entry 5832
# INFO:MyAppLogger:Log entry 5833
# INFO:MyAppLogger:Log entry 5834
# INFO:MyAppLogger:Log entry 5835
# INFO:MyAppLogger:Log entry 5836
# INFO:MyAppLogger:Log entry 5837
# INFO:MyAppLogger:Log entry 5838
# INFO:MyAppLogger:Log entry 5839
# INFO:MyAppLogger:Log entry 5840
# INFO:MyAppLogger:Log entry 5841
# INFO:MyAppLogger:Log entry 5842
# INFO:MyAppLogger:Log entry 5843
# INFO:MyAppLogger:Log entry 5844
# INFO:MyAppLogger:Log entry 5845
# INFO:MyAppLogger:Log entry 5846
# INFO:MyAppLogger:Log entry 5847
# INFO:MyAppLogger:Log entry 5848
# INFO:MyAppLogger:Log entry 5849
# INFO:MyAppLogger:Log entry 5850
# INFO:MyAppLogger:Log entry 5851
# INFO:MyAppLogger:Log entry 5852
# INFO:MyAppLogger:Log entry 5853
# INFO:MyAppLogger:Log entry 5854
# INFO:MyAppLogger:Log entry 5855
# INFO:MyAppLogger:Log entry 5856
# INFO:MyAppLogger:Log entry 5857
# INFO:MyAppLogger:Log entry 5858
# INFO:MyAppLogger:Log entry 5859
# INFO:MyAppLogger:Log entry 5860
# INFO:MyAppLogger:Log entry 5861
# INFO:MyAppLogger:Log entry 5862
# INFO:MyAppLogger:Log entry 5863
# INFO:MyAppLogger:Log entry 5864
# INFO:MyAppLogger:Log entry 5865
# INFO:MyAppLogger:Log entry 5866
# INFO:MyAppLogger:Log entry 5867
# INFO:MyAppLogger:Log entry 5868
# INFO:MyAppLogger:Log entry 5869
# INFO:MyAppLogger:Log entry 5870
# INFO:MyAppLogger:Log entry 5871
# INFO:MyAppLogger:Log entry 5872
# INFO:MyAppLogger:Log entry 5873
# INFO:MyAppLogger:Log entry 5874
# INFO:MyAppLogger:Log entry 5875
# INFO:MyAppLogger:Log entry 5876
# INFO:MyAppLogger:Log entry 5877
# INFO:MyAppLogger:Log entry 5878
# INFO:MyAppLogger:Log entry 5879
# INFO:MyAppLogger:Log entry 5880
# INFO:MyAppLogger:Log entry 5881
# INFO:MyAppLogger:Log entry 5882
# INFO:MyAppLogger:Log entry 5883
# INFO:MyAppLogger:Log entry 5884
# INFO:MyAppLogger:Log entry 5885
# INFO:MyAppLogger:Log entry 5886
# INFO:MyAppLogger:Log entry 5887
# INFO:MyAppLogger:Log entry 5888
# INFO:MyAppLogger:Log entry 5889
# INFO:MyAppLogger:Log entry 5890
# INFO:MyAppLogger:Log entry 5891
# INFO:MyAppLogger:Log entry 5892
# INFO:MyAppLogger:Log entry 5893
# INFO:MyAppLogger:Log entry 5894
# INFO:MyAppLogger:Log entry 5895
# INFO:MyAppLogger:Log entry 5896
# INFO:MyAppLogger:Log entry 5897
# INFO:MyAppLogger:Log entry 5898
# INFO:MyAppLogger:Log entry 5899
# INFO:MyAppLogger:Log entry 5900
# INFO:MyAppLogger:Log entry 5901
# INFO:MyAppLogger:Log entry 5902
# INFO:MyAppLogger:Log entry 5903
# INFO:MyAppLogger:Log entry 5904
# INFO:MyAppLogger:Log entry 5905
# INFO:MyAppLogger:Log entry 5906
# INFO:MyAppLogger:Log entry 5907
# INFO:MyAppLogger:Log entry 5908
# INFO:MyAppLogger:Log entry 5909
# INFO:MyAppLogger:Log entry 5910
# INFO:MyAppLogger:Log entry 5911
# INFO:MyAppLogger:Log entry 5912
# INFO:MyAppLogger:Log entry 5913
# INFO:MyAppLogger:Log entry 5914
# INFO:MyAppLogger:Log entry 5915
# INFO:MyAppLogger:Log entry 5916
# INFO:MyAppLogger:Log entry 5917
# INFO:MyAppLogger:Log entry 5918
# INFO:MyAppLogger:Log entry 5919
# INFO:MyAppLogger:Log entry 5920
# INFO:MyAppLogger:Log entry 5921
# INFO:MyAppLogger:Log entry 5922
# INFO:MyAppLogger:Log entry 5923
# INFO:MyAppLogger:Log entry 5924
# INFO:MyAppLogger:Log entry 5925
# INFO:MyAppLogger:Log entry 5926
# INFO:MyAppLogger:Log entry 5927
# INFO:MyAppLogger:Log entry 5928
# INFO:MyAppLogger:Log entry 5929
# INFO:MyAppLogger:Log entry 5930
# INFO:MyAppLogger:Log entry 5931
# INFO:MyAppLogger:Log entry 5932
# INFO:MyAppLogger:Log entry 5933
# INFO:MyAppLogger:Log entry 5934
# INFO:MyAppLogger:Log entry 5935
# INFO:MyAppLogger:Log entry 5936
# INFO:MyAppLogger:Log entry 5937
# INFO:MyAppLogger:Log entry 5938
# INFO:MyAppLogger:Log entry 5939
# INFO:MyAppLogger:Log entry 5940
# INFO:MyAppLogger:Log entry 5941
# INFO:MyAppLogger:Log entry 5942
# INFO:MyAppLogger:Log entry 5943
# INFO:MyAppLogger:Log entry 5944
# INFO:MyAppLogger:Log entry 5945
# INFO:MyAppLogger:Log entry 5946
# INFO:MyAppLogger:Log entry 5947
# INFO:MyAppLogger:Log entry 5948
# INFO:MyAppLogger:Log entry 5949
# INFO:MyAppLogger:Log entry 5950
# INFO:MyAppLogger:Log entry 5951
# INFO:MyAppLogger:Log entry 5952
# INFO:MyAppLogger:Log entry 5953
# INFO:MyAppLogger:Log entry 5954
# INFO:MyAppLogger:Log entry 5955
# INFO:MyAppLogger:Log entry 5956
# INFO:MyAppLogger:Log entry 5957
# INFO:MyAppLogger:Log entry 5958
# INFO:MyAppLogger:Log entry 5959
# INFO:MyAppLogger:Log entry 5960
# INFO:MyAppLogger:Log entry 5961
# INFO:MyAppLogger:Log entry 5962
# INFO:MyAppLogger:Log entry 5963
# INFO:MyAppLogger:Log entry 5964
# INFO:MyAppLogger:Log entry 5965
# INFO:MyAppLogger:Log entry 5966
# INFO:MyAppLogger:Log entry 5967
# INFO:MyAppLogger:Log entry 5968
# INFO:MyAppLogger:Log entry 5969
# INFO:MyAppLogger:Log entry 5970
# INFO:MyAppLogger:Log entry 5971
# INFO:MyAppLogger:Log entry 5972
# INFO:MyAppLogger:Log entry 5973
# INFO:MyAppLogger:Log entry 5974
# INFO:MyAppLogger:Log entry 5975
# INFO:MyAppLogger:Log entry 5976
# INFO:MyAppLogger:Log entry 5977
# INFO:MyAppLogger:Log entry 5978
# INFO:MyAppLogger:Log entry 5979
# INFO:MyAppLogger:Log entry 5980
# INFO:MyAppLogger:Log entry 5981
# INFO:MyAppLogger:Log entry 5982
# INFO:MyAppLogger:Log entry 5983
# INFO:MyAppLogger:Log entry 5984
# INFO:MyAppLogger:Log entry 5985
# INFO:MyAppLogger:Log entry 5986
# INFO:MyAppLogger:Log entry 5987
# INFO:MyAppLogger:Log entry 5988
# INFO:MyAppLogger:Log entry 5989
# INFO:MyAppLogger:Log entry 5990
# INFO:MyAppLogger:Log entry 5991
# INFO:MyAppLogger:Log entry 5992
# INFO:MyAppLogger:Log entry 5993
# INFO:MyAppLogger:Log entry 5994
# INFO:MyAppLogger:Log entry 5995
# INFO:MyAppLogger:Log entry 5996
# INFO:MyAppLogger:Log entry 5997
# INFO:MyAppLogger:Log entry 5998
# INFO:MyAppLogger:Log entry 5999
# INFO:MyAppLogger:Log entry 6000
# INFO:MyAppLogger:Log entry 6001
# INFO:MyAppLogger:Log entry 6002
# INFO:MyAppLogger:Log entry 6003
# INFO:MyAppLogger:Log entry 6004
# INFO:MyAppLogger:Log entry 6005
# INFO:MyAppLogger:Log entry 6006
# INFO:MyAppLogger:Log entry 6007
# INFO:MyAppLogger:Log entry 6008
# INFO:MyAppLogger:Log entry 6009
# INFO:MyAppLogger:Log entry 6010
# INFO:MyAppLogger:Log entry 6011
# INFO:MyAppLogger:Log entry 6012
# INFO:MyAppLogger:Log entry 6013
# INFO:MyAppLogger:Log entry 6014
# INFO:MyAppLogger:Log entry 6015
# INFO:MyAppLogger:Log entry 6016
# INFO:MyAppLogger:Log entry 6017
# INFO:MyAppLogger:Log entry 6018
# INFO:MyAppLogger:Log entry 6019
# INFO:MyAppLogger:Log entry 6020
# INFO:MyAppLogger:Log entry 6021
# INFO:MyAppLogger:Log entry 6022
# INFO:MyAppLogger:Log entry 6023
# INFO:MyAppLogger:Log entry 6024
# INFO:MyAppLogger:Log entry 6025
# INFO:MyAppLogger:Log entry 6026
# INFO:MyAppLogger:Log entry 6027
# INFO:MyAppLogger:Log entry 6028
# INFO:MyAppLogger:Log entry 6029
# INFO:MyAppLogger:Log entry 6030
# INFO:MyAppLogger:Log entry 6031
# INFO:MyAppLogger:Log entry 6032
# INFO:MyAppLogger:Log entry 6033
# INFO:MyAppLogger:Log entry 6034
# INFO:MyAppLogger:Log entry 6035
# INFO:MyAppLogger:Log entry 6036
# INFO:MyAppLogger:Log entry 6037
# INFO:MyAppLogger:Log entry 6038
# INFO:MyAppLogger:Log entry 6039
# INFO:MyAppLogger:Log entry 6040
# INFO:MyAppLogger:Log entry 6041
# INFO:MyAppLogger:Log entry 6042
# INFO:MyAppLogger:Log entry 6043
# INFO:MyAppLogger:Log entry 6044
# INFO:MyAppLogger:Log entry 6045
# INFO:MyAppLogger:Log entry 6046
# INFO:MyAppLogger:Log entry 6047
# INFO:MyAppLogger:Log entry 6048
# INFO:MyAppLogger:Log entry 6049
# INFO:MyAppLogger:Log entry 6050
# INFO:MyAppLogger:Log entry 6051
# INFO:MyAppLogger:Log entry 6052
# INFO:MyAppLogger:Log entry 6053
# INFO:MyAppLogger:Log entry 6054
# INFO:MyAppLogger:Log entry 6055
# INFO:MyAppLogger:Log entry 6056
# INFO:MyAppLogger:Log entry 6057
# INFO:MyAppLogger:Log entry 6058
# INFO:MyAppLogger:Log entry 6059
# INFO:MyAppLogger:Log entry 6060
# INFO:MyAppLogger:Log entry 6061
# INFO:MyAppLogger:Log entry 6062
# INFO:MyAppLogger:Log entry 6063
# INFO:MyAppLogger:Log entry 6064
# INFO:MyAppLogger:Log entry 6065
# INFO:MyAppLogger:Log entry 6066
# INFO:MyAppLogger:Log entry 6067
# INFO:MyAppLogger:Log entry 6068
# INFO:MyAppLogger:Log entry 6069
# INFO:MyAppLogger:Log entry 6070
# INFO:MyAppLogger:Log entry 6071
# INFO:MyAppLogger:Log entry 6072
# INFO:MyAppLogger:Log entry 6073
# INFO:MyAppLogger:Log entry 6074
# INFO:MyAppLogger:Log entry 6075
# INFO:MyAppLogger:Log entry 6076
# INFO:MyAppLogger:Log entry 6077
# INFO:MyAppLogger:Log entry 6078
# INFO:MyAppLogger:Log entry 6079
# INFO:MyAppLogger:Log entry 6080
# INFO:MyAppLogger:Log entry 6081
# INFO:MyAppLogger:Log entry 6082
# INFO:MyAppLogger:Log entry 6083
# INFO:MyAppLogger:Log entry 6084
# INFO:MyAppLogger:Log entry 6085
# INFO:MyAppLogger:Log entry 6086
# INFO:MyAppLogger:Log entry 6087
# INFO:MyAppLogger:Log entry 6088
# INFO:MyAppLogger:Log entry 6089
# INFO:MyAppLogger:Log entry 6090
# INFO:MyAppLogger:Log entry 6091
# INFO:MyAppLogger:Log entry 6092
# INFO:MyAppLogger:Log entry 6093
# INFO:MyAppLogger:Log entry 6094
# INFO:MyAppLogger:Log entry 6095
# INFO:MyAppLogger:Log entry 6096
# INFO:MyAppLogger:Log entry 6097
# INFO:MyAppLogger:Log entry 6098
# INFO:MyAppLogger:Log entry 6099
# INFO:MyAppLogger:Log entry 6100
# INFO:MyAppLogger:Log entry 6101
# INFO:MyAppLogger:Log entry 6102
# INFO:MyAppLogger:Log entry 6103
# INFO:MyAppLogger:Log entry 6104
# INFO:MyAppLogger:Log entry 6105
# INFO:MyAppLogger:Log entry 6106
# INFO:MyAppLogger:Log entry 6107
# INFO:MyAppLogger:Log entry 6108
# INFO:MyAppLogger:Log entry 6109
# INFO:MyAppLogger:Log entry 6110
# INFO:MyAppLogger:Log entry 6111
# INFO:MyAppLogger:Log entry 6112
# INFO:MyAppLogger:Log entry 6113
# INFO:MyAppLogger:Log entry 6114
# INFO:MyAppLogger:Log entry 6115
# INFO:MyAppLogger:Log entry 6116
# INFO:MyAppLogger:Log entry 6117
# INFO:MyAppLogger:Log entry 6118
# INFO:MyAppLogger:Log entry 6119
# INFO:MyAppLogger:Log entry 6120
# INFO:MyAppLogger:Log entry 6121
# INFO:MyAppLogger:Log entry 6122
# INFO:MyAppLogger:Log entry 6123
# INFO:MyAppLogger:Log entry 6124
# INFO:MyAppLogger:Log entry 6125
# INFO:MyAppLogger:Log entry 6126
# INFO:MyAppLogger:Log entry 6127
# INFO:MyAppLogger:Log entry 6128
# INFO:MyAppLogger:Log entry 6129
# INFO:MyAppLogger:Log entry 6130
# INFO:MyAppLogger:Log entry 6131
# INFO:MyAppLogger:Log entry 6132
# INFO:MyAppLogger:Log entry 6133
# INFO:MyAppLogger:Log entry 6134
# INFO:MyAppLogger:Log entry 6135
# INFO:MyAppLogger:Log entry 6136
# INFO:MyAppLogger:Log entry 6137
# INFO:MyAppLogger:Log entry 6138
# INFO:MyAppLogger:Log entry 6139
# INFO:MyAppLogger:Log entry 6140
# INFO:MyAppLogger:Log entry 6141
# INFO:MyAppLogger:Log entry 6142
# INFO:MyAppLogger:Log entry 6143
# INFO:MyAppLogger:Log entry 6144
# INFO:MyAppLogger:Log entry 6145
# INFO:MyAppLogger:Log entry 6146
# INFO:MyAppLogger:Log entry 6147
# INFO:MyAppLogger:Log entry 6148
# INFO:MyAppLogger:Log entry 6149
# INFO:MyAppLogger:Log entry 6150
# INFO:MyAppLogger:Log entry 6151
# INFO:MyAppLogger:Log entry 6152
# INFO:MyAppLogger:Log entry 6153
# INFO:MyAppLogger:Log entry 6154
# INFO:MyAppLogger:Log entry 6155
# INFO:MyAppLogger:Log entry 6156
# INFO:MyAppLogger:Log entry 6157
# INFO:MyAppLogger:Log entry 6158
# INFO:MyAppLogger:Log entry 6159
# INFO:MyAppLogger:Log entry 6160
# INFO:MyAppLogger:Log entry 6161
# INFO:MyAppLogger:Log entry 6162
# INFO:MyAppLogger:Log entry 6163
# INFO:MyAppLogger:Log entry 6164
# INFO:MyAppLogger:Log entry 6165
# INFO:MyAppLogger:Log entry 6166
# INFO:MyAppLogger:Log entry 6167
# INFO:MyAppLogger:Log entry 6168
# INFO:MyAppLogger:Log entry 6169
# INFO:MyAppLogger:Log entry 6170
# INFO:MyAppLogger:Log entry 6171
# INFO:MyAppLogger:Log entry 6172
# INFO:MyAppLogger:Log entry 6173
# INFO:MyAppLogger:Log entry 6174
# INFO:MyAppLogger:Log entry 6175
# INFO:MyAppLogger:Log entry 6176
# INFO:MyAppLogger:Log entry 6177
# INFO:MyAppLogger:Log entry 6178
# INFO:MyAppLogger:Log entry 6179
# INFO:MyAppLogger:Log entry 6180
# INFO:MyAppLogger:Log entry 6181
# INFO:MyAppLogger:Log entry 6182
# INFO:MyAppLogger:Log entry 6183
# INFO:MyAppLogger:Log entry 6184
# INFO:MyAppLogger:Log entry 6185
# INFO:MyAppLogger:Log entry 6186
# INFO:MyAppLogger:Log entry 6187
# INFO:MyAppLogger:Log entry 6188
# INFO:MyAppLogger:Log entry 6189
# INFO:MyAppLogger:Log entry 6190
# INFO:MyAppLogger:Log entry 6191
# INFO:MyAppLogger:Log entry 6192
# INFO:MyAppLogger:Log entry 6193
# INFO:MyAppLogger:Log entry 6194
# INFO:MyAppLogger:Log entry 6195
# INFO:MyAppLogger:Log entry 6196
# INFO:MyAppLogger:Log entry 6197
# INFO:MyAppLogger:Log entry 6198
# INFO:MyAppLogger:Log entry 6199
# INFO:MyAppLogger:Log entry 6200
# INFO:MyAppLogger:Log entry 6201
# INFO:MyAppLogger:Log entry 6202
# INFO:MyAppLogger:Log entry 6203
# INFO:MyAppLogger:Log entry 6204
# INFO:MyAppLogger:Log entry 6205
# INFO:MyAppLogger:Log entry 6206
# INFO:MyAppLogger:Log entry 6207
# INFO:MyAppLogger:Log entry 6208
# INFO:MyAppLogger:Log entry 6209
# INFO:MyAppLogger:Log entry 6210
# INFO:MyAppLogger:Log entry 6211
# INFO:MyAppLogger:Log entry 6212
# INFO:MyAppLogger:Log entry 6213
# INFO:MyAppLogger:Log entry 6214
# INFO:MyAppLogger:Log entry 6215
# INFO:MyAppLogger:Log entry 6216
# INFO:MyAppLogger:Log entry 6217
# INFO:MyAppLogger:Log entry 6218
# INFO:MyAppLogger:Log entry 6219
# INFO:MyAppLogger:Log entry 6220
# INFO:MyAppLogger:Log entry 6221
# INFO:MyAppLogger:Log entry 6222
# INFO:MyAppLogger:Log entry 6223
# INFO:MyAppLogger:Log entry 6224
# INFO:MyAppLogger:Log entry 6225
# INFO:MyAppLogger:Log entry 6226
# INFO:MyAppLogger:Log entry 6227
# INFO:MyAppLogger:Log entry 6228
# INFO:MyAppLogger:Log entry 6229
# INFO:MyAppLogger:Log entry 6230
# INFO:MyAppLogger:Log entry 6231
# INFO:MyAppLogger:Log entry 6232
# INFO:MyAppLogger:Log entry 6233
# INFO:MyAppLogger:Log entry 6234
# INFO:MyAppLogger:Log entry 6235
# INFO:MyAppLogger:Log entry 6236
# INFO:MyAppLogger:Log entry 6237
# INFO:MyAppLogger:Log entry 6238
# INFO:MyAppLogger:Log entry 6239
# INFO:MyAppLogger:Log entry 6240
# INFO:MyAppLogger:Log entry 6241
# INFO:MyAppLogger:Log entry 6242
# INFO:MyAppLogger:Log entry 6243
# INFO:MyAppLogger:Log entry 6244
# INFO:MyAppLogger:Log entry 6245
# INFO:MyAppLogger:Log entry 6246
# INFO:MyAppLogger:Log entry 6247
# INFO:MyAppLogger:Log entry 6248
# INFO:MyAppLogger:Log entry 6249
# INFO:MyAppLogger:Log entry 6250
# INFO:MyAppLogger:Log entry 6251
# INFO:MyAppLogger:Log entry 6252
# INFO:MyAppLogger:Log entry 6253
# INFO:MyAppLogger:Log entry 6254
# INFO:MyAppLogger:Log entry 6255
# INFO:MyAppLogger:Log entry 6256
# INFO:MyAppLogger:Log entry 6257
# INFO:MyAppLogger:Log entry 6258
# INFO:MyAppLogger:Log entry 6259
# INFO:MyAppLogger:Log entry 6260
# INFO:MyAppLogger:Log entry 6261
# INFO:MyAppLogger:Log entry 6262
# INFO:MyAppLogger:Log entry 6263
# INFO:MyAppLogger:Log entry 6264
# INFO:MyAppLogger:Log entry 6265
# INFO:MyAppLogger:Log entry 6266
# INFO:MyAppLogger:Log entry 6267
# INFO:MyAppLogger:Log entry 6268
# INFO:MyAppLogger:Log entry 6269
# INFO:MyAppLogger:Log entry 6270
# INFO:MyAppLogger:Log entry 6271
# INFO:MyAppLogger:Log entry 6272
# INFO:MyAppLogger:Log entry 6273
# INFO:MyAppLogger:Log entry 6274
# INFO:MyAppLogger:Log entry 6275
# INFO:MyAppLogger:Log entry 6276
# INFO:MyAppLogger:Log entry 6277
# INFO:MyAppLogger:Log entry 6278
# INFO:MyAppLogger:Log entry 6279
# INFO:MyAppLogger:Log entry 6280
# INFO:MyAppLogger:Log entry 6281
# INFO:MyAppLogger:Log entry 6282
# INFO:MyAppLogger:Log entry 6283
# INFO:MyAppLogger:Log entry 6284
# INFO:MyAppLogger:Log entry 6285
# INFO:MyAppLogger:Log entry 6286
# INFO:MyAppLogger:Log entry 6287
# INFO:MyAppLogger:Log entry 6288
# INFO:MyAppLogger:Log entry 6289
# INFO:MyAppLogger:Log entry 6290
# INFO:MyAppLogger:Log entry 6291
# INFO:MyAppLogger:Log entry 6292
# INFO:MyAppLogger:Log entry 6293
# INFO:MyAppLogger:Log entry 6294
# INFO:MyAppLogger:Log entry 6295
# INFO:MyAppLogger:Log entry 6296
# INFO:MyAppLogger:Log entry 6297
# INFO:MyAppLogger:Log entry 6298
# INFO:MyAppLogger:Log entry 6299
# INFO:MyAppLogger:Log entry 6300
# INFO:MyAppLogger:Log entry 6301
# INFO:MyAppLogger:Log entry 6302
# INFO:MyAppLogger:Log entry 6303
# INFO:MyAppLogger:Log entry 6304
# INFO:MyAppLogger:Log entry 6305
# INFO:MyAppLogger:Log entry 6306
# INFO:MyAppLogger:Log entry 6307
# INFO:MyAppLogger:Log entry 6308
# INFO:MyAppLogger:Log entry 6309
# INFO:MyAppLogger:Log entry 6310
# INFO:MyAppLogger:Log entry 6311
# INFO:MyAppLogger:Log entry 6312
# INFO:MyAppLogger:Log entry 6313
# INFO:MyAppLogger:Log entry 6314
# INFO:MyAppLogger:Log entry 6315
# INFO:MyAppLogger:Log entry 6316
# INFO:MyAppLogger:Log entry 6317
# INFO:MyAppLogger:Log entry 6318
# INFO:MyAppLogger:Log entry 6319
# INFO:MyAppLogger:Log entry 6320
# INFO:MyAppLogger:Log entry 6321
# INFO:MyAppLogger:Log entry 6322
# INFO:MyAppLogger:Log entry 6323
# INFO:MyAppLogger:Log entry 6324
# INFO:MyAppLogger:Log entry 6325
# INFO:MyAppLogger:Log entry 6326
# INFO:MyAppLogger:Log entry 6327
# INFO:MyAppLogger:Log entry 6328
# INFO:MyAppLogger:Log entry 6329
# INFO:MyAppLogger:Log entry 6330
# INFO:MyAppLogger:Log entry 6331
# INFO:MyAppLogger:Log entry 6332
# INFO:MyAppLogger:Log entry 6333
# INFO:MyAppLogger:Log entry 6334
# INFO:MyAppLogger:Log entry 6335
# INFO:MyAppLogger:Log entry 6336
# INFO:MyAppLogger:Log entry 6337
# INFO:MyAppLogger:Log entry 6338
# INFO:MyAppLogger:Log entry 6339
# INFO:MyAppLogger:Log entry 6340
# INFO:MyAppLogger:Log entry 6341
# INFO:MyAppLogger:Log entry 6342
# INFO:MyAppLogger:Log entry 6343
# INFO:MyAppLogger:Log entry 6344
# INFO:MyAppLogger:Log entry 6345
# INFO:MyAppLogger:Log entry 6346
# INFO:MyAppLogger:Log entry 6347
# INFO:MyAppLogger:Log entry 6348
# INFO:MyAppLogger:Log entry 6349
# INFO:MyAppLogger:Log entry 6350
# INFO:MyAppLogger:Log entry 6351
# INFO:MyAppLogger:Log entry 6352
# INFO:MyAppLogger:Log entry 6353
# INFO:MyAppLogger:Log entry 6354
# INFO:MyAppLogger:Log entry 6355
# INFO:MyAppLogger:Log entry 6356
# INFO:MyAppLogger:Log entry 6357
# INFO:MyAppLogger:Log entry 6358
# INFO:MyAppLogger:Log entry 6359
# INFO:MyAppLogger:Log entry 6360
# INFO:MyAppLogger:Log entry 6361
# INFO:MyAppLogger:Log entry 6362
# INFO:MyAppLogger:Log entry 6363
# INFO:MyAppLogger:Log entry 6364
# INFO:MyAppLogger:Log entry 6365
# INFO:MyAppLogger:Log entry 6366
# INFO:MyAppLogger:Log entry 6367
# INFO:MyAppLogger:Log entry 6368
# INFO:MyAppLogger:Log entry 6369
# INFO:MyAppLogger:Log entry 6370
# INFO:MyAppLogger:Log entry 6371
# INFO:MyAppLogger:Log entry 6372
# INFO:MyAppLogger:Log entry 6373
# INFO:MyAppLogger:Log entry 6374
# INFO:MyAppLogger:Log entry 6375
# INFO:MyAppLogger:Log entry 6376
# INFO:MyAppLogger:Log entry 6377
# INFO:MyAppLogger:Log entry 6378
# INFO:MyAppLogger:Log entry 6379
# INFO:MyAppLogger:Log entry 6380
# INFO:MyAppLogger:Log entry 6381
# INFO:MyAppLogger:Log entry 6382
# INFO:MyAppLogger:Log entry 6383
# INFO:MyAppLogger:Log entry 6384
# INFO:MyAppLogger:Log entry 6385
# INFO:MyAppLogger:Log entry 6386
# INFO:MyAppLogger:Log entry 6387
# INFO:MyAppLogger:Log entry 6388
# INFO:MyAppLogger:Log entry 6389
# INFO:MyAppLogger:Log entry 6390
# INFO:MyAppLogger:Log entry 6391
# INFO:MyAppLogger:Log entry 6392
# INFO:MyAppLogger:Log entry 6393
# INFO:MyAppLogger:Log entry 6394
# INFO:MyAppLogger:Log entry 6395
# INFO:MyAppLogger:Log entry 6396
# INFO:MyAppLogger:Log entry 6397
# INFO:MyAppLogger:Log entry 6398
# INFO:MyAppLogger:Log entry 6399
# INFO:MyAppLogger:Log entry 6400
# INFO:MyAppLogger:Log entry 6401
# INFO:MyAppLogger:Log entry 6402
# INFO:MyAppLogger:Log entry 6403
# INFO:MyAppLogger:Log entry 6404
# INFO:MyAppLogger:Log entry 6405
# INFO:MyAppLogger:Log entry 6406
# INFO:MyAppLogger:Log entry 6407
# INFO:MyAppLogger:Log entry 6408
# INFO:MyAppLogger:Log entry 6409
# INFO:MyAppLogger:Log entry 6410
# INFO:MyAppLogger:Log entry 6411
# INFO:MyAppLogger:Log entry 6412
# INFO:MyAppLogger:Log entry 6413
# INFO:MyAppLogger:Log entry 6414
# INFO:MyAppLogger:Log entry 6415
# INFO:MyAppLogger:Log entry 6416
# INFO:MyAppLogger:Log entry 6417
# INFO:MyAppLogger:Log entry 6418
# INFO:MyAppLogger:Log entry 6419
# INFO:MyAppLogger:Log entry 6420
# INFO:MyAppLogger:Log entry 6421
# INFO:MyAppLogger:Log entry 6422
# INFO:MyAppLogger:Log entry 6423
# INFO:MyAppLogger:Log entry 6424
# INFO:MyAppLogger:Log entry 6425
# INFO:MyAppLogger:Log entry 6426
# INFO:MyAppLogger:Log entry 6427
# INFO:MyAppLogger:Log entry 6428
# INFO:MyAppLogger:Log entry 6429
# INFO:MyAppLogger:Log entry 6430
# INFO:MyAppLogger:Log entry 6431
# INFO:MyAppLogger:Log entry 6432
# INFO:MyAppLogger:Log entry 6433
# INFO:MyAppLogger:Log entry 6434
# INFO:MyAppLogger:Log entry 6435
# INFO:MyAppLogger:Log entry 6436
# INFO:MyAppLogger:Log entry 6437
# INFO:MyAppLogger:Log entry 6438
# INFO:MyAppLogger:Log entry 6439
# INFO:MyAppLogger:Log entry 6440
# INFO:MyAppLogger:Log entry 6441
# INFO:MyAppLogger:Log entry 6442
# INFO:MyAppLogger:Log entry 6443
# INFO:MyAppLogger:Log entry 6444
# INFO:MyAppLogger:Log entry 6445
# INFO:MyAppLogger:Log entry 6446
# INFO:MyAppLogger:Log entry 6447
# INFO:MyAppLogger:Log entry 6448
# INFO:MyAppLogger:Log entry 6449
# INFO:MyAppLogger:Log entry 6450
# INFO:MyAppLogger:Log entry 6451
# INFO:MyAppLogger:Log entry 6452
# INFO:MyAppLogger:Log entry 6453
# INFO:MyAppLogger:Log entry 6454
# INFO:MyAppLogger:Log entry 6455
# INFO:MyAppLogger:Log entry 6456
# INFO:MyAppLogger:Log entry 6457
# INFO:MyAppLogger:Log entry 6458
# INFO:MyAppLogger:Log entry 6459
# INFO:MyAppLogger:Log entry 6460
# INFO:MyAppLogger:Log entry 6461
# INFO:MyAppLogger:Log entry 6462
# INFO:MyAppLogger:Log entry 6463
# INFO:MyAppLogger:Log entry 6464
# INFO:MyAppLogger:Log entry 6465
# INFO:MyAppLogger:Log entry 6466
# INFO:MyAppLogger:Log entry 6467
# INFO:MyAppLogger:Log entry 6468
# INFO:MyAppLogger:Log entry 6469
# INFO:MyAppLogger:Log entry 6470
# INFO:MyAppLogger:Log entry 6471
# INFO:MyAppLogger:Log entry 6472
# INFO:MyAppLogger:Log entry 6473
# INFO:MyAppLogger:Log entry 6474
# INFO:MyAppLogger:Log entry 6475
# INFO:MyAppLogger:Log entry 6476
# INFO:MyAppLogger:Log entry 6477
# INFO:MyAppLogger:Log entry 6478
# INFO:MyAppLogger:Log entry 6479
# INFO:MyAppLogger:Log entry 6480
# INFO:MyAppLogger:Log entry 6481
# INFO:MyAppLogger:Log entry 6482
# INFO:MyAppLogger:Log entry 6483
# INFO:MyAppLogger:Log entry 6484
# INFO:MyAppLogger:Log entry 6485
# INFO:MyAppLogger:Log entry 6486
# INFO:MyAppLogger:Log entry 6487
# INFO:MyAppLogger:Log entry 6488
# INFO:MyAppLogger:Log entry 6489
# INFO:MyAppLogger:Log entry 6490
# INFO:MyAppLogger:Log entry 6491
# INFO:MyAppLogger:Log entry 6492
# INFO:MyAppLogger:Log entry 6493
# INFO:MyAppLogger:Log entry 6494
# INFO:MyAppLogger:Log entry 6495
# INFO:MyAppLogger:Log entry 6496
# INFO:MyAppLogger:Log entry 6497
# ...
# INFO:MyAppLogger:Log entry 9500
# INFO:MyAppLogger:Log entry 9501
# INFO:MyAppLogger:Log entry 9502
# INFO:MyAppLogger:Log entry 9503
# INFO:MyAppLogger:Log entry 9504
# INFO:MyAppLogger:Log entry 9505
# INFO:MyAppLogger:Log entry 9506
# INFO:MyAppLogger:Log entry 9507
# INFO:MyAppLogger:Log entry 9508
# INFO:MyAppLogger:Log entry 9509
# INFO:MyAppLogger:Log entry 9510
# INFO:MyAppLogger:Log entry 9511
# INFO:MyAppLogger:Log entry 9512
# INFO:MyAppLogger:Log entry 9513
# INFO:MyAppLogger:Log entry 9514
# INFO:MyAppLogger:Log entry 9515
# INFO:MyAppLogger:Log entry 9516
# INFO:MyAppLogger:Log entry 9517
# INFO:MyAppLogger:Log entry 9518
# INFO:MyAppLogger:Log entry 9519
# INFO:MyAppLogger:Log entry 9520
# INFO:MyAppLogger:Log entry 9521
# INFO:MyAppLogger:Log entry 9522
# INFO:MyAppLogger:Log entry 9523
# INFO:MyAppLogger:Log entry 9524
# INFO:MyAppLogger:Log entry 9525
# INFO:MyAppLogger:Log entry 9526
# INFO:MyAppLogger:Log entry 9527
# INFO:MyAppLogger:Log entry 9528
# INFO:MyAppLogger:Log entry 9529
# INFO:MyAppLogger:Log entry 9530
# INFO:MyAppLogger:Log entry 9531
# INFO:MyAppLogger:Log entry 9532
# INFO:MyAppLogger:Log entry 9533
# INFO:MyAppLogger:Log entry 9534
# INFO:MyAppLogger:Log entry 9535
# INFO:MyAppLogger:Log entry 9536
# INFO:MyAppLogger:Log entry 9537
# INFO:MyAppLogger:Log entry 9538
# INFO:MyAppLogger:Log entry 9539
# INFO:MyAppLogger:Log entry 9540
# INFO:MyAppLogger:Log entry 9541
# INFO:MyAppLogger:Log entry 9542
# INFO:MyAppLogger:Log entry 9543
# INFO:MyAppLogger:Log entry 9544
# INFO:MyAppLogger:Log entry 9545
# INFO:MyAppLogger:Log entry 9546
# INFO:MyAppLogger:Log entry 9547
# INFO:MyAppLogger:Log entry 9548
# INFO:MyAppLogger:Log entry 9549
# INFO:MyAppLogger:Log entry 9550
# INFO:MyAppLogger:Log entry 9551
# INFO:MyAppLogger:Log entry 9552
# INFO:MyAppLogger:Log entry 9553
# INFO:MyAppLogger:Log entry 9554
# INFO:MyAppLogger:Log entry 9555
# INFO:MyAppLogger:Log entry 9556
# INFO:MyAppLogger:Log entry 9557
# INFO:MyAppLogger:Log entry 9558
# INFO:MyAppLogger:Log entry 9559
# INFO:MyAppLogger:Log entry 9560
# INFO:MyAppLogger:Log entry 9561
# INFO:MyAppLogger:Log entry 9562
# INFO:MyAppLogger:Log entry 9563
# INFO:MyAppLogger:Log entry 9564
# INFO:MyAppLogger:Log entry 9565
# INFO:MyAppLogger:Log entry 9566
# INFO:MyAppLogger:Log entry 9567
# INFO:MyAppLogger:Log entry 9568
# INFO:MyAppLogger:Log entry 9569
# INFO:MyAppLogger:Log entry 9570
# INFO:MyAppLogger:Log entry 9571
# INFO:MyAppLogger:Log entry 9572
# INFO:MyAppLogger:Log entry 9573
# INFO:MyAppLogger:Log entry 9574
# INFO:MyAppLogger:Log entry 9575
# INFO:MyAppLogger:Log entry 9576
# INFO:MyAppLogger:Log entry 9577
# INFO:MyAppLogger:Log entry 9578
# INFO:MyAppLogger:Log entry 9579
# INFO:MyAppLogger:Log entry 9580
# INFO:MyAppLogger:Log entry 9581
# INFO:MyAppLogger:Log entry 9582
# INFO:MyAppLogger:Log entry 9583
# INFO:MyAppLogger:Log entry 9584
# INFO:MyAppLogger:Log entry 9585
# INFO:MyAppLogger:Log entry 9586
# INFO:MyAppLogger:Log entry 9587
# INFO:MyAppLogger:Log entry 9588
# INFO:MyAppLogger:Log entry 9589
# INFO:MyAppLogger:Log entry 9590
# INFO:MyAppLogger:Log entry 9591
# INFO:MyAppLogger:Log entry 9592
# INFO:MyAppLogger:Log entry 9593
# INFO:MyAppLogger:Log entry 9594
# INFO:MyAppLogger:Log entry 9595
# INFO:MyAppLogger:Log entry 9596
# INFO:MyAppLogger:Log entry 9597
# INFO:MyAppLogger:Log entry 9598
# INFO:MyAppLogger:Log entry 9599
# INFO:MyAppLogger:Log entry 9600
# INFO:MyAppLogger:Log entry 9601
# INFO:MyAppLogger:Log entry 9602
# INFO:MyAppLogger:Log entry 9603
# INFO:MyAppLogger:Log entry 9604
# INFO:MyAppLogger:Log entry 9605
# INFO:MyAppLogger:Log entry 9606
# INFO:MyAppLogger:Log entry 9607
# INFO:MyAppLogger:Log entry 9608
# INFO:MyAppLogger:Log entry 9609
# INFO:MyAppLogger:Log entry 9610
# INFO:MyAppLogger:Log entry 9611
# INFO:MyAppLogger:Log entry 9612
# INFO:MyAppLogger:Log entry 9613
# INFO:MyAppLogger:Log entry 9614
# INFO:MyAppLogger:Log entry 9615
# INFO:MyAppLogger:Log entry 9616
# INFO:MyAppLogger:Log entry 9617
# INFO:MyAppLogger:Log entry 9618
# INFO:MyAppLogger:Log entry 9619
# INFO:MyAppLogger:Log entry 9620
# INFO:MyAppLogger:Log entry 9621
# INFO:MyAppLogger:Log entry 9622
# INFO:MyAppLogger:Log entry 9623
# INFO:MyAppLogger:Log entry 9624
# INFO:MyAppLogger:Log entry 9625
# INFO:MyAppLogger:Log entry 9626
# INFO:MyAppLogger:Log entry 9627
# INFO:MyAppLogger:Log entry 9628
# INFO:MyAppLogger:Log entry 9629
# INFO:MyAppLogger:Log entry 9630
# INFO:MyAppLogger:Log entry 9631
# INFO:MyAppLogger:Log entry 9632
# INFO:MyAppLogger:Log entry 9633
# INFO:MyAppLogger:Log entry 9634
# INFO:MyAppLogger:Log entry 9635
# INFO:MyAppLogger:Log entry 9636
# INFO:MyAppLogger:Log entry 9637
# INFO:MyAppLogger:Log entry 9638
# INFO:MyAppLogger:Log entry 9639
# INFO:MyAppLogger:Log entry 9640
# INFO:MyAppLogger:Log entry 9641
# INFO:MyAppLogger:Log entry 9642
# INFO:MyAppLogger:Log entry 9643
# INFO:MyAppLogger:Log entry 9644
# INFO:MyAppLogger:Log entry 9645
# INFO:MyAppLogger:Log entry 9646
# INFO:MyAppLogger:Log entry 9647
# INFO:MyAppLogger:Log entry 9648
# INFO:MyAppLogger:Log entry 9649
# INFO:MyAppLogger:Log entry 9650
# INFO:MyAppLogger:Log entry 9651
# INFO:MyAppLogger:Log entry 9652
# INFO:MyAppLogger:Log entry 9653
# INFO:MyAppLogger:Log entry 9654
# INFO:MyAppLogger:Log entry 9655
# INFO:MyAppLogger:Log entry 9656
# INFO:MyAppLogger:Log entry 9657
# INFO:MyAppLogger:Log entry 9658
# INFO:MyAppLogger:Log entry 9659
# INFO:MyAppLogger:Log entry 9660
# INFO:MyAppLogger:Log entry 9661
# INFO:MyAppLogger:Log entry 9662
# INFO:MyAppLogger:Log entry 9663
# INFO:MyAppLogger:Log entry 9664
# INFO:MyAppLogger:Log entry 9665
# INFO:MyAppLogger:Log entry 9666
# INFO:MyAppLogger:Log entry 9667
# INFO:MyAppLogger:Log entry 9668
# INFO:MyAppLogger:Log entry 9669
# INFO:MyAppLogger:Log entry 9670
# INFO:MyAppLogger:Log entry 9671
# INFO:MyAppLogger:Log entry 9672
# INFO:MyAppLogger:Log entry 9673
# INFO:MyAppLogger:Log entry 9674
# INFO:MyAppLogger:Log entry 9675
# INFO:MyAppLogger:Log entry 9676
# INFO:MyAppLogger:Log entry 9677
# INFO:MyAppLogger:Log entry 9678
# INFO:MyAppLogger:Log entry 9679
# INFO:MyAppLogger:Log entry 9680
# INFO:MyAppLogger:Log entry 9681
# INFO:MyAppLogger:Log entry 9682
# INFO:MyAppLogger:Log entry 9683
# INFO:MyAppLogger:Log entry 9684
# INFO:MyAppLogger:Log entry 9685
# INFO:MyAppLogger:Log entry 9686
# INFO:MyAppLogger:Log entry 9687
# INFO:MyAppLogger:Log entry 9688
# INFO:MyAppLogger:Log entry 9689
# INFO:MyAppLogger:Log entry 9690
# INFO:MyAppLogger:Log entry 9691
# INFO:MyAppLogger:Log entry 9692
# INFO:MyAppLogger:Log entry 9693
# INFO:MyAppLogger:Log entry 9694
# INFO:MyAppLogger:Log entry 9695
# INFO:MyAppLogger:Log entry 9696
# INFO:MyAppLogger:Log entry 9697
# INFO:MyAppLogger:Log entry 9698
# INFO:MyAppLogger:Log entry 9699
# INFO:MyAppLogger:Log entry 9700
# INFO:MyAppLogger:Log entry 9701
# INFO:MyAppLogger:Log entry 9702
# INFO:MyAppLogger:Log entry 9703
# INFO:MyAppLogger:Log entry 9704
# INFO:MyAppLogger:Log entry 9705
# INFO:MyAppLogger:Log entry 9706
# INFO:MyAppLogger:Log entry 9707
# INFO:MyAppLogger:Log entry 9708
# INFO:MyAppLogger:Log entry 9709
# INFO:MyAppLogger:Log entry 9710
# INFO:MyAppLogger:Log entry 9711
# INFO:MyAppLogger:Log entry 9712
# INFO:MyAppLogger:Log entry 9713
# INFO:MyAppLogger:Log entry 9714
# INFO:MyAppLogger:Log entry 9715
# INFO:MyAppLogger:Log entry 9716
# INFO:MyAppLogger:Log entry 9717
# INFO:MyAppLogger:Log entry 9718
# INFO:MyAppLogger:Log entry 9719
# INFO:MyAppLogger:Log entry 9720
# INFO:MyAppLogger:Log entry 9721
# INFO:MyAppLogger:Log entry 9722
# INFO:MyAppLogger:Log entry 9723
# INFO:MyAppLogger:Log entry 9724
# INFO:MyAppLogger:Log entry 9725
# INFO:MyAppLogger:Log entry 9726
# INFO:MyAppLogger:Log entry 9727
# INFO:MyAppLogger:Log entry 9728
# INFO:MyAppLogger:Log entry 9729
# INFO:MyAppLogger:Log entry 9730
# INFO:MyAppLogger:Log entry 9731
# INFO:MyAppLogger:Log entry 9732
# INFO:MyAppLogger:Log entry 9733
# INFO:MyAppLogger:Log entry 9734
# INFO:MyAppLogger:Log entry 9735
# INFO:MyAppLogger:Log entry 9736
# INFO:MyAppLogger:Log entry 9737
# INFO:MyAppLogger:Log entry 9738
# INFO:MyAppLogger:Log entry 9739
# INFO:MyAppLogger:Log entry 9740
# INFO:MyAppLogger:Log entry 9741
# INFO:MyAppLogger:Log entry 9742
# INFO:MyAppLogger:Log entry 9743
# INFO:MyAppLogger:Log entry 9744
# INFO:MyAppLogger:Log entry 9745
# INFO:MyAppLogger:Log entry 9746
# INFO:MyAppLogger:Log entry 9747
# INFO:MyAppLogger:Log entry 9748
# INFO:MyAppLogger:Log entry 9749
# INFO:MyAppLogger:Log entry 9750
# INFO:MyAppLogger:Log entry 9751
# INFO:MyAppLogger:Log entry 9752
# INFO:MyAppLogger:Log entry 9753
# INFO:MyAppLogger:Log entry 9754
# INFO:MyAppLogger:Log entry 9755
# INFO:MyAppLogger:Log entry 9756
# INFO:MyAppLogger:Log entry 9757
# INFO:MyAppLogger:Log entry 9758
# INFO:MyAppLogger:Log entry 9759
# INFO:MyAppLogger:Log entry 9760
# INFO:MyAppLogger:Log entry 9761
# INFO:MyAppLogger:Log entry 9762
# INFO:MyAppLogger:Log entry 9763
# INFO:MyAppLogger:Log entry 9764
# INFO:MyAppLogger:Log entry 9765
# INFO:MyAppLogger:Log entry 9766
# INFO:MyAppLogger:Log entry 9767
# INFO:MyAppLogger:Log entry 9768
# INFO:MyAppLogger:Log entry 9769
# INFO:MyAppLogger:Log entry 9770
# INFO:MyAppLogger:Log entry 9771
# INFO:MyAppLogger:Log entry 9772
# INFO:MyAppLogger:Log entry 9773
# INFO:MyAppLogger:Log entry 9774
# INFO:MyAppLogger:Log entry 9775
# INFO:MyAppLogger:Log entry 9776
# INFO:MyAppLogger:Log entry 9777
# INFO:MyAppLogger:Log entry 9778
# INFO:MyAppLogger:Log entry 9779
# INFO:MyAppLogger:Log entry 9780
# INFO:MyAppLogger:Log entry 9781
# INFO:MyAppLogger:Log entry 9782
# INFO:MyAppLogger:Log entry 9783
# INFO:MyAppLogger:Log entry 9784
# INFO:MyAppLogger:Log entry 9785
# INFO:MyAppLogger:Log entry 9786
# INFO:MyAppLogger:Log entry 9787
# INFO:MyAppLogger:Log entry 9788
# INFO:MyAppLogger:Log entry 9789
# INFO:MyAppLogger:Log entry 9790
# INFO:MyAppLogger:Log entry 9791
# INFO:MyAppLogger:Log entry 9792
# INFO:MyAppLogger:Log entry 9793
# INFO:MyAppLogger:Log entry 9794
# INFO:MyAppLogger:Log entry 9795
# INFO:MyAppLogger:Log entry 9796
# INFO:MyAppLogger:Log entry 9797
# INFO:MyAppLogger:Log entry 9798
# INFO:MyAppLogger:Log entry 9799
# INFO:MyAppLogger:Log entry 9800
# INFO:MyAppLogger:Log entry 9801
# INFO:MyAppLogger:Log entry 9802
# INFO:MyAppLogger:Log entry 9803
# INFO:MyAppLogger:Log entry 9804
# INFO:MyAppLogger:Log entry 9805
# INFO:MyAppLogger:Log entry 9806
# INFO:MyAppLogger:Log entry 9807
# INFO:MyAppLogger:Log entry 9808
# INFO:MyAppLogger:Log entry 9809
# INFO:MyAppLogger:Log entry 9810
# INFO:MyAppLogger:Log entry 9811
# INFO:MyAppLogger:Log entry 9812
# INFO:MyAppLogger:Log entry 9813
# INFO:MyAppLogger:Log entry 9814
# INFO:MyAppLogger:Log entry 9815
# INFO:MyAppLogger:Log entry 9816
# INFO:MyAppLogger:Log entry 9817
# INFO:MyAppLogger:Log entry 9818
# INFO:MyAppLogger:Log entry 9819
# INFO:MyAppLogger:Log entry 9820
# INFO:MyAppLogger:Log entry 9821
# INFO:MyAppLogger:Log entry 9822
# INFO:MyAppLogger:Log entry 9823
# INFO:MyAppLogger:Log entry 9824
# INFO:MyAppLogger:Log entry 9825
# INFO:MyAppLogger:Log entry 9826
# INFO:MyAppLogger:Log entry 9827
# INFO:MyAppLogger:Log entry 9828
# INFO:MyAppLogger:Log entry 9829
# INFO:MyAppLogger:Log entry 9830
# INFO:MyAppLogger:Log entry 9831
# INFO:MyAppLogger:Log entry 9832
# INFO:MyAppLogger:Log entry 9833
# INFO:MyAppLogger:Log entry 9834
# INFO:MyAppLogger:Log entry 9835
# INFO:MyAppLogger:Log entry 9836
# INFO:MyAppLogger:Log entry 9837
# INFO:MyAppLogger:Log entry 9838
# INFO:MyAppLogger:Log entry 9839
# INFO:MyAppLogger:Log entry 9840
# INFO:MyAppLogger:Log entry 9841
# INFO:MyAppLogger:Log entry 9842
# INFO:MyAppLogger:Log entry 9843
# INFO:MyAppLogger:Log entry 9844
# INFO:MyAppLogger:Log entry 9845
# INFO:MyAppLogger:Log entry 9846
# INFO:MyAppLogger:Log entry 9847
# INFO:MyAppLogger:Log entry 9848
# INFO:MyAppLogger:Log entry 9849
# INFO:MyAppLogger:Log entry 9850
# INFO:MyAppLogger:Log entry 9851
# INFO:MyAppLogger:Log entry 9852
# INFO:MyAppLogger:Log entry 9853
# INFO:MyAppLogger:Log entry 9854
# INFO:MyAppLogger:Log entry 9855
# INFO:MyAppLogger:Log entry 9856
# INFO:MyAppLogger:Log entry 9857
# INFO:MyAppLogger:Log entry 9858
# INFO:MyAppLogger:Log entry 9859
# INFO:MyAppLogger:Log entry 9860
# INFO:MyAppLogger:Log entry 9861
# INFO:MyAppLogger:Log entry 9862
# INFO:MyAppLogger:Log entry 9863
# INFO:MyAppLogger:Log entry 9864
# INFO:MyAppLogger:Log entry 9865
# INFO:MyAppLogger:Log entry 9866
# INFO:MyAppLogger:Log entry 9867
# INFO:MyAppLogger:Log entry 9868
# INFO:MyAppLogger:Log entry 9869
# INFO:MyAppLogger:Log entry 9870
# INFO:MyAppLogger:Log entry 9871
# INFO:MyAppLogger:Log entry 9872
# INFO:MyAppLogger:Log entry 9873
# INFO:MyAppLogger:Log entry 9874
# INFO:MyAppLogger:Log entry 9875
# INFO:MyAppLogger:Log entry 9876
# INFO:MyAppLogger:Log entry 9877
# INFO:MyAppLogger:Log entry 9878
# INFO:MyAppLogger:Log entry 9879
# INFO:MyAppLogger:Log entry 9880
# INFO:MyAppLogger:Log entry 9881
# INFO:MyAppLogger:Log entry 9882
# INFO:MyAppLogger:Log entry 9883
# INFO:MyAppLogger:Log entry 9884
# INFO:MyAppLogger:Log entry 9885
# INFO:MyAppLogger:Log entry 9886
# INFO:MyAppLogger:Log entry 9887
# INFO:MyAppLogger:Log entry 9888
# INFO:MyAppLogger:Log entry 9889
# INFO:MyAppLogger:Log entry 9890
# INFO:MyAppLogger:Log entry 9891
# INFO:MyAppLogger:Log entry 9892
# INFO:MyAppLogger:Log entry 9893
# INFO:MyAppLogger:Log entry 9894
# INFO:MyAppLogger:Log entry 9895
# INFO:MyAppLogger:Log entry 9896
# INFO:MyAppLogger:Log entry 9897
# INFO:MyAppLogger:Log entry 9898
# INFO:MyAppLogger:Log entry 9899
# INFO:MyAppLogger:Log entry 9900
# INFO:MyAppLogger:Log entry 9901
# INFO:MyAppLogger:Log entry 9902
# INFO:MyAppLogger:Log entry 9903
# INFO:MyAppLogger:Log entry 9904
# INFO:MyAppLogger:Log entry 9905
# INFO:MyAppLogger:Log entry 9906
# INFO:MyAppLogger:Log entry 9907
# INFO:MyAppLogger:Log entry 9908
# INFO:MyAppLogger:Log entry 9909
# INFO:MyAppLogger:Log entry 9910
# INFO:MyAppLogger:Log entry 9911
# INFO:MyAppLogger:Log entry 9912
# INFO:MyAppLogger:Log entry 9913
# INFO:MyAppLogger:Log entry 9914
# INFO:MyAppLogger:Log entry 9915
# INFO:MyAppLogger:Log entry 9916
# INFO:MyAppLogger:Log entry 9917
# INFO:MyAppLogger:Log entry 9918
# INFO:MyAppLogger:Log entry 9919
# INFO:MyAppLogger:Log entry 9920
# INFO:MyAppLogger:Log entry 9921
# INFO:MyAppLogger:Log entry 9922
# INFO:MyAppLogger:Log entry 9923
# INFO:MyAppLogger:Log entry 9924
# INFO:MyAppLogger:Log entry 9925
# INFO:MyAppLogger:Log entry 9926
# INFO:MyAppLogger:Log entry 9927
# INFO:MyAppLogger:Log entry 9928
# INFO:MyAppLogger:Log entry 9929
# INFO:MyAppLogger:Log entry 9930
# INFO:MyAppLogger:Log entry 9931
# INFO:MyAppLogger:Log entry 9932
# INFO:MyAppLogger:Log entry 9933
# INFO:MyAppLogger:Log entry 9934
# INFO:MyAppLogger:Log entry 9935
# INFO:MyAppLogger:Log entry 9936
# INFO:MyAppLogger:Log entry 9937
# INFO:MyAppLogger:Log entry 9938
# INFO:MyAppLogger:Log entry 9939
# INFO:MyAppLogger:Log entry 9940
# INFO:MyAppLogger:Log entry 9941
# INFO:MyAppLogger:Log entry 9942
# INFO:MyAppLogger:Log entry 9943
# INFO:MyAppLogger:Log entry 9944
# INFO:MyAppLogger:Log entry 9945
# INFO:MyAppLogger:Log entry 9946
# INFO:MyAppLogger:Log entry 9947
# INFO:MyAppLogger:Log entry 9948
# INFO:MyAppLogger:Log entry 9949
# INFO:MyAppLogger:Log entry 9950
# INFO:MyAppLogger:Log entry 9951
# INFO:MyAppLogger:Log entry 9952
# INFO:MyAppLogger:Log entry 9953
# INFO:MyAppLogger:Log entry 9954
# INFO:MyAppLogger:Log entry 9955
# INFO:MyAppLogger:Log entry 9956
# INFO:MyAppLogger:Log entry 9957
# INFO:MyAppLogger:Log entry 9958
# INFO:MyAppLogger:Log entry 9959
# INFO:MyAppLogger:Log entry 9960
# INFO:MyAppLogger:Log entry 9961
# INFO:MyAppLogger:Log entry 9962
# INFO:MyAppLogger:Log entry 9963
# INFO:MyAppLogger:Log entry 9964
# INFO:MyAppLogger:Log entry 9965
# INFO:MyAppLogger:Log entry 9966
# INFO:MyAppLogger:Log entry 9967
# INFO:MyAppLogger:Log entry 9968
# INFO:MyAppLogger:Log entry 9969
# INFO:MyAppLogger:Log entry 9970
# INFO:MyAppLogger:Log entry 9971
# INFO:MyAppLogger:Log entry 9972
# INFO:MyAppLogger:Log entry 9973
# INFO:MyAppLogger:Log entry 9974
# INFO:MyAppLogger:Log entry 9975
# INFO:MyAppLogger:Log entry 9976
# INFO:MyAppLogger:Log entry 9977
# INFO:MyAppLogger:Log entry 9978
# INFO:MyAppLogger:Log entry 9979
# INFO:MyAppLogger:Log entry 9980
# INFO:MyAppLogger:Log entry 9981
# INFO:MyAppLogger:Log entry 9982
# INFO:MyAppLogger:Log entry 9983
# INFO:MyAppLogger:Log entry 9984
# INFO:MyAppLogger:Log entry 9985
# INFO:MyAppLogger:Log entry 9986
# INFO:MyAppLogger:Log entry 9987
# INFO:MyAppLogger:Log entry 9988
# INFO:MyAppLogger:Log entry 9989
# INFO:MyAppLogger:Log entry 9990
# INFO:MyAppLogger:Log entry 9991
# INFO:MyAppLogger:Log entry 9992
# INFO:MyAppLogger:Log entry 9993
# INFO:MyAppLogger:Log entry 9994
# INFO:MyAppLogger:Log entry 9995
# INFO:MyAppLogger:Log entry 9996
# INFO:MyAppLogger:Log entry 9997
# INFO:MyAppLogger:Log entry 9998
# INFO:MyAppLogger:Log entry 9999

# %% [markdown]
# ***19.Write a program that handles  both indexerror and keyerror using a try-except block***

# %%
def handle_errors():
    my_list = [10, 20, 30]
    my_dict = {"a": 1, "b": 2, "c": 3}

    try:
        # Attempt to access an out-of-range index in the list
        print(f"List element: {my_list[5]}")

        # Attempt to access a non-existent key in the dictionary
        print(f"Dictionary value: {my_dict['z']}")
    except IndexError as e:
        print(f"IndexError caught: {e}")
    except KeyError as e:
        print(f"KeyError caught: {e}")

# Call the function
handle_errors()
# Out:
# IndexError caught: list index out of range

# %% [markdown]
# ***21.Write a python program that reads a file and prints the number of occurences of a specific word.***

# %%
def count_word_occurrences(file_path, target_word):
    try:
        # Open the file in read mode
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the entire file content
            content = file.read()

        # Convert content to lowercase to make the search case-insensitive
        content_lower = content.lower()
        target_word_lower = target_word.lower()

        # Split the content into words and count occurrences
        word_count = content_lower.split().count(target_word_lower)

        print(f"The word '{target_word}' appears {word_count} times in the file.")
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
file_path = input("Enter the file path: ")
target_word = input("Enter the word to count: ")
count_word_occurrences(file_path, target_word)
# Out:
# Enter the file path: /New Text Document.txt
# Enter the word to count: python
# The word 'python' appears 1 times in the file.

# %% [markdown]
# ***22.How can you check if a file is empty before attempting to read it contents ?***

# %%
import os

def is_file_empty(file_path):
    try:
        if os.path.getsize(file_path) == 0:
            print("The file is empty.")
            return True
        else:
            print("The file is not empty.")
            return False
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
        return True  # Treat non-existent files as "empty"
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return True

# Example usage
file_path = input("Enter the file path: ")
if not is_file_empty(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        print(content)
# Out:
# Enter the file path: /New Text Document.txt
# The file is not empty.
# python is fun.datascience using python.data analytics using python.

# %% [markdown]
# ***23.Write a python program that writes to a log file when an error occurs during file handling.***

# %%
import logging

# Configure logging
log_file = "error_log.log"
logging.basicConfig(
    filename=log_file,
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def handle_file(file_path):
    try:
        # Try to open the file in read mode
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            print("File content:")
            print(content)
    except FileNotFoundError as e:
        error_message = f"FileNotFoundError: The file '{file_path}' does not exist."
        print(error_message)
        logging.error(error_message)
    except PermissionError as e:
        error_message = f"PermissionError: Permission denied for file '{file_path}'."
        print(error_message)
        logging.error(error_message)
    except Exception as e:
        error_message = f"Unexpected error: {e}"
        print(error_message)
        logging.error(error_message)

# Example usage
file_path = input("Enter the file path to read: ")
handle_file(file_path)

print(f"Errors, if any, have been logged to '{log_file}'.")
# Out:
# Enter the file path to read: /New Text Document.txt
# File content:
# python is fun.datascience using python.data analytics using python.
# Errors, if any, have been logged to 'error_log.log'.
