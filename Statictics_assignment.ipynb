# %% [markdown]
# ***1.Explain the differen types of data (qualative and quantitative) and provide examples of each. Discuss nominal,ordinal,interval and ratio scores.***

# %% [markdown]
# Types of Data
# Data is broadly classified into qualitative and quantitative types, each with distinct characteristics and uses.
#
# **1. Qualitative Data (Categorical Data)**
#
# Definition: Data that describes categories or groups and is not numerical. This data is used to classify or label entities and does not have a measurable quantity.
#
# Examples:
#
# Colors of cars (e.g., red, blue, green).
#
# Types of cuisine (e.g., Italian, Chinese, Mexican).
#
# Gender (e.g., male, female).
#
# Subtypes:
#
# *Nominal Data:*
#
# Data with categories that have no inherent order or ranking.
# Example: Types of fruits (apple, banana, cherry).
# Ordinal Data:
# Data with categories that have a logical order but no consistent difference between categories.
#
# Example: Customer satisfaction levels (satisfied, neutral, dissatisfied).
#
# **2. Quantitative Data (Numerical Data)**
#
# Definition: Data that represents measurable quantities and can be
# expressed numerically. This data is used to quantify variables.
#
# Examples:
#
# Height of individuals (e.g., 5.8 ft, 6.2 ft).
#
# Temperature readings (e.g., 25°C, 30°C).
#
# Number of students in a class.
#
# Subtypes:
#
# **Interval Data:**
#
# Data with ordered categories, where the difference between values is meaningful but there is no true zero point.
#
# Example: Temperature in Celsius or Fahrenheit. (0°C doesn’t mean the absence of temperature).
#
# **Ratio Data:**
#
# Data with ordered categories, where the difference between values is meaningful, and there is a true zero point (zero represents the absence of the quantity).
#
# Example: Weight in kilograms, age in years.
#
# Summary of Scales of Measurement
#
#      Scale	             Description	                      Example
#
#     Nominal	   Categories without order or rank	          Hair color (black, brown)
#
#     Ordinal	  Categories with a logical order but no fixed gap Education level (high school, college)
#
#     Interval	Ordered with consistent gaps; no true zero	Temperature in Celsius
#
#     Ratio	Ordered with consistent gaps; true zero exists	Height, weight, income

# %% [markdown]
# ***2.What are the measure of central tendency , and when should you use each ? Discuss the mean, median, and mode with examples and situations where each is appropriate.***

# %% [markdown]
# Measures of Central Tendency
# Central tendency refers to the statistical measures that summarize a dataset by identifying the center point or typical value. The three main measures are mean, median, and mode.
#
# 1. Mean (Arithmetic Average)
# Definition: The sum of all data points divided by the total number of points.
# Formula:
#
# Mean
# =(Sum of data values) / (Number of data values)
#
# Example:
#
# Dataset:
# 10
# ,
# 15
# ,
# 20
# ,
# 25
# ,
# 30
# 10,15,20,25,30
# Mean:
# (
# 10
# +
# 15
# +
# 20
# +
# 25
# +
# 30
# )
# /
# 5
# =
# 20
# (10+15+20+25+30)/5=20.
#
# When to Use:
#
# When the data is evenly distributed without significant outliers.
#
# Example Scenario: Calculating the average score in a test.
#
# 2. Median (Middle Value)
#
# Definition: The middle value of a dataset when it is ordered from smallest to largest. If the dataset has an even number of observations, the median is the average of the two middle values.
#
# Example:
#
# Dataset:
# 10
# ,
# 15
# ,
# 20
# ,
# 25
# ,
# 30
# 10,15,20,25,30
#
# Median:
# 20
# 20.
#
# For an even-sized dataset (
# 10
# ,
# 15
# ,
# 20
# ,
# 25
# 10,15,20,25), Median:
# (
# 15
# +
# 20
# )
# /
# 2
# =
# 17.5
# (15+20)/2=17.5.
#
# When to Use:
#
# When the data contains outliers or is skewed, as the median is unaffected by extreme values.
# Example Scenario: Reporting household income, where a few very high incomes may skew the mean.
#
# 3. Mode (Most Frequent Value)
#
# Definition: The value that occurs most frequently in the dataset. A dataset can have one mode (unimodal), two modes (bimodal), or more (multimodal).
#
# Example:
# Dataset:
# 10
# ,
# 15
# ,
# 20
# ,
# 15
# ,
# 30
# 10,15,20,15,30
#
# Mode:
#
# 15
# 15 (occurs twice).
#
# When to Use:
#
# When identifying the most common category or value is of interest.
# Example Scenario: Determining the most common shoe size sold in a store.

# %% [markdown]
# ***3.Explain the concept of dispersion.How do varience and standard deviation measure the spread of data?***

# %% [markdown]
# **Concept of Dispersion**
#
# Dispersion refers to the spread or variability of a dataset. It measures how much the data values differ from one another and from the central tendency (e.g., mean, median). Dispersion helps to understand the consistency, reliability, and distribution of the data.
#
# **Key characteristics of dispersion:**
#
# *High dispersion:* Data points are spread widely around the center.
#
# *Low dispersion:* Data points are closely clustered around the center.
# Common measures of dispersion include range, variance, and standard deviation. Among these, variance and standard deviation are more precise and commonly used.
#
# **Variance**
#
# Variance quantifies the average squared deviation of each data point from the mean. It provides a measure of how much the data values spread out, but because it involves squaring deviations, it is sensitive to outliers and expressed in squared units.
#
# Formula:
# For a dataset of
#
# σ2 = ∑ (xi – x̄)2/n
#
#
# where,
#
#
# x̄ is the mean of population data set
# n is the total number of observations
#
# For a sample dataset:
#
# Sample Variance
# (
# σ2 = ∑ (xi – x̄)2/(n – 1)
#
#
# where,
#
#
# x̄ is the mean of sample data set
# n is the total number of observations
#
# **Interpretation:**
# A higher variance indicates greater spread in the data.
# A variance of zero means all data points are identical.
#
# Example:
#
# Data:
# 2
# ,
# 4
# ,
# 6
# ,
# 8
# 2,4,6,8, Mean (
# 𝜇
# μ) =
# 5
# 5.
#
# Variance
# =
# (
# 2
# −
# 5
# )
# 2
# +
# (
# 4
# −
# 5
# )
# 2
# +
# (
# 6
# −
# 5
# )
# 2
# +
# (
# 8
# −
# 5
# )
# 2
# 4
# =
# 9
# +
# 1
# +
# 1
# +
# 9
# 4
# =
# 5
# Variance=
# 4
# (2−5)
# 2
#  +(4−5)
# 2
#  +(6−5)
# 2
#  +(8−5)
# 2
#
# ​
#  =
# 4
# 9+1+1+9
# ​
#  =5
# Standard Deviation
# Standard deviation is the square root of variance, making it a measure of dispersion in the same units as the data. It is a widely used statistic to assess the spread of data.
#
# Formula:
#  s=
# n−1
# ∑
# i=1
# n
# ​
#  (x
# i
# ​
#  –
# x
# ˉ
#  )
# 2
#
# ​
#
# ​
#
#
# For a sample:
#
# ![image.png](data:image/png;base64,...)
# Sample Standard Deviation
# (
# 𝑠
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# Sample Standard Deviation(s)=
# n−1
# ∑
# i=1
# n
# ​
#  (x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# ​
#
# Interpretation:
# A small standard deviation indicates that data points are close to the mean.
# A large standard deviation indicates data points are spread out over a wider range.
# Example:
# Using the variance from the earlier example:
#
# Standard Deviation
# =
# 5
# ≈
# 2.236
# Standard Deviation=
# 5
# ​
#  ≈2.236
# Relationship Between Variance and Standard Deviation
# Variance measures the average squared deviation, providing a broader mathematical representation of spread.
# Standard deviation gives a more intuitive sense of dispersion since it is in the same units as the data.
# When to Use Variance and Standard Deviation
# Variance:
#
# Useful in mathematical or statistical models (e.g., analysis of variance, financial models).
# Good for comparing variability in datasets with very different means.
# Standard Deviation:
#
# Preferred in real-world contexts where interpretability in the same unit as the data is important.
# Commonly used to summarize data spread in reports, graphs, and descriptive statistics.
# Applications
# Business: Measuring sales variability over months.
# Finance: Assessing stock market risk by calculating the standard deviation of returns.
# Quality Control: Ensuring product consistency in manufacturing by analyzing variance in measurements.
# By quantifying spread, variance and standard deviation help to understand data variability and make informed decisions based on statistical analysis.

# %% [markdown]
# ***3.What is boxplot ,and what can it tell you about the distribution of data?***

# %% [markdown]
# **Boxplot (or Box-and-Whisker Plot)**
#
# A boxplot is a graphical representation of the distribution of a dataset. It provides a summary of the data by displaying its central tendency, spread, and variability, as well as potential outliers. It is widely used in exploratory data analysis to visualize the key statistical features of the data.
#
# Components of a Boxplot
#
# *Box:*
#
# Represents the interquartile range (IQR), which contains the middle 50% of the data.
# The bottom of the box indicates the first quartile (Q1, 25th percentile).
# The top of the box indicates the third quartile (Q3, 75th percentile).
# The line inside the box represents the median (Q2, 50th percentile).
#
# *Whiskers:*
#
# Extend from the edges of the box to the smallest and largest values within 1.5 × IQR from Q1 and Q3.
# They indicate the range of the data that is not considered an outlier.
#
# *Outliers:*
#
# Data points outside the whiskers (more than 1.5 × IQR away from Q1 or Q3) are plotted individually as dots or small symbols.
# They highlight extreme values in the dataset.
# What a Boxplot Can Tell You About the Distribution
#
# *Central Tendency:*
#
# The median (line inside the box) shows the central value of the data.
#
# *Spread:*
#
# The height of the box (IQR) indicates the range of the middle 50% of the data.
# The length of the whiskers shows the variability in the data.
# Symmetry or Skewness:
#
# If the box is centered around the median and the whiskers are roughly equal in length, the data is symmetrical.
# If the box is shifted or the whiskers are uneven, the data is skewed (longer whisker indicates the direction of the skew).
# Presence of Outliers:
#
# Any points beyond the whiskers are flagged as outliers, which may indicate anomalies or variability.
# Example
# Consider a dataset:
# 2
# ,
# 3
# ,
# 5
# ,
# 7
# ,
# 8
# ,
# 10
# ,
# 15
# ,
# 20
# ,
# 50
# 2,3,5,7,8,10,15,20,50.
#
# Q1 (25th percentile) = 5
# Median (Q2, 50th percentile) = 8
# Q3 (75th percentile) = 15
# IQR =
# 𝑄
# 3
# −
# 𝑄
# 1
# =
# 15
# −
# 5
# =
# 10
# Q3−Q1=15−5=10
# Whiskers extend to
# 5
# −
# 1.5
# ×
# 10
# =
# −
# 10
# 5−1.5×10=−10 and
# 15
# +
# 1.5
# ×
# 10
# =
# 30
# 15+1.5×10=30.
# Outlier:
# 50
# 50 (beyond 30).
# The boxplot would show:
#
# A box from
# 5
# 5 to
# 15
# 15, with a median line at
# 8
# 8.
# Whiskers extending to
# 2
# 2 and
# 20
# 20.
# The outlier
# 50
# 50 plotted separately.
# Advantages of a Boxplot
# Provides a clear summary of the data distribution.
# Easily identifies outliers.
# Effective for comparing distributions across multiple datasets.
# Limitations
# Does not show the exact number of data points or their density within the box.
# Cannot display bimodal distributions or other complex shapes clearly.
# Applications of Boxplots
#
# **Comparing Datasets:**
#
# Comparing exam scores of different classes.
# Analyzing sales performance across regions.
#
# **Detecting Outliers:**
#
# Identifying errors or anomalies in experimental data.
#
# **Understanding Skewness:**
#
# Checking income distribution in a population (often skewed).
# Boxplots provide a compact yet informative way to explore and compare distributions, making them a valuable tool in data analysis.

# %% [markdown]
# ***5.Discuss the role of random smapling in making inferences about popultions.***

# %% [markdown]
# The Role of Random Sampling in Making Inferences About Populations
# Random sampling is a fundamental technique in statistics and research for selecting a subset (sample) of individuals or observations from a larger group (population) in such a way that every member of the population has an equal chance of being selected. It plays a critical role in making inferences about populations because it ensures that the sample is representative, unbiased, and reliable for drawing conclusions about the whole population.
#
# *Key Principles of Random Sampling*
#
# **Representativeness:**
#
# Random sampling helps to ensure that the sample reflects the diversity and characteristics of the population.
# This reduces bias, making the sample a "microcosm" of the population.
#
# **Fairness:**
#
# By giving every individual an equal chance of selection, random sampling eliminates favoritism and systemic exclusion.
#
# **Basis for Statistical Inference:**
#
# Random samples are essential for applying probability theory, which underpins statistical methods for estimating population parameters (e.g., mean, proportion) and testing hypotheses.
# Why Random Sampling is Crucial for Inference
#
# **Reduction of Bias:**
#
# Without random sampling, the sample might overrepresent certain groups, leading to biased estimates and incorrect inferences about the population.
# Enables Generalization:
#
# Random sampling ensures that the results derived from the sample can be extended (generalized) to the entire population with a quantifiable level of confidence.
#
# **Facilitates Use of Statistical Tools:**
#
# Techniques like confidence intervals, hypothesis testing, and regression analysis rely on the assumption that the data is drawn from a random sample.
#
# **Error Estimation:**
#
# Random sampling allows researchers to quantify sampling error (e.g., margin of error), which is the difference between the sample statistic and the true population parameter.
# Examples of Random Sampling in Practice
#
# **Survey Research:**
#
# A polling organization uses random sampling to select respondents from a voter population to estimate election outcomes.
# Quality Control:
#
# A factory inspects a random sample of products from a production line to infer the defect rate.
#
# *Medical Research:*
#
# Researchers randomly select patients from a hospital population to test the effectiveness of a new drug, ensuring results are generalizable to the broader patient group.
#
# **Challenges and Limitations**
#
# **Sampling Frame Issues:**
#
# If the list of the population (sampling frame) is incomplete or inaccurate, some groups may be underrepresented or excluded.
# Non-Response Bias:
#
# Even with random sampling, if certain individuals do not participate (non-response), the sample may become less representative.
# Practical Constraints:
#
# In some cases, random sampling may be costly, time-consuming, or logistically difficult.
# Techniques for Random Sampling
# Simple Random Sampling:
#
# Every individual in the population has an equal probability of selection.
# Example: Drawing names from a hat.
# Stratified Sampling:
#
# The population is divided into subgroups (strata), and random samples are taken from each.
# Example: Dividing students by grade level and sampling from each group.
# Systematic Sampling:
#
# Selecting every
# 𝑘
# kth individual from a list after a random starting point.
# Example: Surveying every 10th person entering a store.
# Cluster Sampling:
#
# Randomly selecting entire groups (clusters) rather than individuals.
# Example: Randomly selecting schools and surveying all students within them.

# %% [markdown]
# ***6.Explain the concept of skewness and its types . How does skewness affect the interpretation of data?***

# %% [markdown]
# **Concept of Skewness**
#
# Skewness is a statistical measure that describes the asymmetry or lack of symmetry in the distribution of data. It indicates whether the data values are spread more to one side of the distribution's peak compared to the other. In essence, skewness tells us about the shape of the data distribution.
#
# **Symmetrical distribution: **
# If the data is perfectly symmetrical, the skewness is zero.
# Asymmetrical distribution: If one tail is longer or more pronounced than the other, the distribution is skewed.
# Types of Skewness
# Positive Skew (Right-Skewed):
#
# The right tail (higher values) is longer than the left tail.
# The majority of the data values are concentrated on the lower end, but some extreme high values "pull" the tail to the right.
# Examples:
# Income distribution in most countries (a few very high earners skew the data).
# Test scores when most students perform poorly but a few excel.
# Effect on Measures of Central Tendency:
# Mean > Median > Mode
#
# **Negative Skew (Left-Skewed):**
#
# The left tail (lower values) is longer than the right tail.
# The majority of the data values are concentrated on the higher end, but some extreme low values "pull" the tail to the left.
# Examples:
# Age at retirement (most people retire around a specific age, but a few retire very early).
# Distribution of grades in an easy exam.
#
# **Effect on Measures of Central Tendency:**
#
# Mean < Median < Mode
#
# **Symmetrical (No Skewness):**
#
# The distribution is balanced and bell-shaped, like a normal distribution.
# Examples:
# Heights of adults in a population (approximately normal).
# Errors in manufacturing processes.
#
# **Effect on Measures of Central Tendency:**
#
# Mean = Median = Mode
#
# How Skewness Affects the Interpretation of Data
#
# **Central Tendency:**
#
# Skewness distorts the relationship between the mean, median, and mode. In a skewed dataset, the mean is "pulled" toward the tail, while the median remains a better indicator of the center.
#
# **Data Analysis and Decision-Making:**
#
# Right-Skewed Data: Analysts should be cautious when interpreting averages, as they may overestimate typical values due to the influence of high outliers.
# Left-Skewed Data: Analysts may underestimate typical values due to the influence of low outliers.
#
# **Choosing Statistical Methods:**
#
# Many statistical tests (e.g., t-tests, regression) assume normality or symmetry in the data. Skewed data may require transformations (e.g., log or square root) to meet these assumptions.
#
# **Real-World Implications:**
#
# In finance, skewness is critical for understanding risks (e.g., the likelihood of extreme losses in left-skewed returns).
# In education, skewness in test scores can reveal whether an exam was too easy or too hard.
#
# **Interpretation of Variability:**
#
# The presence of skewness implies that variability is not evenly distributed. This can influence measures like the standard deviation, which may not fully capture the spread in skewed distributions.
#
# **Visualizing Skewness**
# Skewness can be effectively visualized using histograms or boxplots:
#
# Positive Skew: A histogram with a longer right tail.
#
# Negative Skew: A histogram with a longer left tail.
#
# No Skew: A histogram that is symmetric around the center.

# %% [markdown]
# ***7.Explain the concept of skewness and its types . How does skewness affect the interpretation of data?***

# %% [markdown]
# Interquartile Range (IQR)
# The Interquartile Range (IQR) is a measure of statistical dispersion that quantifies the range within which the middle 50% of the data lies. It is calculated as the difference between the third quartile (
# 𝑄
# 3
# Q3) and the first quartile (
# 𝑄
# 1
# Q1):
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# 𝑄
# 1
# Q1 (First Quartile): The value below which 25% of the data falls (25th percentile).
# 𝑄
# 3
# Q3 (Third Quartile): The value below which 75% of the data falls (75th percentile).
# The IQR is robust to outliers and provides a summary of the variability within the central part of the dataset.
#
# How IQR is Used to Detect Outliers
# Outliers are data points that are significantly different from other observations. The IQR is commonly used to identify these outliers using the following rule:
#
# **Steps to Detect Outliers Using IQR:**
#
# Calculate
# 𝑄
# 1
# Q1 and
# 𝑄
# 3
# Q3:
#
# Sort the data and find the first quartile (
# 𝑄
# 1
# Q1) and third quartile (
# 𝑄
# 3
# Q3).
#
# **Compute the IQR:**
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
#
# **Determine the Outlier Boundaries:**
#
# **Lower Bound: **
#
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Q1−1.5×IQR
#
# **Upper Bound: **
#
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Q3+1.5×IQR
#
# **Identify Outliers:**
#
# Any data point below the lower bound or above the upper bound is considered an outlier.
#
# Example of Outlier Detection
#
# **Dataset:**
# 2
# ,
# 4
# ,
# 7
# ,
# 8
# ,
# 10
# ,
# 11
# ,
# 15
# ,
# 18
# ,
# 28
# 2,4,7,8,10,11,15,18,28
# Calculate
# 𝑄
# 1
# Q1 and
# 𝑄
# 3
# Q3:
#
# 𝑄
# 1
# =
# 7
# Q1=7 (25th percentile).
# 𝑄
# 3
# =
# 15
# Q3=15 (75th percentile).
#
# **Compute IQR:**
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# =
# 15
# −
# 7
# =
# 8
# IQR=Q3−Q1=15−7=8
#
# **Determine Boundaries:**
#
#
# **Lower Bound:**
#
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# =
# 7
# −
# 1.5
# ×
# 8
# =
# −
# 5
# Q1−1.5×IQR=7−1.5×8=−5.
#
# **Upper Bound: **
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# =
# 15
# +
# 1.5
# ×
# 8
# =
# 27
# Q3+1.5×IQR=15+1.5×8=27.
#
# **Identify Outliers:**
#
# Any value below
# −
# 5
# −5 or above
# 27
# 27 is an outlier.
# In this dataset,
# 28
# 28 is an outlier.
#
# **Advantages of Using IQR for Outlier Detection**
#
# **Resistant to Extreme Values:**
#
# Unlike the mean and standard deviation, the IQR is not influenced by outliers, making it robust.
# Simplicity:
#
# The IQR-based method is straightforward and easy to apply.
#
# **Focus on Central Data:**
#
# It concentrates on the central 50% of the data, excluding the tails.
# Limitations
#
# **Not Ideal for Small Datasets:**
#
# In small datasets, the calculation of quartiles can be unstable, leading to unreliable results.
#
# **Subjective Boundaries:**
#
# The
# 1.5
# ×
# IQR
# 1.5×IQR rule is a convention and may not always align with the context of the data.
# Applications of IQR and Outlier Detection
#
# **Quality Control:**
#
# Identifying defective products in manufacturing.
#
# **Finance:**
#
# Detecting anomalies in stock price movements or financial transactions.
#
# **Healthcare:**
#
# Identifying unusual patient data, such as extreme blood pressure readings.
#
# **Data Cleaning:**
#
# Removing outliers to improve the reliability of statistical analyses.
# The IQR is a powerful tool for summarizing data variability and identifying outliers, ensuring robust and accurate data analysis.

# %% [markdown]
# ***8.Discuss the conditions under which the binomial distribution is used.***

# %% [markdown]
# Conditions for Using the Binomial Distribution
# The binomial distribution is a discrete probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure. For the binomial distribution to apply, the following conditions must be met:
#
# **1. Fixed Number of Trials**
#
# The total number of trials,
# 𝑛
# n, must be predetermined and constant.
# Example: Tossing a coin 10 times to count the number of heads.
#
# **2. Two Possible Outcomes (Binary)**
#
# Each trial must result in one of two possible outcomes, commonly labeled as "success" and "failure."
# Example: Success = rolling a 6 on a die, Failure = not rolling a 6.
#
# **3. Independence of Trials**
#
# The outcome of one trial must not affect the outcome of any other trial.
# Example: Tossing a fair coin multiple times satisfies independence because each flip is not influenced by the previous ones.
#
# **4. Constant Probability of Success**
#
# The probability of success (
# 𝑝
# p) must remain the same across all trials.
# Example: In a game where the chance of winning is 0.3, this probability must stay constant for all attempts.
#
# **5. Discrete Data**
#
# The variable of interest must represent a count of successes (whole numbers), not continuous measurements.
# Example: Counting the number of defective items in a batch of 20.
# Mathematical Representation
# If
# 𝑋
# X is the random variable representing the number of successes in
# 𝑛
# n trials:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# 𝑛
# n: Number of trials.
# 𝑘
# k: Number of successes (0 ≤
# 𝑘
# k ≤
# 𝑛
# n).
# 𝑝
# p: Probability of success on a single trial.
# 1
# −
# 𝑝
# 1−p: Probability of failure.
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ): Number of ways to choose
# 𝑘
# k successes out of
# 𝑛
# n trials, calculated as
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#  .
# Examples of Binomial Distribution
#
# Coin Tossing:
#
# Tossing a coin 10 times to count the number of heads.
# 𝑛
# =
# 10
# n=10,
# 𝑝
# =
# 0.5
# p=0.5.
#
# Quality Control:
#
# Inspecting 50 products to count the number of defective ones.
# 𝑛
# =
# 50
# n=50,
# 𝑝
# =
# p= Probability of a defect.
#
# Medical Trials:
#
# Testing a new drug on 100 patients to count how many experience relief.
# 𝑛
# =
# 100
# n=100,
# 𝑝
# =
# p= Probability of experiencing relief.
# When Not to Use the Binomial Distribution
# If any of the conditions are violated, the binomial distribution may not be appropriate. For example:
#
# Trials are not independent:
#
# Sampling without replacement in a small population violates independence.
#
# Probability of success changes:
#
# If the chance of success varies between trials, the distribution is not binomial.
#
# More than two outcomes:
#
# If there are multiple possible outcomes (e.g., rolling a die with six outcomes), a multinomial or other distribution may be more suitable.
# Applications of Binomial Distribution
#
# Business:
#
# Estimating the likelihood of a specific number of customer purchases.
#
# Healthcare:
#
# Calculating the probability of a certain number of patients recovering from treatment.
#
# Education:
#
# Determining the probability of a set number of students passing an exam.
#
# Manufacturing:
#
# Predicting the number of defective items in a production batch.
# The binomial distribution is versatile and widely used in fields where trials follow the conditions outlined above.

# %% [markdown]
# ***9.Explain the properties of the normal distribution and the emperical rule (68-95-99.7 rule).***

# %% [markdown]
# Properties of the Normal Distribution
# The normal distribution is a continuous probability distribution that is symmetric about its mean, commonly referred to as the bell curve due to its shape. It is fundamental in statistics because it describes many natural phenomena and forms the basis for many statistical methods.
#
# *Key Properties*
#
# **Symmetry:**
#
# The normal distribution is symmetric around the mean (
# 𝜇
# μ).
# The left and right halves of the curve are mirror images.
# Mean, Median, and Mode:
#
# In a normal distribution, the mean (
# 𝜇
# μ), median, and mode are all equal and located at the center of the distribution.
#
# **Bell-Shaped Curve:**
#
# The curve is highest at the mean and tapers off as you move away in either direction, approaching but never touching the horizontal axis.
# Defined by Two Parameters:
#
# Mean (
# 𝜇
# μ): Determines the center or location of the distribution.
# Standard Deviation (
# 𝜎
# σ): Determines the spread or width of the curve.
#
# **Total Area Under the Curve:**
#
# The total area under the curve is 1, representing the entire probability distribution.
# Asymptotic:
#
# The tails of the normal distribution approach the horizontal axis but never actually touch it.
#
# *Empirical Rule:*
#
# A large proportion of the data lies within one, two, or three standard deviations of the mean (
# 𝜇
# ±
# 𝑘
# 𝜎
# μ±kσ).
# The Empirical Rule (68-95-99.7 Rule)
# The empirical rule describes how data is distributed in a normal distribution based on the standard deviation (
# 𝜎
# σ):
#
# **68% of the Data:**
#
# Approximately 68% of the data falls within one standard deviation of the mean (
# 𝜇
# ±
# 𝜎
# μ±σ).
#
# **95% of the Data:**
#
# Approximately 95% of the data falls within two standard deviations of the mean (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ).
#
# **99.7% of the Data:**
#
# Approximately 99.7% of the data falls within three standard deviations of the mean (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ).
# Visualizing the Empirical Rule
# For a normal distribution with
# 𝜇
# =
# 100
# μ=100 and
# 𝜎
# =
# 15
# σ=15:
#
# 68%: Data lies between
# 85
# 85 and
# 115
# 115 (
# 100
# ±
# 15
# 100±15).
# 95%: Data lies between
# 70
# 70 and
# 130
# 130 (
# 100
# ±
# 30
# 100±30).
# 99.7%: Data lies between
# 55
# 55 and
# 145
# 145 (
# 100
# ±
# 45
# 100±45).
# Why the Empirical Rule is Useful
#
# **Quick Estimates:**
#
# It provides an intuitive way to estimate probabilities and understand data variability without complex calculations.
#
# **Outlier Detection:**
#
# Data points beyond three standard deviations (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ) are rare (about 0.3% of the data) and may be considered outliers.
# Applications in Various Fields:
#
# Finance: Modeling stock price returns.
# Healthcare: Analyzing patient test results.
# Quality Control: Determining acceptable product variations.
# Applications of the Normal Distribution and Empirical Rule
#
# **Standardization (Z-Scores):**
#
# Z-scores transform data into a standard normal distribution with a mean of 0 and a standard deviation of 1, enabling comparisons across datasets.
#
# **Confidence Intervals:**
#
# Many confidence intervals in hypothesis testing assume a normal distribution.
#
# **Error and Noise Analysis:**
#
# Measurement errors and random noise often follow a normal distribution.

# %% [markdown]
# ***10.Provide a real - life example of  poission process and calculate the probaility for a specific event.***

# %% [markdown]
# Real-Life Example of a Poisson Process
# Example Scenario:
# A hospital receives, on average, 3 emergency calls per hour. These calls occur randomly and independently of each other. This can be modeled as a Poisson process, as the events (calls) meet the following criteria:
#
# They occur randomly in time.
#
# The average rate of occurrence (
# 𝜆
# λ) is constant (3 calls per hour).
# The probability of two events occurring simultaneously is negligible.
#
# **Specific Event:**
#
# What is the probability that the hospital receives exactly 5 emergency calls in an hour?
#
# The Poisson Formula
# The Poisson probability mass function (PMF) is given by:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Where:
#
# 𝑋
# X: Number of events (calls in this case).
# 𝑘
# k: Specific number of events (5 calls in this case).
# 𝜆
# λ: Average rate of events per unit time (3 calls per hour).
# 𝑒
# e: The base of the natural logarithm (
# ≈
# 2.718
# ≈2.718).
# Solution
#
# Parameters:
# 𝜆
# =
# 3
# ,
#
# 𝑘
# =
# 5
# λ=3,k=5
#
# Substitute into the formula:
#
# 𝑃
# (
# 𝑋
# =
# 5
# )
# =
# 𝑒
# −
# 3
# ⋅
# 3
# 5
# 5
# !
# P(X=5)=
# 5!
# e
# −3
#  ⋅3
# 5
#
# ​
#
# Calculate
# 𝑒
# −
# 3
# e
# −3
#  :
# 𝑒
# −
# 3
# ≈
# 0.0498
# e
# −3
#  ≈0.0498
# Calculate
# 3
# 5
# 3
# 5
#  :
# 3
# 5
# =
# 243
# 3
# 5
#  =243
# Calculate
# 5
# !
# 5!:
# 5
# !
# =
# 5
# ⋅
# 4
# ⋅
# 3
# ⋅
# 2
# ⋅
# 1
# =
# 120
# 5!=5⋅4⋅3⋅2⋅1=120
# Substitute values:
# 𝑃
# (
# 𝑋
# =
# 5
# )
# =
# 0.0498
# ⋅
# 243
# 120
# P(X=5)=
# 120
# 0.0498⋅243
# ​
#
# Simplify:
# 𝑃
# (
# 𝑋
# =
# 5
# )
# ≈
# 12.0954
# 120
# ≈
# 0.1008
# P(X=5)≈
# 120
# 12.0954
# ​
#  ≈0.1008
# Result
# The probability of receiving exactly 5 emergency calls in an hour is approximately 10.08%.
#
# **Interpretation**
#
# In practical terms:
#
# If the hospital expects an average of 3 emergency calls per hour, there is about a 10% chance they will receive exactly 5 calls in any given hour.
# This information can help the hospital plan resources like staff and equipment to handle fluctuating call volumes.

# %% [markdown]
# ***11.Explain what a random variable is and differenciate between dicrete and continious random varibles.***

# %% [markdown]
# A random variable is a numerical quantity that is determined by the outcome of a random experiment. It assigns a real number to each possible outcome of the experiment.
#
# Random variables are used to quantify uncertainty and are foundational in probability and statistics.
#
# Notation: Typically denoted by uppercase letters like
# 𝑋
# X,
# 𝑌
# Y, or
# 𝑍
# Z.
# Value: The specific realization of a random variable is denoted by lowercase letters, such as
# 𝑥
# x,
# 𝑦
# y, or
# 𝑧
# z.
#
# **Types of Random Variables**
#
# **1. Discrete Random Variables**
# A random variable is discrete if it takes on a countable number of distinct values.
#
# **Characteristics:**
#
# Values are isolated points (e.g., integers, counts).
# Examples: 0, 1, 2, 3, ...
# Associated with probability mass functions (PMFs), which assign a probability to each possible value.
# Examples:
#
# Number of defective items in a batch of 10.
# Number of heads in 5 coin tosses.
# Number of customers arriving at a store in an hour.
#
# **Key Features:**
#
#
# **Probabilities for each value sum to 1:**
# ∑
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# ∑P(X=x
# i
# ​
#  )=1
#
# **2. Continuous Random Variables**
# A random variable is continuous if it can take any value within a given range or interval.
#
# **Characteristics:**
#
# Values are uncountable and can take any number in a continuum (e.g., all real numbers within a range).
# Associated with probability density functions (PDFs), where probabilities are given as areas under the curve.
# Examples:
#
# Height of individuals in a population.
# Time it takes to complete a task.
# Temperature measured in a day.
#
# **Key Features:**
#
# The probability of the random variable taking on any specific value is 0:
# 𝑃
# (
# 𝑋
# =
# 𝑐
# )
# =
# 0
# P(X=c)=0
# Instead, probabilities are computed over intervals:
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# Where
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function.

# %% [markdown]
# ***12.Provide the example of dataset, calculate both covarience and correlation and interpret the results.***

# %% [markdown]
# Example Dataset
#
#     X (Hours Studied)	Y (Test Scores)
#         1	              50
#         2	              55
#         3	              65
#         4               70
#         5	              85
# Formulas
#
# Covariance:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 𝑛
# −
# 1
# Cov(X,Y)=
# n−1
# ∑
# i=1
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# ​
#
#
# Correlation:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where
# 𝜎
# 𝑋
# σ
# X
# ​
#   and
# 𝜎
# 𝑌
# σ
# Y
# ​
#   are the standard deviations of
# 𝑋
# X and
# 𝑌
# Y, respectively.
#
# Let's calculate these values step-by-step.
#
#
# *Results*
#
# Covariance:
# 21.25
# 21.25
#
# Correlation:
# 0.981
# 0.981 (approximately)
#
# **Interpretation**
#
# Covariance:
#
# The positive covariance (
# 21.25
# 21.25) indicates a positive relationship between the two variables, meaning that as hours studied (
# 𝑋
# X) increases, test scores (
# 𝑌
# Y) tend to increase.
#
# Correlation:
#
# The correlation coefficient (
# 0.981
# 0.981) is close to 1, indicating a very strong positive linear relationship between hours studied and test scores. This means that the more hours a student studies, the higher their test score is likely to be, with a nearly linear trend.

# %%
import numpy as np

# Dataset
X = np.array([1, 2, 3, 4, 5])
Y = np.array([50, 55, 65, 70, 85])

mean_X = np.mean(X)
mean_Y = np.mean(Y)
covariance = np.sum((X - mean_X) * (Y - mean_Y)) / (len(X) - 1)
std_X = np.std(X, ddof=1)
std_Y = np.std(Y, ddof=1)

correlation = covariance / (std_X * std_Y)

covariance, correlation
# Out:
# (21.25, 0.9814954576223637)
